# %%
import argparse
import glob
import json
import multiprocessing
import os
import random
import re
from pathlib import Path
from enum import Enum
from typing import Tuple, List
from collections import defaultdict
from sklearn.metrics import f1_score

import cv2
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import torch
import torch.nn as nn
import torch.nn.functional as F
from PIL import Image
from torch.optim import SGD, Adam, RMSprop
from torch.optim.lr_scheduler import StepLR, ReduceLROnPlateau, CosineAnnealingLR, ExponentialLR
from torch.utils.data import Dataset, Subset, random_split, DataLoader
from torch.utils.tensorboard import SummaryWriter
from torchvision import transforms, models
from albumentations import *
from albumentations.pytorch import ToTensorV2
from torchsampler import ImbalancedDatasetSampler

# %% [markdown]
# # config

# %%
# config
class Config():
    seed = 42
    
    # 데이터
#     data_dir = './face_input/train' #
    data_dir = './input/data/train'
    resize = [224, 224]
    val_ratio = 0.2
    
    # 학습 설정
    epochs = 50
    batch_size = 64
#     batch_size = 16
    valid_batch_size = 1000
    lr = 1e-4
    lr_decay_step = 10
    log_interval = 50
    
    # 세이브 경로
    save_dir = './multiheadage_exp'
    

config = Config()

# %%
# 시드 고정 함수
def seed_everything(seed):
    torch.manual_seed(seed)
    torch.cuda.manual_seed(seed)
    torch.cuda.manual_seed_all(seed)  # if use multi-GPU
    torch.backends.cudnn.deterministic = True
    torch.backends.cudnn.benchmark = False
    np.random.seed(seed)
    random.seed(seed)

# %%
# 시드 고정
seed_everything(config.seed)

# %%
 # -- settings
use_cuda = torch.cuda.is_available()
device = torch.device("cuda" if use_cuda else "cpu")

# %% [markdown]
# # Dataset

# %%
# base setting
IMG_EXTENSIONS = [
    ".jpg", ".JPG", ".jpeg", ".JPEG", ".png",
    ".PNG", ".ppm", ".PPM", ".bmp", ".BMP",
]


def is_image_file(filename):
    return any(filename.endswith(extension) for extension in IMG_EXTENSIONS)

class MaskLabels(int, Enum):
    MASK = 0
    INCORRECT = 1
    NORMAL = 2

class GenderLabels(int, Enum):
    MALE = 0
    FEMALE = 1

    @classmethod
    def from_str(cls, value: str) -> int:
        value = value.lower()
        if value == "male":
            return cls.MALE
        elif value == "female":
            return cls.FEMALE
        else:
            raise ValueError(f"Gender value should be either 'male' or 'female', {value}")

class AgeLabels(int, Enum):
    YOUNG = 0
    MIDDLE = 1
    OLD = 2

    @classmethod
    def from_number(cls, value: str) -> int:
        try:
            value = int(value)
        except Exception:
            raise ValueError(f"Age value should be numeric, {value}")

        if value < 30:
            return cls.YOUNG
        elif value < 60:
            return cls.MIDDLE
        else:
            return cls.OLD

# %% [markdown]
# ### define transform (Augmentation)

# %%
mean=(0.548, 0.504, 0.479)
std=(0.237, 0.247, 0.246)
train_transform = Compose([
    CenterCrop(height=480, width=320),
    HorizontalFlip(p=0.5),
#     ShiftScaleRotate(p=0.5),
    HueSaturationValue(hue_shift_limit=0.2, sat_shift_limit=0.2, val_shift_limit=0.2, p=0.5),
    RandomScale(scale_limit=0.1, interpolation=cv2.INTER_LINEAR, p=0.5),
    RandomBrightnessContrast(brightness_limit=(-0.2, 0.2), contrast_limit=(-0.2, 0.2), p=0.5),
    GaussNoise(p=0.5),
    Resize(config.resize[0], config.resize[1], p=1.0, interpolation=cv2.INTER_LINEAR),
    Normalize(mean=mean, std=std, max_pixel_value=255.0, p=1.0),
    ToTensorV2(p=1.0),
], p=1.0)
val_transform = Compose([
    CenterCrop(height=440, width=320),
    Resize(config.resize[0], config.resize[1], p=1.0),
    Normalize(mean=mean, std=std, max_pixel_value=255.0, p=1.0),
    ToTensorV2(p=1.0),
], p=1.0)

# %% [markdown]
# ### define datasets

# %%
class newBaseDataset(Dataset):

    def __init__(self, img_dir, indices, transform=None):
        """
        MaskBaseDataset을 initialize 합니다.

        Args:
            img_dir: 학습 이미지 폴더의 root directory 입니다.
            transform: Augmentation을 하는 함수입니다.
        """
        self.img_dir = img_dir
        self.transform = transform
        self.indices = indices
        self._file_names = {
            "mask1": MaskLabels.MASK,
            "mask2": MaskLabels.MASK,
            "mask3": MaskLabels.MASK,
            "mask4": MaskLabels.MASK,
            "mask5": MaskLabels.MASK,
            "incorrect_mask": MaskLabels.INCORRECT,
            "normal": MaskLabels.NORMAL
        }

        self.image_paths = []
        self.mask_labels = []
        self.gender_labels = []
        self.age_labels = []
        self.setup()

    def set_transform(self, transform):
        """
        transform 함수를 설정하는 함수입니다.
        """
        self.transform = transform

    def setup(self):
        """
        image의 경로와 각 이미지들의 label을 계산하여 저장해두는 함수입니다.
        """
        csv_path = os.path.join(self.img_dir, 'train.csv')
        csv_data = pd.read_csv(csv_path)
        
        csv_data = csv_data.loc[self.indices]
        csv_data_list = list(csv_data.values)
        cnt = 0
        for id, gender, _, age, path in csv_data_list:
            img_folder = os.path.join(self.img_dir, 'images', path)
            for file_name in os.listdir(img_folder):
                _file_name, ext = os.path.splitext(file_name)
                if _file_name not in self._file_names:  # "." 로 시작하는 파일 및 invalid 한 파일들은 무시합니다
                    continue
                    
                img_path = os.path.join(img_folder, file_name)  # (data_path, 000004_male_Asian_54, mask1.jpg)
                mask_label = self._file_names[_file_name]
                gender_label = GenderLabels.from_str(gender)
                age_label = AgeLabels.from_number(age)
                self.image_paths.append(img_path)
                self.mask_labels.append(mask_label)
                self.gender_labels.append(gender_label)
                self.age_labels.append(age_label)
                
    def __getitem__(self, index):
        """
        데이터를 불러오는 함수입니다. 
        데이터셋 class에 데이터 정보가 저장되어 있고, index를 통해 해당 위치에 있는 데이터 정보를 불러옵니다.
        
        Args:
            index: 불러올 데이터의 인덱스값입니다.
        """
        # 이미지를 불러옵니다.
        image_path = self.image_paths[index]
        image = cv2.imread(image_path)
        image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
#         image = Image.open(image_path)
        
        # 레이블을 불러옵니다.
        mask_label = self.mask_labels[index]
        gender_label = self.gender_labels[index]
        age_label = self.age_labels[index]
        multi_class_label = mask_label * 6 + gender_label * 3 + age_label
        
        # 이미지를 Augmentation 시킵니다.
        image_transform = self.transform(image=np.array(image))['image']
        return image_transform, (mask_label, gender_label, age_label, multi_class_label) # multi_class_label

    def __len__(self):
        return len(self.image_paths)

# %%
# class Sampler(ImbalancedDatasetSampler):
#     def _get_labels(self, dataset):
#         return [dataset.dataset.class_list[i] for i in dataset.indices]

# %%
csv_path = os.path.join(config.data_dir,'train.csv')
data = pd.read_csv(csv_path)
age_img_num_per_cls =  torch.Tensor([data['age'][lambda x : x <30].count(), data['age'][lambda x : (x >= 30) & (x<60)].count(), data['age'][lambda x : x >= 60].count()])
length = len(data)
n_val = int(length * config.val_ratio)
val_indices = set(random.choices(range(length), k=n_val))
train_indices = set(range(length)) - val_indices

# %%
train_dataset = newBaseDataset(img_dir = config.data_dir, indices = train_indices)
val_dataset = newBaseDataset(img_dir = config.data_dir, indices = val_indices)
train_dataset.set_transform(train_transform)
val_dataset.set_transform(val_transform)
train_loader = DataLoader(
    train_dataset,
    batch_size=config.batch_size,
    num_workers=multiprocessing.cpu_count() // 2,
#         sampler=Sampler(train_dataset),
    shuffle=True,
    pin_memory=use_cuda
)
val_loader = DataLoader(
    val_dataset,
    batch_size=config.valid_batch_size,
    num_workers=multiprocessing.cpu_count() // 2,
    shuffle=False,
    pin_memory=use_cuda
)

# %% [markdown]
# # define model

# %%
# class BaseModel(nn.Module):
#     def __init__(self, num_classes):
#         super().__init__()
#         self.base_model = models.vit_b_16(pretrained=True)
#         self.base_model.heads.head = nn.Linear(in_features=768, out_features=num_classes, bias=True)

#     def forward(self, x):
#         return self.base_model(x)

# %%
# class ResnextModel(nn.Module):
#     def __init__(self, num_classes):
#         super().__init__()
#         self.base_model = models.resnext50_32x4d(pretrained=True)
#         self.base_model.fc = nn.Sequential(
#             nn.Linear(in_features=2048, out_features=1000, bias=True),
#             nn.ELU(True),
#             nn.Dropout(),
#             nn.Linear(in_features=1000, out_features=num_classes, bias=True)
#         )
#     def forward(self, x):
#         return self.base_model(x)

# %%
# class Resnext101Model(nn.Module):
#     def __init__(self, num_classes):
#         super().__init__()
#         self.base_model = models.resnext101_32x8d(weights=models.ResNeXt101_32X8D_Weights.DEFAULT)
#         self.base_model.fc = nn.Sequential(
#             nn.Linear(in_features=2048, out_features=1000, bias=True),
#             nn.ELU(True),
#             nn.Dropout(),
#             nn.Linear(in_features=1000, out_features=num_classes, bias=True)
#         )
#     def forward(self, x):
#         return self.base_model(x)

# %%
class Identity(nn.Module):
    def __init__(self):
        super(Identity, self).__init__()
        
    def forward(self, x):
        return x
    
class ResnextMultiheadModel(nn.Module):
    def __init__(self):
        super().__init__()
        self.base_model = models.resnext50_32x4d(pretrained=True)
        self.base_model.fc = Identity()
#         self.base_model = nn.Sequential(*list(self.base_model.children())[:-2])
#         self.avgpool = nn.AdaptiveAvgPool2d(output_size=(1, 1))

        self.fc_mask_classifier = nn.Sequential(
            nn.Linear(in_features=2048, out_features=1000, bias=True),
            nn.ELU(True),
            nn.Dropout(0.5, inplace=True),
            nn.Linear(in_features=1000, out_features=3, bias=True)
#             nn.Softmax(dim=1)
        )
        self.fc_age_classifier = nn.Sequential(
            nn.Linear(in_features=2048, out_features=1000, bias=True),
            nn.ELU(True),
            nn.Dropout(0.5, inplace=True),
            nn.Linear(in_features=1000, out_features=1000, bias=True),
            nn.ELU(True),
            nn.Dropout(0.5, inplace=True),
            nn.Linear(in_features=1000, out_features=3, bias=True)
#             nn.Softmax(dim=1)
        )
        self.fc_gender_classifier = nn.Sequential(
            nn.Linear(in_features=2048, out_features=1000, bias=True),
            nn.ELU(True),
            nn.Dropout(0.5, inplace=True),
            nn.Linear(in_features=1000, out_features=2, bias=True)
#             nn.Sigmoid()
        )
    def forward(self, x):
        x = self.base_model(x)
#         x = self.avgpool(x)
#         print(x.shape)
        mask = self.fc_mask_classifier(x)
        age = self.fc_age_classifier(x)
        gender = self.fc_gender_classifier(x)
        return mask, age, gender
#         return x

# %% [markdown]
# # train

# %%
# model
# num_classes = train_dataset.dataset.num_classes
# print(num_classes)
# model = BaseModel(num_classes=num_classes).to(device)
# model = Resnext101Model(num_classes=num_classes).to(device)
# a = torch.tensor(np.ones([64, 3, 224, 224]), dtype=torch.float32).to(device)
model = ResnextMultiheadModel().to(device)
model = torch.nn.DataParallel(model)
# Out:
# /opt/conda/lib/python3.8/site-packages/torchvision/models/_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and will be removed in 0.15, please use 'weights' instead.
#   warnings.warn(
# /opt/conda/lib/python3.8/site-packages/torchvision/models/_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and will be removed in 0.15. The current behavior is equivalent to passing `weights=ResNeXt50_32X4D_Weights.IMAGENET1K_V1`. You can also use `weights=ResNeXt50_32X4D_Weights.DEFAULT` to get the most up-to-date weights.
#   warnings.warn(msg)

# %%
# https://discuss.pytorch.org/t/is-this-a-correct-implementation-for-focal-loss-in-pytorch/43327/8
class FocalLoss(nn.Module):
    def __init__(self, weight=None,
                 gamma=2., reduction='mean'):
        nn.Module.__init__(self)
        self.weight = weight
        self.gamma = gamma
        self.reduction = reduction

    def forward(self, input_tensor, target_tensor):
        log_prob = F.log_softmax(input_tensor, dim=-1)
        prob = torch.exp(log_prob)
        return F.nll_loss(
            ((1 - prob) ** self.gamma) * log_prob,
            target_tensor,
            weight=self.weight,
            reduction=self.reduction
        )
class LADELoss(nn.Module):
    def __init__(self, num_classes=10, img_num_per_cls=None, remine_lambda=0.1):
        super().__init__()
        if img_num_per_cls is not None:
#             self.img_num_per_cls = calculate_prior(num_classes, img_max, prior, prior_txt, return_num=True).float().cuda()
            self.img_num_per_cls = img_num_per_cls
            self.prior = self.img_num_per_cls / self.img_num_per_cls.sum()
        else:
            self.prior = None
        self.prior = self.prior.to(device)
        self.balanced_prior = torch.tensor(1. / num_classes).float().cuda()
        self.remine_lambda = remine_lambda

        self.num_classes = num_classes
        self.cls_weight = (self.img_num_per_cls.float() / torch.sum(self.img_num_per_cls.float())).cuda()

    def mine_lower_bound(self, x_p, x_q, num_samples_per_cls):
        N = x_p.size(-1)
        first_term = torch.sum(x_p, -1) / (num_samples_per_cls + 1e-8)
        second_term = torch.logsumexp(x_q, -1) - np.log(N)

        return first_term - second_term, first_term, second_term

    def remine_lower_bound(self, x_p, x_q, num_samples_per_cls):
        loss, first_term, second_term = self.mine_lower_bound(x_p, x_q, num_samples_per_cls)
        reg = (second_term ** 2) * self.remine_lambda
        return loss - reg, first_term, second_term

    def forward(self, y_pred, target, q_pred=None):
        """
        y_pred: N x C
        target: N
        """
        per_cls_pred_spread = y_pred.T * (target == torch.arange(0, self.num_classes).view(-1, 1).type_as(target))  # C x N
        pred_spread = (y_pred - torch.log(self.prior + 1e-9) + torch.log(self.balanced_prior + 1e-9)).T  # C x N

        num_samples_per_cls = torch.sum(target == torch.arange(0, self.num_classes).view(-1, 1).type_as(target), -1).float()  # C
        estim_loss, first_term, second_term = self.remine_lower_bound(per_cls_pred_spread, pred_spread, num_samples_per_cls)

        loss = -torch.sum(estim_loss * self.cls_weight)
        return loss

# %% [markdown]
# ### loss , metric , optimizer , scheduler

# %%
# criterion = FocalLoss()

criterion_mask = FocalLoss() #F1Loss(classes=3)
criterion_age = LADELoss(num_classes=3, img_num_per_cls=age_img_num_per_cls) #F1Loss(classes=3)
criterion_gender = FocalLoss() #F1Loss(classes=2)
optimizer = Adam(
    filter(lambda p: p.requires_grad, model.parameters()),
    lr=config.lr,
    weight_decay=5e-4
)
# optimizer = SGD(
#     filter(lambda p: p.requires_grad, model.parameters()),
#     lr=config.lr,
#     momentum=0.9,
#     nesterov=True
# )
# optimizer = RMSprop(
#     filter(lambda p: p.requires_grad, model.parameters()),
#     lr=config.lr,
#     weight_decay=5e-4,
#     momentum=0.9
# )
# scheduler = StepLR(optimizer, config.lr_decay_step, gamma=0.5)
scheduler = ExponentialLR(optimizer, gamma=0.85)
# -- scheduler: ReduceLROnPlateau
# 성능이 향상되지 않을 때 learning rate를 줄입니다. patience=10은 10회 동안 성능 향상이 없을 경우입니다.
# scheduler = ReduceLROnPlateau(optimizer, factor=0.1, patience=10)
# -- scheduler: CosineAnnealingLR
# CosineAnnealing은 learning rate를 cosine 그래프처럼 변화시킵니다.
# scheduler = CosineAnnealingLR(optimizer, T_max=2, eta_min=0.)
def get_lr(optimizer):
    for param_group in optimizer.param_groups:
        return param_group['lr']

# %%
# 세이브 경로
path = Path(config.save_dir)
if (not path.exists()):
    save_dir = str(path)
else:
    dirs = glob.glob(f"{path}*")
    matches = [re.search(rf"%s(\d+)" % path.stem, d) for d in dirs]
    i = [int(m.groups()[0]) for m in matches if m]
    n = max(i) + 1 if i else 2
    save_dir = f"{path}{n}"

print("save path : " + save_dir)
# Out:
# save path : multiheadage_exp4

# %% [markdown]
# ### start training

# %%
logger = SummaryWriter(log_dir=save_dir)
with open(os.path.join(save_dir, 'config.json'), 'w', encoding='utf-8') as f:
    json.dump(vars(config), f, ensure_ascii=False, indent=4)

# %%
best_val_acc = 0
best_val_loss = np.inf
best_val_f1 = 0
for epoch in range(config.epochs):
    # train loop
    model.train()
    loss_value = 0
    matches = 0
#     f1_sum = 0
    label_list=[]
    pred_list=[]
    mask_label_list=[]
    mask_pred_list=[]
    age_label_list=[]
    age_pred_list=[]
    gender_label_list=[]
    gender_pred_list=[]
    for idx, train_batch in enumerate(train_loader):
        inputs, (mask_labels, gender_labels, age_labels, multi_class_labels) = train_batch
        inputs = inputs.to(device)
        mask_labels = mask_labels.to(device)
        gender_labels = gender_labels.to(device)
        age_labels = age_labels.to(device)
        multi_class_labels = multi_class_labels.to(device)

        optimizer.zero_grad()

        mask_outs, age_outs, gender_outs = model(inputs)
        mask_preds = torch.argmax(mask_outs, dim=-1)
        age_preds = torch.argmax(age_outs, dim=-1)
        gender_preds = torch.argmax(gender_outs, dim=-1)
        
        multi_preds = mask_preds * 6 + gender_preds * 3 + age_preds
        mask_loss = criterion_mask(mask_outs, mask_labels)
        age_loss = criterion_age(age_outs, age_labels)
        gender_loss = criterion_gender(gender_outs, gender_labels)
#         mask_loss = criterion(mask_outs, mask_labels)
#         age_loss = criterion(age_outs, age_labels)
#         gender_loss = criterion(gender_outs, gender_labels)
        
        loss = mask_loss + gender_loss + 2*age_loss
        
        loss.backward()
#         mask_loss.backward()
#         age_loss.backward()
#         gender_loss.backward()
        optimizer.step()
        
        label_list+=multi_class_labels.detach().cpu()
        pred_list+=multi_preds.detach().cpu()
        
        mask_label_list+=mask_labels.detach().cpu()
        mask_pred_list+=mask_preds.detach().cpu()
        age_label_list+=age_labels.detach().cpu()
        age_pred_list+=age_preds.detach().cpu()
        gender_label_list+=gender_labels.detach().cpu()
        gender_pred_list+=gender_preds.detach().cpu()

        loss_value += loss.item()
        matches += (multi_preds == multi_class_labels).sum().item()
#         f1_sum += f1_score(labels.cpu(), preds.cpu(), average='macro')
        if (idx + 1) % config.log_interval == 0:
            train_loss = loss_value / config.log_interval
            train_acc = matches / config.batch_size / config.log_interval
#             train_f1 = f1_sum / config.log_interval
            train_f1 = f1_score(label_list, pred_list, average='macro')
            mask_f1 = f1_score(mask_label_list, mask_pred_list, average='macro')
            age_f1 = f1_score(age_label_list, age_pred_list, average='macro')
            gender_f1 = f1_score(gender_label_list, gender_pred_list, average='macro')
            current_lr = get_lr(optimizer)
            print(
                f"Epoch[{epoch}/{config.epochs}]({idx + 1}/{len(train_loader)}) || "
                f"training loss {train_loss:4.4} || training accuracy {train_acc:4.2%} || training f1_score {train_f1:4.4} || lr {current_lr}"
            )
            print(f"          training each f1 || mask f1 {mask_f1:4.4} || age f1 {age_f1:4.4} || gender f1 {gender_f1:4.4}")
            logger.add_scalar("Train/loss", train_loss, epoch * len(train_loader) + idx)
            logger.add_scalar("Train/accuracy", train_acc, epoch * len(train_loader) + idx)
            logger.add_scalar("Train/f1_score", train_f1, epoch * len(train_loader) + idx)

            loss_value = 0
            matches = 0
#             f1_sum = 0
            label_list=[]
            pred_list=[]

    scheduler.step()

    # val loop
    with torch.no_grad():
        print("Calculating validation results...")
        model.eval()
        val_loss_items = []
        val_acc_items = []
#         val_f1_items = []
        label_list=[]
        pred_list=[]
        mask_label_list=[]
        mask_pred_list=[]
        age_label_list=[]
        age_pred_list=[]
        gender_label_list=[]
        gender_pred_list=[]
        for val_batch in val_loader:
            inputs, (mask_labels, gender_labels, age_labels, multi_class_labels) = val_batch
            inputs = inputs.to(device)
            mask_labels = mask_labels.to(device)
            gender_labels = gender_labels.to(device)
            age_labels = age_labels.to(device)
            multi_class_labels = multi_class_labels.to(device)

            mask_outs, age_outs, gender_outs = model(inputs)
            mask_preds = torch.argmax(mask_outs, dim=-1)
            age_preds = torch.argmax(age_outs, dim=-1)
            gender_preds = torch.argmax(gender_outs, dim=-1)
            multi_preds = mask_preds * 6 + gender_preds * 3 + age_preds
            
            label_list+=multi_class_labels.detach().cpu()
            pred_list+=multi_preds.detach().cpu()
            mask_label_list+=mask_labels.detach().cpu()
            mask_pred_list+=mask_preds.detach().cpu()
            age_label_list+=age_labels.detach().cpu()
            age_pred_list+=age_preds.detach().cpu()
            gender_label_list+=gender_labels.detach().cpu()
            gender_pred_list+=gender_preds.detach().cpu()

#             loss_item = criterion(outs, labels).item() 
            mask_loss = criterion_mask(mask_outs, mask_labels)
            age_loss = criterion_age(age_outs, age_labels)
            gender_loss = criterion_gender(gender_outs, gender_labels)
#             mask_loss = criterion(mask_outs, mask_labels)
#             age_loss = criterion(age_outs, age_labels)
#             gender_loss = criterion(gender_outs, gender_labels)
            loss = mask_loss + age_loss + gender_loss
            
            acc_item = (multi_class_labels == multi_preds).sum().item()
#             f1_item = f1_score(labels.cpu(), preds.cpu(), average='macro').item()
            val_loss_items.append(loss.item())
            val_acc_items.append(acc_item)
#             val_f1_items.append(f1_item)

        val_loss = float(np.sum(val_loss_items) / len(val_loader))
        val_acc = float(np.sum(val_acc_items) / len(val_dataset))
        val_f1= float(f1_score(label_list,pred_list,average="macro"))
        val_mask_f1 = f1_score(mask_label_list, mask_pred_list, average='macro')
        val_age_f1 = f1_score(age_label_list, age_pred_list, average='macro')
        val_gender_f1 = f1_score(gender_label_list, gender_pred_list, average='macro')
#         val_f1 = np.sum(val_f1_items) / len(val_dataset)
        
#         best_val_loss = min(best_val_loss, val_loss)
#         if val_acc > best_val_acc:
        if val_f1 > best_val_f1:
            print(f"New best model for val f1 : {val_f1:4.4}! saving the best model..")
            torch.save(model.module.state_dict(), f"{save_dir}/best.pth")
            best_val_f1 = val_f1
            best_val_acc = val_acc
            best_val_loss = val_loss
        torch.save(model.module.state_dict(), f"{save_dir}/last.pth")
        print(
            f"[Val] acc : {val_acc:4.2%}, loss: {val_loss:4.4}, f1: {val_f1:4.4} || "
            f"best acc : {best_val_acc:4.2%}, best loss: {best_val_loss:4.4}, best f1: {best_val_f1:4.4}"
        )
        print(f"[Val] each f1 || mask f1 {val_mask_f1:4.4} || age f1 {val_age_f1:4.4} || gender f1 {val_gender_f1:4.4}")
        logger.add_scalar("Val/loss", val_loss, epoch)
        logger.add_scalar("Val/accuracy", val_acc, epoch)
        logger.add_scalar("Val/f1", val_f1, epoch)
        print()
# Out:
# Epoch[0/50](50/242) || training loss -1.118 || training accuracy 72.34% || training f1_score 0.5026 || lr 0.0001
#           training each f1 || mask f1 0.8741 || age f1 0.6227 || gender f1 0.8794
# Epoch[0/50](100/242) || training loss -1.592 || training accuracy 86.09% || training f1_score 0.779 || lr 0.0001
#           training each f1 || mask f1 0.9269 || age f1 0.7529 || gender f1 0.914
# Epoch[0/50](150/242) || training loss -1.709 || training accuracy 89.31% || training f1_score 0.7775 || lr 0.0001
#           training each f1 || mask f1 0.948 || age f1 0.7917 || gender f1 0.9303
# Epoch[0/50](200/242) || training loss -1.799 || training accuracy 91.03% || training f1_score 0.8207 || lr 0.0001
#           training each f1 || mask f1 0.9574 || age f1 0.8162 || gender f1 0.9399
# Calculating validation results...
# New best model for val f1 : 0.7681! saving the best model..
# [Val] acc : 86.56%, loss: -0.847, f1: 0.7681 || best acc : 86.56%, best loss: -0.847, best f1: 0.7681
# [Val] each f1 || mask f1 0.9917 || age f1 0.7973 || gender f1 0.9811
#
# Epoch[1/50](50/242) || training loss -1.97 || training accuracy 95.84% || training f1_score 0.9148 || lr 8.5e-05
#           training each f1 || mask f1 0.9879 || age f1 0.9568 || gender f1 0.9875
# Epoch[1/50](100/242) || training loss -1.998 || training accuracy 96.84% || training f1_score 0.9372 || lr 8.5e-05
#           training each f1 || mask f1 0.9903 || age f1 0.9606 || gender f1 0.988
# Epoch[1/50](150/242) || training loss -2.037 || training accuracy 97.78% || training f1_score 0.9646 || lr 8.5e-05
#           training each f1 || mask f1 0.991 || age f1 0.9678 || gender f1 0.9888
# Epoch[1/50](200/242) || training loss -2.036 || training accuracy 97.16% || training f1_score 0.9473 || lr 8.5e-05
#           training each f1 || mask f1 0.9906 || age f1 0.9701 || gender f1 0.9889
# Calculating validation results...
# New best model for val f1 : 0.8079! saving the best model..
# [Val] acc : 91.14%, loss: -0.819, f1: 0.8079 || best acc : 91.14%, best loss: -0.819, best f1: 0.8079
# [Val] each f1 || mask f1 0.9933 || age f1 0.8275 || gender f1 0.9892
#
# Epoch[2/50](50/242) || training loss -2.103 || training accuracy 98.69% || training f1_score 0.9741 || lr 7.225000000000001e-05
#           training each f1 || mask f1 0.9941 || age f1 0.9954 || gender f1 0.9937
# Epoch[2/50](100/242) || training loss -2.107 || training accuracy 99.25% || training f1_score 0.9891 || lr 7.225000000000001e-05
#           training each f1 || mask f1 0.9957 || age f1 0.9955 || gender f1 0.9947
# Epoch[2/50](150/242) || training loss -2.109 || training accuracy 98.94% || training f1_score 0.9782 || lr 7.225000000000001e-05
#           training each f1 || mask f1 0.996 || age f1 0.9947 || gender f1 0.9952
# Epoch[2/50](200/242) || training loss -2.119 || training accuracy 99.12% || training f1_score 0.9904 || lr 7.225000000000001e-05
#           training each f1 || mask f1 0.9962 || age f1 0.9954 || gender f1 0.9952
# Calculating validation results...
# New best model for val f1 : 0.8136! saving the best model..
# [Val] acc : 92.22%, loss: -0.8323, f1: 0.8136 || best acc : 92.22%, best loss: -0.8323, best f1: 0.8136
# [Val] each f1 || mask f1 0.9938 || age f1 0.8465 || gender f1 0.9836
#
# Epoch[3/50](50/242) || training loss -2.131 || training accuracy 99.38% || training f1_score 0.9886 || lr 6.141250000000001e-05
#           training each f1 || mask f1 0.9967 || age f1 0.9971 || gender f1 0.9974
# Epoch[3/50](100/242) || training loss -2.134 || training accuracy 99.25% || training f1_score 0.9915 || lr 6.141250000000001e-05
#           training each f1 || mask f1 0.9962 || age f1 0.9971 || gender f1 0.9969
# Epoch[3/50](150/242) || training loss -2.127 || training accuracy 99.03% || training f1_score 0.9764 || lr 6.141250000000001e-05
#           training each f1 || mask f1 0.9964 || age f1 0.9967 || gender f1 0.9962
# Epoch[3/50](200/242) || training loss -2.14 || training accuracy 99.31% || training f1_score 0.9915 || lr 6.141250000000001e-05
#           training each f1 || mask f1 0.9961 || age f1 0.9968 || gender f1 0.9966
# Calculating validation results...
# New best model for val f1 : 0.8306! saving the best model..
# [Val] acc : 91.84%, loss: -0.8177, f1: 0.8306 || best acc : 91.84%, best loss: -0.8177, best f1: 0.8306
# [Val] each f1 || mask f1 0.9946 || age f1 0.8388 || gender f1 0.9849
#
# Epoch[4/50](50/242) || training loss -2.153 || training accuracy 99.69% || training f1_score 0.9969 || lr 5.2200625000000005e-05
#           training each f1 || mask f1 0.9996 || age f1 0.9998 || gender f1 0.9974
# Epoch[4/50](100/242) || training loss -2.162 || training accuracy 99.69% || training f1_score 0.9942 || lr 5.2200625000000005e-05
#           training each f1 || mask f1 0.9996 || age f1 0.9991 || gender f1 0.9979
# Epoch[4/50](150/242) || training loss -2.163 || training accuracy 99.59% || training f1_score 0.9968 || lr 5.2200625000000005e-05
#           training each f1 || mask f1 0.9993 || age f1 0.9994 || gender f1 0.9976
# Epoch[4/50](200/242) || training loss -2.165 || training accuracy 99.69% || training f1_score 0.9932 || lr 5.2200625000000005e-05
#           training each f1 || mask f1 0.9995 || age f1 0.9989 || gender f1 0.9979
# Calculating validation results...
# New best model for val f1 : 0.8313! saving the best model..
# [Val] acc : 90.41%, loss: -0.7537, f1: 0.8313 || best acc : 90.41%, best loss: -0.7537, best f1: 0.8313
# [Val] each f1 || mask f1 0.9954 || age f1 0.8344 || gender f1 0.9901
#
# Epoch[5/50](50/242) || training loss -2.164 || training accuracy 99.56% || training f1_score 0.9952 || lr 4.437053125e-05
#           training each f1 || mask f1 0.9981 || age f1 0.999 || gender f1 0.9971
# Epoch[5/50](100/242) || training loss -2.173 || training accuracy 99.84% || training f1_score 0.9976 || lr 4.437053125e-05
#           training each f1 || mask f1 0.9991 || age f1 0.999 || gender f1 0.998
# Epoch[5/50](150/242) || training loss -2.176 || training accuracy 99.81% || training f1_score 0.9976 || lr 4.437053125e-05
#           training each f1 || mask f1 0.9994 || age f1 0.9991 || gender f1 0.9983
# Epoch[5/50](200/242) || training loss -2.169 || training accuracy 99.62% || training f1_score 0.9975 || lr 4.437053125e-05
#           training each f1 || mask f1 0.9994 || age f1 0.9989 || gender f1 0.998
# Calculating validation results...
# [Val] acc : 92.54%, loss: -0.8144, f1: 0.8298 || best acc : 90.41%, best loss: -0.7537, best f1: 0.8313
# [Val] each f1 || mask f1 0.9958 || age f1 0.8399 || gender f1 0.9941
#
# Epoch[6/50](50/242) || training loss -2.176 || training accuracy 99.91% || training f1_score 0.9992 || lr 3.77149515625e-05
#           training each f1 || mask f1 0.9988 || age f1  1.0 || gender f1 0.9997
# Epoch[6/50](100/242) || training loss -2.194 || training accuracy 99.72% || training f1_score 0.9973 || lr 3.77149515625e-05
#           training each f1 || mask f1 0.9992 || age f1 0.9999 || gender f1 0.9987
# Epoch[6/50](150/242) || training loss -2.182 || training accuracy 99.78% || training f1_score 0.9986 || lr 3.77149515625e-05
#           training each f1 || mask f1 0.9992 || age f1 0.9999 || gender f1 0.9986
# Epoch[6/50](200/242) || training loss -2.18 || training accuracy 99.66% || training f1_score 0.9971 || lr 3.77149515625e-05
#           training each f1 || mask f1 0.9993 || age f1 0.9999 || gender f1 0.9981
# Calculating validation results...
# [Val] acc : 91.40%, loss: -0.7656, f1: 0.826 || best acc : 90.41%, best loss: -0.7537, best f1: 0.8313
# [Val] each f1 || mask f1 0.995 || age f1 0.8387 || gender f1 0.992
#
# Epoch[7/50](50/242) || training loss -2.182 || training accuracy 99.91% || training f1_score 0.9997 || lr 3.2057708828124995e-05
#           training each f1 || mask f1  1.0 || age f1  1.0 || gender f1 0.999
# Epoch[7/50](100/242) || training loss -2.187 || training accuracy 99.94% || training f1_score 0.9994 || lr 3.2057708828124995e-05
#           training each f1 || mask f1 0.9998 || age f1  1.0 || gender f1 0.9993
# Epoch[7/50](150/242) || training loss -2.193 || training accuracy 99.94% || training f1_score 0.9993 || lr 3.2057708828124995e-05
#           training each f1 || mask f1 0.9999 || age f1  1.0 || gender f1 0.9993
# Epoch[7/50](200/242) || training loss -2.189 || training accuracy 99.81% || training f1_score 0.9985 || lr 3.2057708828124995e-05
#           training each f1 || mask f1 0.9994 || age f1  1.0 || gender f1 0.9993
# Calculating validation results...
# [Val] acc : 92.04%, loss: -0.7817, f1: 0.822 || best acc : 90.41%, best loss: -0.7537, best f1: 0.8313
# [Val] each f1 || mask f1 0.9942 || age f1 0.8369 || gender f1 0.9917
#
# Epoch[8/50](50/242) || training loss -2.186 || training accuracy 99.94% || training f1_score 0.9996 || lr 2.7249052503906245e-05
#           training each f1 || mask f1 0.9996 || age f1 0.9998 || gender f1  1.0
# Epoch[8/50](100/242) || training loss -2.189 || training accuracy 99.84% || training f1_score 0.9984 || lr 2.7249052503906245e-05
#           training each f1 || mask f1 0.9996 || age f1 0.9999 || gender f1 0.9993
# Epoch[8/50](150/242) || training loss -2.202 || training accuracy 99.97% || training f1_score 0.9999 || lr 2.7249052503906245e-05
#           training each f1 || mask f1 0.9997 || age f1 0.9999 || gender f1 0.9995
# Epoch[8/50](200/242) || training loss -2.207 || training accuracy 99.91% || training f1_score 0.9991 || lr 2.7249052503906245e-05
#           training each f1 || mask f1 0.9995 || age f1 0.9999 || gender f1 0.9996
# Calculating validation results...
# New best model for val f1 : 0.8328! saving the best model..
# [Val] acc : 92.48%, loss: -0.7671, f1: 0.8328 || best acc : 92.48%, best loss: -0.7671, best f1: 0.8328
# [Val] each f1 || mask f1 0.9954 || age f1 0.8407 || gender f1 0.9938
#
# Epoch[9/50](50/242) || training loss -2.197 || training accuracy 99.88% || training f1_score 0.998 || lr 2.3161694628320308e-05
#           training each f1 || mask f1 0.9996 || age f1  1.0 || gender f1 0.999
# Epoch[9/50](100/242) || training loss -2.191 || training accuracy 99.88% || training f1_score 0.9974 || lr 2.3161694628320308e-05
#           training each f1 || mask f1 0.9998 || age f1 0.9992 || gender f1 0.9992
# Epoch[9/50](150/242) || training loss -2.193 || training accuracy 99.97% || training f1_score 0.9994 || lr 2.3161694628320308e-05
#           training each f1 || mask f1 0.9999 || age f1 0.9994 || gender f1 0.9993
# Epoch[9/50](200/242) || training loss -2.193 || training accuracy 99.88% || training f1_score 0.999 || lr 2.3161694628320308e-05
#           training each f1 || mask f1 0.9996 || age f1 0.9996 || gender f1 0.9994
# Calculating validation results...
# [Val] acc : 91.90%, loss: -0.7545, f1: 0.819 || best acc : 92.48%, best loss: -0.7671, best f1: 0.8328
# [Val] each f1 || mask f1 0.9962 || age f1 0.8374 || gender f1 0.992
#
# Epoch[10/50](50/242) || training loss -2.197 || training accuracy 99.91% || training f1_score 0.9997 || lr 1.9687440434072263e-05
#           training each f1 || mask f1  1.0 || age f1  1.0 || gender f1 0.999
# Epoch[10/50](100/242) || training loss -2.199 || training accuracy 99.97% || training f1_score 0.9999 || lr 1.9687440434072263e-05
#           training each f1 || mask f1  1.0 || age f1 0.9999 || gender f1 0.9995
# Epoch[10/50](150/242) || training loss -2.193 || training accuracy 100.00% || training f1_score  1.0 || lr 1.9687440434072263e-05
#           training each f1 || mask f1  1.0 || age f1 0.9999 || gender f1 0.9997
# Epoch[10/50](200/242) || training loss -2.194 || training accuracy 100.00% || training f1_score  1.0 || lr 1.9687440434072263e-05
#           training each f1 || mask f1  1.0 || age f1 0.9999 || gender f1 0.9998
# Calculating validation results...
# [Val] acc : 91.90%, loss: -0.7433, f1: 0.8144 || best acc : 92.48%, best loss: -0.7671, best f1: 0.8328
# [Val] each f1 || mask f1 0.995 || age f1 0.8291 || gender f1 0.9944
#
# Epoch[11/50](50/242) || training loss -2.202 || training accuracy 99.94% || training f1_score 0.9994 || lr 1.673432436896142e-05
#           training each f1 || mask f1 0.9996 || age f1  1.0 || gender f1 0.9997
# Epoch[11/50](100/242) || training loss -2.197 || training accuracy 99.97% || training f1_score 0.9997 || lr 1.673432436896142e-05
#           training each f1 || mask f1 0.9996 || age f1  1.0 || gender f1 0.9998
# Epoch[11/50](150/242) || training loss -2.205 || training accuracy 99.94% || training f1_score 0.9984 || lr 1.673432436896142e-05
#           training each f1 || mask f1 0.9996 || age f1  1.0 || gender f1 0.9998
# Epoch[11/50](200/242) || training loss -2.204 || training accuracy 99.91% || training f1_score 0.9992 || lr 1.673432436896142e-05
#           training each f1 || mask f1 0.9997 || age f1  1.0 || gender f1 0.9996
# Calculating validation results...
# [Val] acc : 91.66%, loss: -0.7276, f1: 0.8277 || best acc : 92.48%, best loss: -0.7671, best f1: 0.8328
# [Val] each f1 || mask f1 0.9954 || age f1 0.8366 || gender f1 0.9923
#
# Epoch[12/50](50/242) || training loss -2.197 || training accuracy 99.97% || training f1_score 0.9997 || lr 1.4224175713617208e-05
#           training each f1 || mask f1 0.9996 || age f1  1.0 || gender f1  1.0
# Epoch[12/50](100/242) || training loss -2.198 || training accuracy 99.97% || training f1_score 0.9995 || lr 1.4224175713617208e-05
#           training each f1 || mask f1 0.9996 || age f1  1.0 || gender f1  1.0
# Epoch[12/50](150/242) || training loss -2.208 || training accuracy 99.97% || training f1_score 0.9996 || lr 1.4224175713617208e-05
#           training each f1 || mask f1 0.9996 || age f1  1.0 || gender f1  1.0
# Epoch[12/50](200/242) || training loss -2.202 || training accuracy 99.97% || training f1_score 0.9999 || lr 1.4224175713617208e-05
#           training each f1 || mask f1 0.9997 || age f1  1.0 || gender f1 0.9999
# Calculating validation results...
# [Val] acc : 91.57%, loss: -0.7183, f1: 0.8301 || best acc : 92.48%, best loss: -0.7671, best f1: 0.8328
# [Val] each f1 || mask f1 0.9954 || age f1 0.8347 || gender f1 0.9941
#
# Epoch[13/50](50/242) || training loss -2.2 || training accuracy 100.00% || training f1_score  1.0 || lr 1.2090549356574626e-05
#           training each f1 || mask f1  1.0 || age f1  1.0 || gender f1  1.0
# Epoch[13/50](100/242) || training loss -2.2 || training accuracy 99.97% || training f1_score 0.9976 || lr 1.2090549356574626e-05
#           training each f1 || mask f1  1.0 || age f1 0.9996 || gender f1  1.0
# Epoch[13/50](150/242) || training loss -2.196 || training accuracy 100.00% || training f1_score  1.0 || lr 1.2090549356574626e-05
#           training each f1 || mask f1  1.0 || age f1 0.9997 || gender f1  1.0
# Epoch[13/50](200/242) || training loss -2.205 || training accuracy 99.97% || training f1_score 0.9998 || lr 1.2090549356574626e-05
#           training each f1 || mask f1 0.9999 || age f1 0.9998 || gender f1  1.0
# Calculating validation results...
# [Val] acc : 91.63%, loss: -0.7121, f1: 0.8317 || best acc : 92.48%, best loss: -0.7671, best f1: 0.8328
# [Val] each f1 || mask f1 0.9958 || age f1 0.8403 || gender f1 0.9929
#
# Epoch[14/50](50/242) || training loss -2.197 || training accuracy 99.97% || training f1_score 0.9996 || lr 1.0276966953088432e-05
#           training each f1 || mask f1 0.9996 || age f1  1.0 || gender f1  1.0
# Epoch[14/50](100/242) || training loss -2.208 || training accuracy 100.00% || training f1_score  1.0 || lr 1.0276966953088432e-05
#           training each f1 || mask f1 0.9998 || age f1  1.0 || gender f1  1.0
# Epoch[14/50](150/242) || training loss -2.203 || training accuracy 100.00% || training f1_score  1.0 || lr 1.0276966953088432e-05
#           training each f1 || mask f1 0.9999 || age f1  1.0 || gender f1  1.0
# Epoch[14/50](200/242) || training loss -2.21 || training accuracy 99.91% || training f1_score 0.9993 || lr 1.0276966953088432e-05
#           training each f1 || mask f1 0.9999 || age f1  1.0 || gender f1 0.9998
# Calculating validation results...
# [Val] acc : 91.90%, loss: -0.7359, f1: 0.8291 || best acc : 92.48%, best loss: -0.7671, best f1: 0.8328
# [Val] each f1 || mask f1 0.9958 || age f1 0.8419 || gender f1 0.9932
#
# Epoch[15/50](50/242) || training loss -2.203 || training accuracy 99.97% || training f1_score 0.9997 || lr 8.735421910125167e-06
#           training each f1 || mask f1 0.9996 || age f1  1.0 || gender f1  1.0
# Epoch[15/50](100/242) || training loss -2.203 || training accuracy 100.00% || training f1_score  1.0 || lr 8.735421910125167e-06
#           training each f1 || mask f1 0.9998 || age f1  1.0 || gender f1  1.0
# Epoch[15/50](150/242) || training loss -2.204 || training accuracy 100.00% || training f1_score  1.0 || lr 8.735421910125167e-06
#           training each f1 || mask f1 0.9999 || age f1  1.0 || gender f1  1.0
# Epoch[15/50](200/242) || training loss -2.208 || training accuracy 100.00% || training f1_score  1.0 || lr 8.735421910125167e-06
#           training each f1 || mask f1 0.9999 || age f1  1.0 || gender f1  1.0
# Calculating validation results...
# [Val] acc : 92.01%, loss: -0.7353, f1: 0.8295 || best acc : 92.48%, best loss: -0.7671, best f1: 0.8328
# [Val] each f1 || mask f1 0.9954 || age f1 0.8391 || gender f1 0.9938
#
# Epoch[16/50](50/242) || training loss -2.211 || training accuracy 99.88% || training f1_score 0.9995 || lr 7.425108623606392e-06
#           training each f1 || mask f1  1.0 || age f1 0.9996 || gender f1 0.9993
# Epoch[16/50](100/242) || training loss -2.209 || training accuracy 100.00% || training f1_score  1.0 || lr 7.425108623606392e-06
#           training each f1 || mask f1  1.0 || age f1 0.9998 || gender f1 0.9997
# Epoch[16/50](150/242) || training loss -2.207 || training accuracy 100.00% || training f1_score  1.0 || lr 7.425108623606392e-06
#           training each f1 || mask f1  1.0 || age f1 0.9999 || gender f1 0.9998
# Epoch[16/50](200/242) || training loss -2.208 || training accuracy 100.00% || training f1_score  1.0 || lr 7.425108623606392e-06
#           training each f1 || mask f1  1.0 || age f1 0.9999 || gender f1 0.9998
# Calculating validation results...
# [Val] acc : 92.13%, loss: -0.7514, f1: 0.8291 || best acc : 92.48%, best loss: -0.7671, best f1: 0.8328
# [Val] each f1 || mask f1 0.9958 || age f1 0.84 || gender f1 0.9941
#
# Epoch[17/50](50/242) || training loss -2.208 || training accuracy 100.00% || training f1_score  1.0 || lr 6.3113423300654325e-06
#           training each f1 || mask f1  1.0 || age f1  1.0 || gender f1  1.0
# Epoch[17/50](100/242) || training loss -2.202 || training accuracy 100.00% || training f1_score  1.0 || lr 6.3113423300654325e-06
#           training each f1 || mask f1  1.0 || age f1  1.0 || gender f1  1.0
# Epoch[17/50](150/242) || training loss -2.208 || training accuracy 100.00% || training f1_score  1.0 || lr 6.3113423300654325e-06
#           training each f1 || mask f1  1.0 || age f1  1.0 || gender f1  1.0
# Epoch[17/50](200/242) || training loss -2.207 || training accuracy 99.94% || training f1_score 0.9987 || lr 6.3113423300654325e-06
#           training each f1 || mask f1  1.0 || age f1  1.0 || gender f1 0.9998
# Calculating validation results...
# [Val] acc : 92.13%, loss: -0.7384, f1: 0.8326 || best acc : 92.48%, best loss: -0.7671, best f1: 0.8328
# [Val] each f1 || mask f1 0.9958 || age f1 0.8409 || gender f1 0.9941
#
# Epoch[18/50](50/242) || training loss -2.206 || training accuracy 100.00% || training f1_score  1.0 || lr 5.3646409805556175e-06
#           training each f1 || mask f1  1.0 || age f1  1.0 || gender f1  1.0
# Epoch[18/50](100/242) || training loss -2.206 || training accuracy 99.97% || training f1_score 0.9999 || lr 5.3646409805556175e-06
#           training each f1 || mask f1  1.0 || age f1  1.0 || gender f1 0.9998
# Epoch[18/50](150/242) || training loss -2.207 || training accuracy 99.97% || training f1_score 0.9999 || lr 5.3646409805556175e-06
#           training each f1 || mask f1  1.0 || age f1  1.0 || gender f1 0.9998
# Epoch[18/50](200/242) || training loss -2.209 || training accuracy 100.00% || training f1_score  1.0 || lr 5.3646409805556175e-06
#           training each f1 || mask f1  1.0 || age f1  1.0 || gender f1 0.9998
# Calculating validation results...
# [Val] acc : 91.87%, loss: -0.728, f1: 0.822 || best acc : 92.48%, best loss: -0.7671, best f1: 0.8328
# [Val] each f1 || mask f1 0.9962 || age f1 0.831 || gender f1 0.9954
#
# Epoch[19/50](50/242) || training loss -2.216 || training accuracy 99.97% || training f1_score 0.9994 || lr 4.559944833472275e-06
#           training each f1 || mask f1  1.0 || age f1  1.0 || gender f1 0.9997
# Epoch[19/50](100/242) || training loss -2.204 || training accuracy 100.00% || training f1_score  1.0 || lr 4.559944833472275e-06
#           training each f1 || mask f1  1.0 || age f1  1.0 || gender f1 0.9998
# Epoch[19/50](150/242) || training loss -2.208 || training accuracy 100.00% || training f1_score  1.0 || lr 4.559944833472275e-06
#           training each f1 || mask f1  1.0 || age f1  1.0 || gender f1 0.9999
# Epoch[19/50](200/242) || training loss -2.215 || training accuracy 99.94% || training f1_score 0.999 || lr 4.559944833472275e-06
#           training each f1 || mask f1  1.0 || age f1  1.0 || gender f1 0.9998
# Calculating validation results...
# [Val] acc : 92.07%, loss: -0.7293, f1: 0.8287 || best acc : 92.48%, best loss: -0.7671, best f1: 0.8328
# [Val] each f1 || mask f1 0.995 || age f1 0.8356 || gender f1 0.9948
#
# Epoch[20/50](50/242) || training loss -2.205 || training accuracy 99.97% || training f1_score 0.9995 || lr 3.875953108451433e-06
#           training each f1 || mask f1  1.0 || age f1  1.0 || gender f1 0.9997
# Epoch[20/50](100/242) || training loss -2.206 || training accuracy 100.00% || training f1_score  1.0 || lr 3.875953108451433e-06
#           training each f1 || mask f1  1.0 || age f1  1.0 || gender f1 0.9998
# Epoch[20/50](150/242) || training loss -2.205 || training accuracy 100.00% || training f1_score  1.0 || lr 3.875953108451433e-06
#           training each f1 || mask f1  1.0 || age f1  1.0 || gender f1 0.9999
# Epoch[20/50](200/242) || training loss -2.206 || training accuracy 100.00% || training f1_score  1.0 || lr 3.875953108451433e-06
#           training each f1 || mask f1  1.0 || age f1  1.0 || gender f1 0.9999
# Calculating validation results...
# [Val] acc : 92.10%, loss: -0.7295, f1: 0.8298 || best acc : 92.48%, best loss: -0.7671, best f1: 0.8328
# [Val] each f1 || mask f1 0.9962 || age f1 0.8365 || gender f1 0.9941
#
# Epoch[21/50](50/242) || training loss -2.202 || training accuracy 100.00% || training f1_score  1.0 || lr 3.2945601421837183e-06
#           training each f1 || mask f1  1.0 || age f1  1.0 || gender f1  1.0
# Epoch[21/50](100/242) || training loss -2.203 || training accuracy 99.97% || training f1_score 0.9995 || lr 3.2945601421837183e-06
#           training each f1 || mask f1 0.9998 || age f1  1.0 || gender f1  1.0
# Epoch[21/50](150/242) || training loss -2.205 || training accuracy 100.00% || training f1_score  1.0 || lr 3.2945601421837183e-06
#           training each f1 || mask f1 0.9999 || age f1  1.0 || gender f1  1.0
# Epoch[21/50](200/242) || training loss -2.213 || training accuracy 100.00% || training f1_score  1.0 || lr 3.2945601421837183e-06
#           training each f1 || mask f1 0.9999 || age f1  1.0 || gender f1  1.0
# Calculating validation results...
# [Val] acc : 92.39%, loss: -0.7283, f1: 0.8311 || best acc : 92.48%, best loss: -0.7671, best f1: 0.8328
# [Val] each f1 || mask f1 0.9945 || age f1 0.8435 || gender f1 0.9944
#
# Epoch[22/50](50/242) || training loss -2.204 || training accuracy 99.97% || training f1_score 0.997 || lr 2.8003761208561607e-06
#           training each f1 || mask f1 0.9996 || age f1  1.0 || gender f1  1.0
# Epoch[22/50](100/242) || training loss -2.212 || training accuracy 100.00% || training f1_score  1.0 || lr 2.8003761208561607e-06
#           training each f1 || mask f1 0.9998 || age f1  1.0 || gender f1  1.0
# Epoch[22/50](150/242) || training loss -2.21 || training accuracy 100.00% || training f1_score  1.0 || lr 2.8003761208561607e-06
#           training each f1 || mask f1 0.9999 || age f1  1.0 || gender f1  1.0
# Epoch[22/50](200/242) || training loss -2.217 || training accuracy 99.97% || training f1_score 0.9999 || lr 2.8003761208561607e-06
#           training each f1 || mask f1 0.9999 || age f1  1.0 || gender f1 0.9999
# Calculating validation results...
# [Val] acc : 92.33%, loss: -0.7242, f1: 0.8286 || best acc : 92.48%, best loss: -0.7671, best f1: 0.8328
# [Val] each f1 || mask f1 0.9954 || age f1 0.8381 || gender f1 0.9948
#
# Epoch[23/50](50/242) || training loss -2.215 || training accuracy 100.00% || training f1_score  1.0 || lr 2.3803197027277364e-06
#           training each f1 || mask f1  1.0 || age f1  1.0 || gender f1  1.0
# Epoch[23/50](100/242) || training loss -2.221 || training accuracy 100.00% || training f1_score  1.0 || lr 2.3803197027277364e-06
#           training each f1 || mask f1  1.0 || age f1  1.0 || gender f1  1.0
# Epoch[23/50](150/242) || training loss -2.211 || training accuracy 100.00% || training f1_score  1.0 || lr 2.3803197027277364e-06
#           training each f1 || mask f1  1.0 || age f1  1.0 || gender f1  1.0
# Epoch[23/50](200/242) || training loss -2.211 || training accuracy 100.00% || training f1_score  1.0 || lr 2.3803197027277364e-06
#           training each f1 || mask f1  1.0 || age f1  1.0 || gender f1  1.0
# Calculating validation results...
# [Val] acc : 91.98%, loss: -0.7145, f1: 0.8258 || best acc : 92.48%, best loss: -0.7671, best f1: 0.8328
# [Val] each f1 || mask f1 0.9958 || age f1 0.836 || gender f1 0.9941
#
# Epoch[24/50](50/242) || training loss -2.212 || training accuracy 100.00% || training f1_score  1.0 || lr 2.0232717473185757e-06
#           training each f1 || mask f1  1.0 || age f1  1.0 || gender f1  1.0
# Epoch[24/50](100/242) || training loss -2.208 || training accuracy 100.00% || training f1_score  1.0 || lr 2.0232717473185757e-06
#           training each f1 || mask f1  1.0 || age f1  1.0 || gender f1  1.0
# Epoch[24/50](150/242) || training loss -2.217 || training accuracy 99.97% || training f1_score 0.9999 || lr 2.0232717473185757e-06
#           training each f1 || mask f1  1.0 || age f1  1.0 || gender f1 0.9999
# Epoch[24/50](200/242) || training loss -2.212 || training accuracy 99.94% || training f1_score 0.9992 || lr 2.0232717473185757e-06
#           training each f1 || mask f1 0.9996 || age f1  1.0 || gender f1 0.9999
# Calculating validation results...
# [Val] acc : 92.13%, loss: -0.7171, f1: 0.8318 || best acc : 92.48%, best loss: -0.7671, best f1: 0.8328
# [Val] each f1 || mask f1 0.9958 || age f1 0.8413 || gender f1 0.9944
#
# Epoch[25/50](50/242) || training loss -2.206 || training accuracy 100.00% || training f1_score  1.0 || lr 1.7197809852207893e-06
#           training each f1 || mask f1  1.0 || age f1  1.0 || gender f1  1.0
# Epoch[25/50](100/242) || training loss -2.218 || training accuracy 100.00% || training f1_score  1.0 || lr 1.7197809852207893e-06
#           training each f1 || mask f1  1.0 || age f1  1.0 || gender f1  1.0
# Epoch[25/50](150/242) || training loss -2.207 || training accuracy 100.00% || training f1_score  1.0 || lr 1.7197809852207893e-06
#           training each f1 || mask f1  1.0 || age f1  1.0 || gender f1  1.0
# Epoch[25/50](200/242) || training loss -2.219 || training accuracy 99.97% || training f1_score 0.9999 || lr 1.7197809852207893e-06
#           training each f1 || mask f1  1.0 || age f1  1.0 || gender f1 0.9999
# Calculating validation results...
# New best model for val f1 : 0.8328! saving the best model..
# [Val] acc : 92.39%, loss: -0.7177, f1: 0.8328 || best acc : 92.39%, best loss: -0.7177, best f1: 0.8328
# [Val] each f1 || mask f1 0.995 || age f1 0.8419 || gender f1 0.9948
#
# Epoch[26/50](50/242) || training loss -2.213 || training accuracy 100.00% || training f1_score  1.0 || lr 1.4618138374376709e-06
#           training each f1 || mask f1  1.0 || age f1  1.0 || gender f1  1.0
# Epoch[26/50](100/242) || training loss -2.201 || training accuracy 99.97% || training f1_score 0.9996 || lr 1.4618138374376709e-06
#           training each f1 || mask f1 0.9996 || age f1  1.0 || gender f1  1.0
# Epoch[26/50](150/242) || training loss -2.218 || training accuracy 100.00% || training f1_score  1.0 || lr 1.4618138374376709e-06
#           training each f1 || mask f1 0.9998 || age f1  1.0 || gender f1  1.0
# Epoch[26/50](200/242) || training loss -2.206 || training accuracy 100.00% || training f1_score  1.0 || lr 1.4618138374376709e-06
#           training each f1 || mask f1 0.9998 || age f1  1.0 || gender f1  1.0
# Calculating validation results...
# New best model for val f1 : 0.8367! saving the best model..
# [Val] acc : 92.33%, loss: -0.7122, f1: 0.8367 || best acc : 92.33%, best loss: -0.7122, best f1: 0.8367
# [Val] each f1 || mask f1 0.9962 || age f1 0.8449 || gender f1 0.9948
#
# Epoch[27/50](50/242) || training loss -2.217 || training accuracy 100.00% || training f1_score  1.0 || lr 1.2425417618220202e-06
#           training each f1 || mask f1  1.0 || age f1  1.0 || gender f1  1.0
# Epoch[27/50](100/242) || training loss -2.213 || training accuracy 99.97% || training f1_score 0.9999 || lr 1.2425417618220202e-06
#           training each f1 || mask f1  1.0 || age f1  1.0 || gender f1 0.9998
# Epoch[27/50](150/242) || training loss -2.214 || training accuracy 100.00% || training f1_score  1.0 || lr 1.2425417618220202e-06
#           training each f1 || mask f1  1.0 || age f1  1.0 || gender f1 0.9999
# Epoch[27/50](200/242) || training loss -2.212 || training accuracy 100.00% || training f1_score  1.0 || lr 1.2425417618220202e-06
#           training each f1 || mask f1  1.0 || age f1  1.0 || gender f1 0.9999
# Calculating validation results...
# [Val] acc : 92.36%, loss: -0.7225, f1: 0.8327 || best acc : 92.33%, best loss: -0.7122, best f1: 0.8367
# [Val] each f1 || mask f1 0.995 || age f1 0.8425 || gender f1 0.9938
#
# Epoch[28/50](50/242) || training loss -2.207 || training accuracy 100.00% || training f1_score  1.0 || lr 1.0561604975487172e-06
#           training each f1 || mask f1  1.0 || age f1  1.0 || gender f1  1.0
# Epoch[28/50](100/242) || training loss -2.206 || training accuracy 100.00% || training f1_score  1.0 || lr 1.0561604975487172e-06
#           training each f1 || mask f1  1.0 || age f1  1.0 || gender f1  1.0
# Epoch[28/50](150/242) || training loss -2.211 || training accuracy 100.00% || training f1_score  1.0 || lr 1.0561604975487172e-06
#           training each f1 || mask f1  1.0 || age f1  1.0 || gender f1  1.0
# Epoch[28/50](200/242) || training loss -2.211 || training accuracy 100.00% || training f1_score  1.0 || lr 1.0561604975487172e-06
#           training each f1 || mask f1  1.0 || age f1  1.0 || gender f1  1.0
# Calculating validation results...
# [Val] acc : 92.13%, loss: -0.7128, f1: 0.8315 || best acc : 92.33%, best loss: -0.7122, best f1: 0.8367
# [Val] each f1 || mask f1 0.9958 || age f1 0.8392 || gender f1 0.9947
#
# Epoch[29/50](50/242) || training loss -2.213 || training accuracy 100.00% || training f1_score  1.0 || lr 8.977364229164096e-07
#           training each f1 || mask f1  1.0 || age f1  1.0 || gender f1  1.0
# Epoch[29/50](100/242) || training loss -2.21 || training accuracy 100.00% || training f1_score  1.0 || lr 8.977364229164096e-07
#           training each f1 || mask f1  1.0 || age f1  1.0 || gender f1  1.0
# Epoch[29/50](150/242) || training loss -2.214 || training accuracy 100.00% || training f1_score  1.0 || lr 8.977364229164096e-07
#           training each f1 || mask f1  1.0 || age f1  1.0 || gender f1  1.0
# Epoch[29/50](200/242) || training loss -2.213 || training accuracy 100.00% || training f1_score  1.0 || lr 8.977364229164096e-07
#           training each f1 || mask f1  1.0 || age f1  1.0 || gender f1  1.0
# Calculating validation results...
# New best model for val f1 : 0.8373! saving the best model..
# [Val] acc : 92.42%, loss: -0.7214, f1: 0.8373 || best acc : 92.42%, best loss: -0.7214, best f1: 0.8373
# [Val] each f1 || mask f1 0.9954 || age f1 0.8447 || gender f1 0.9951
#
# Epoch[30/50](50/242) || training loss -2.201 || training accuracy 100.00% || training f1_score  1.0 || lr 7.630759594789481e-07
#           training each f1 || mask f1  1.0 || age f1  1.0 || gender f1  1.0
# Epoch[30/50](100/242) || training loss -2.219 || training accuracy 100.00% || training f1_score  1.0 || lr 7.630759594789481e-07
#           training each f1 || mask f1  1.0 || age f1  1.0 || gender f1  1.0
# Epoch[30/50](150/242) || training loss -2.207 || training accuracy 100.00% || training f1_score  1.0 || lr 7.630759594789481e-07
#           training each f1 || mask f1  1.0 || age f1  1.0 || gender f1  1.0
# Epoch[30/50](200/242) || training loss -2.204 || training accuracy 100.00% || training f1_score  1.0 || lr 7.630759594789481e-07
#           training each f1 || mask f1  1.0 || age f1  1.0 || gender f1  1.0
# Calculating validation results...
# [Val] acc : 92.19%, loss: -0.7129, f1: 0.8333 || best acc : 92.42%, best loss: -0.7214, best f1: 0.8373
# [Val] each f1 || mask f1 0.9962 || age f1 0.8417 || gender f1 0.9951
#
# Epoch[31/50](50/242) || training loss -2.224 || training accuracy 99.97% || training f1_score 0.9999 || lr 6.486145655571059e-07
#           training each f1 || mask f1  1.0 || age f1  1.0 || gender f1 0.9997
# Epoch[31/50](100/242) || training loss -2.212 || training accuracy 100.00% || training f1_score  1.0 || lr 6.486145655571059e-07
#           training each f1 || mask f1  1.0 || age f1  1.0 || gender f1 0.9998
# Epoch[31/50](150/242) || training loss -2.21 || training accuracy 100.00% || training f1_score  1.0 || lr 6.486145655571059e-07
#           training each f1 || mask f1  1.0 || age f1  1.0 || gender f1 0.9999
# Epoch[31/50](200/242) || training loss -2.211 || training accuracy 99.97% || training f1_score 0.9999 || lr 6.486145655571059e-07
#           training each f1 || mask f1  1.0 || age f1  1.0 || gender f1 0.9998
# Calculating validation results...
# [Val] acc : 92.42%, loss: -0.7198, f1: 0.8347 || best acc : 92.42%, best loss: -0.7214, best f1: 0.8373
# [Val] each f1 || mask f1 0.9958 || age f1 0.8447 || gender f1 0.9948
#
# Epoch[32/50](50/242) || training loss -2.215 || training accuracy 100.00% || training f1_score  1.0 || lr 5.5132238072354e-07
#           training each f1 || mask f1  1.0 || age f1  1.0 || gender f1  1.0
# Epoch[32/50](100/242) || training loss -2.204 || training accuracy 100.00% || training f1_score  1.0 || lr 5.5132238072354e-07
#           training each f1 || mask f1  1.0 || age f1  1.0 || gender f1  1.0
# Epoch[32/50](150/242) || training loss -2.209 || training accuracy 100.00% || training f1_score  1.0 || lr 5.5132238072354e-07
#           training each f1 || mask f1  1.0 || age f1  1.0 || gender f1  1.0
# Epoch[32/50](200/242) || training loss -2.214 || training accuracy 100.00% || training f1_score  1.0 || lr 5.5132238072354e-07
#           training each f1 || mask f1  1.0 || age f1  1.0 || gender f1  1.0
# Calculating validation results...
# [Val] acc : 92.54%, loss: -0.7263, f1: 0.8367 || best acc : 92.42%, best loss: -0.7214, best f1: 0.8373
# [Val] each f1 || mask f1 0.9958 || age f1 0.8465 || gender f1 0.9947
#
# Epoch[33/50](50/242) || training loss -2.21 || training accuracy 100.00% || training f1_score  1.0 || lr 4.68624023615009e-07
#           training each f1 || mask f1  1.0 || age f1  1.0 || gender f1  1.0
# Epoch[33/50](100/242) || training loss -2.201 || training accuracy 100.00% || training f1_score  1.0 || lr 4.68624023615009e-07
#           training each f1 || mask f1  1.0 || age f1  1.0 || gender f1  1.0
# Epoch[33/50](150/242) || training loss -2.212 || training accuracy 100.00% || training f1_score  1.0 || lr 4.68624023615009e-07
#           training each f1 || mask f1  1.0 || age f1  1.0 || gender f1  1.0
# Epoch[33/50](200/242) || training loss -2.209 || training accuracy 100.00% || training f1_score  1.0 || lr 4.68624023615009e-07
#           training each f1 || mask f1  1.0 || age f1  1.0 || gender f1  1.0
# Calculating validation results...
# [Val] acc : 92.45%, loss: -0.7215, f1: 0.8365 || best acc : 92.42%, best loss: -0.7214, best f1: 0.8373
# [Val] each f1 || mask f1 0.9958 || age f1 0.8466 || gender f1 0.9941
#
# Epoch[34/50](50/242) || training loss -2.213 || training accuracy 100.00% || training f1_score  1.0 || lr 3.983304200727576e-07
#           training each f1 || mask f1  1.0 || age f1  1.0 || gender f1  1.0
# Epoch[34/50](100/242) || training loss -2.212 || training accuracy 100.00% || training f1_score  1.0 || lr 3.983304200727576e-07
#           training each f1 || mask f1  1.0 || age f1  1.0 || gender f1  1.0
# Epoch[34/50](150/242) || training loss -2.209 || training accuracy 100.00% || training f1_score  1.0 || lr 3.983304200727576e-07
#           training each f1 || mask f1  1.0 || age f1  1.0 || gender f1  1.0
# Epoch[34/50](200/242) || training loss -2.215 || training accuracy 100.00% || training f1_score  1.0 || lr 3.983304200727576e-07
#           training each f1 || mask f1  1.0 || age f1  1.0 || gender f1  1.0
# Calculating validation results...
# [Val] acc : 92.27%, loss: -0.7215, f1: 0.8356 || best acc : 92.42%, best loss: -0.7214, best f1: 0.8373
# [Val] each f1 || mask f1 0.995 || age f1 0.8435 || gender f1 0.9948
#
# Epoch[35/50](50/242) || training loss -2.218 || training accuracy 100.00% || training f1_score  1.0 || lr 3.38580857061844e-07
#           training each f1 || mask f1  1.0 || age f1  1.0 || gender f1  1.0
# Epoch[35/50](100/242) || training loss -2.212 || training accuracy 100.00% || training f1_score  1.0 || lr 3.38580857061844e-07
#           training each f1 || mask f1  1.0 || age f1  1.0 || gender f1  1.0
# Epoch[35/50](150/242) || training loss -2.217 || training accuracy 100.00% || training f1_score  1.0 || lr 3.38580857061844e-07
#           training each f1 || mask f1  1.0 || age f1  1.0 || gender f1  1.0
# Epoch[35/50](200/242) || training loss -2.216 || training accuracy 100.00% || training f1_score  1.0 || lr 3.38580857061844e-07
#           training each f1 || mask f1  1.0 || age f1  1.0 || gender f1  1.0
# Calculating validation results...
# [Val] acc : 92.57%, loss: -0.7212, f1: 0.8338 || best acc : 92.42%, best loss: -0.7214, best f1: 0.8373
# [Val] each f1 || mask f1 0.9962 || age f1 0.8433 || gender f1 0.9951
#
# Epoch[36/50](50/242) || training loss -2.215 || training accuracy 100.00% || training f1_score  1.0 || lr 2.877937285025674e-07
#           training each f1 || mask f1  1.0 || age f1  1.0 || gender f1  1.0
# Epoch[36/50](100/242) || training loss -2.214 || training accuracy 100.00% || training f1_score  1.0 || lr 2.877937285025674e-07
#           training each f1 || mask f1  1.0 || age f1  1.0 || gender f1  1.0
# Epoch[36/50](150/242) || training loss -2.212 || training accuracy 100.00% || training f1_score  1.0 || lr 2.877937285025674e-07
#           training each f1 || mask f1  1.0 || age f1  1.0 || gender f1  1.0
# Epoch[36/50](200/242) || training loss -2.208 || training accuracy 99.97% || training f1_score 0.9994 || lr 2.877937285025674e-07
#           training each f1 || mask f1  1.0 || age f1  1.0 || gender f1 0.9999
# Calculating validation results...
# [Val] acc : 92.07%, loss: -0.7103, f1: 0.8313 || best acc : 92.42%, best loss: -0.7214, best f1: 0.8373
# [Val] each f1 || mask f1 0.9958 || age f1 0.8403 || gender f1 0.9947
#
# Epoch[37/50](50/242) || training loss -2.209 || training accuracy 100.00% || training f1_score  1.0 || lr 2.4462466922718226e-07
#           training each f1 || mask f1  1.0 || age f1  1.0 || gender f1  1.0
# Epoch[37/50](100/242) || training loss -2.205 || training accuracy 100.00% || training f1_score  1.0 || lr 2.4462466922718226e-07
#           training each f1 || mask f1  1.0 || age f1  1.0 || gender f1  1.0
# Epoch[37/50](150/242) || training loss -2.216 || training accuracy 100.00% || training f1_score  1.0 || lr 2.4462466922718226e-07
#           training each f1 || mask f1  1.0 || age f1  1.0 || gender f1  1.0
# Epoch[37/50](200/242) || training loss -2.208 || training accuracy 99.97% || training f1_score 0.9995 || lr 2.4462466922718226e-07
#           training each f1 || mask f1  1.0 || age f1  1.0 || gender f1 0.9999
# Calculating validation results...
# [Val] acc : 92.24%, loss: -0.7122, f1: 0.8341 || best acc : 92.42%, best loss: -0.7214, best f1: 0.8373
# [Val] each f1 || mask f1 0.9958 || age f1 0.8437 || gender f1 0.9944
#
# Epoch[38/50](50/242) || training loss -2.209 || training accuracy 100.00% || training f1_score  1.0 || lr 2.079309688431049e-07
#           training each f1 || mask f1  1.0 || age f1  1.0 || gender f1  1.0
# Epoch[38/50](100/242) || training loss -2.21 || training accuracy 100.00% || training f1_score  1.0 || lr 2.079309688431049e-07
#           training each f1 || mask f1  1.0 || age f1  1.0 || gender f1  1.0
# Epoch[38/50](150/242) || training loss -2.199 || training accuracy 100.00% || training f1_score  1.0 || lr 2.079309688431049e-07
#           training each f1 || mask f1  1.0 || age f1  1.0 || gender f1  1.0
# Epoch[38/50](200/242) || training loss -2.217 || training accuracy 100.00% || training f1_score  1.0 || lr 2.079309688431049e-07
#           training each f1 || mask f1  1.0 || age f1  1.0 || gender f1  1.0
# Calculating validation results...
# [Val] acc : 92.19%, loss: -0.7132, f1: 0.8317 || best acc : 92.42%, best loss: -0.7214, best f1: 0.8373
# [Val] each f1 || mask f1 0.9958 || age f1 0.8415 || gender f1 0.9947
#
# Epoch[39/50](50/242) || training loss -2.215 || training accuracy 100.00% || training f1_score  1.0 || lr 1.7674132351663916e-07
#           training each f1 || mask f1  1.0 || age f1  1.0 || gender f1  1.0
# Epoch[39/50](100/242) || training loss -2.208 || training accuracy 100.00% || training f1_score  1.0 || lr 1.7674132351663916e-07
#           training each f1 || mask f1  1.0 || age f1  1.0 || gender f1  1.0
# Epoch[39/50](150/242) || training loss -2.202 || training accuracy 100.00% || training f1_score  1.0 || lr 1.7674132351663916e-07
#           training each f1 || mask f1  1.0 || age f1  1.0 || gender f1  1.0
# Epoch[39/50](200/242) || training loss -2.209 || training accuracy 100.00% || training f1_score  1.0 || lr 1.7674132351663916e-07
#           training each f1 || mask f1  1.0 || age f1  1.0 || gender f1  1.0
# Calculating validation results...
# [Val] acc : 92.27%, loss: -0.7167, f1: 0.8338 || best acc : 92.42%, best loss: -0.7214, best f1: 0.8373
# [Val] each f1 || mask f1 0.9958 || age f1 0.8436 || gender f1 0.9944
#
# Epoch[40/50](50/242) || training loss -2.217 || training accuracy 100.00% || training f1_score  1.0 || lr 1.5023012498914328e-07
#           training each f1 || mask f1  1.0 || age f1  1.0 || gender f1  1.0
# Epoch[40/50](100/242) || training loss -2.215 || training accuracy 100.00% || training f1_score  1.0 || lr 1.5023012498914328e-07
#           training each f1 || mask f1  1.0 || age f1  1.0 || gender f1  1.0
# Epoch[40/50](150/242) || training loss -2.216 || training accuracy 100.00% || training f1_score  1.0 || lr 1.5023012498914328e-07
#           training each f1 || mask f1  1.0 || age f1  1.0 || gender f1  1.0
# Epoch[40/50](200/242) || training loss -2.214 || training accuracy 99.97% || training f1_score 0.9999 || lr 1.5023012498914328e-07
#           training each f1 || mask f1  1.0 || age f1  1.0 || gender f1 0.9999
# Calculating validation results...
# [Val] acc : 92.24%, loss: -0.7189, f1: 0.8335 || best acc : 92.42%, best loss: -0.7214, best f1: 0.8373
# [Val] each f1 || mask f1 0.9958 || age f1 0.841 || gender f1 0.9948
#
# Epoch[41/50](50/242) || training loss -2.212 || training accuracy 99.97% || training f1_score 0.9999 || lr 1.276956062407718e-07
#           training each f1 || mask f1  1.0 || age f1 0.9998 || gender f1  1.0
# Epoch[41/50](100/242) || training loss -2.218 || training accuracy 100.00% || training f1_score  1.0 || lr 1.276956062407718e-07
#           training each f1 || mask f1  1.0 || age f1 0.9999 || gender f1  1.0
# Epoch[41/50](150/242) || training loss -2.213 || training accuracy 100.00% || training f1_score  1.0 || lr 1.276956062407718e-07
#           training each f1 || mask f1  1.0 || age f1 0.9999 || gender f1  1.0
# Epoch[41/50](200/242) || training loss -2.211 || training accuracy 99.97% || training f1_score 0.9996 || lr 1.276956062407718e-07
#           training each f1 || mask f1 0.9999 || age f1 0.9999 || gender f1  1.0
# Calculating validation results...
# [Val] acc : 92.36%, loss: -0.718, f1: 0.8342 || best acc : 92.42%, best loss: -0.7214, best f1: 0.8373
# [Val] each f1 || mask f1 0.9958 || age f1 0.8424 || gender f1 0.9951
#
# Epoch[42/50](50/242) || training loss -2.218 || training accuracy 100.00% || training f1_score  1.0 || lr 1.0854126530465602e-07
#           training each f1 || mask f1  1.0 || age f1  1.0 || gender f1  1.0
# Epoch[42/50](100/242) || training loss -2.208 || training accuracy 99.97% || training f1_score 0.9999 || lr 1.0854126530465602e-07
#           training each f1 || mask f1  1.0 || age f1  1.0 || gender f1 0.9998
# Epoch[42/50](150/242) || training loss -2.202 || training accuracy 100.00% || training f1_score  1.0 || lr 1.0854126530465602e-07
#           training each f1 || mask f1  1.0 || age f1  1.0 || gender f1 0.9999
# Epoch[42/50](200/242) || training loss -2.216 || training accuracy 100.00% || training f1_score  1.0 || lr 1.0854126530465602e-07
#           training each f1 || mask f1  1.0 || age f1  1.0 || gender f1 0.9999
# Calculating validation results...
# [Val] acc : 92.45%, loss: -0.721, f1: 0.8355 || best acc : 92.42%, best loss: -0.7214, best f1: 0.8373
# [Val] each f1 || mask f1 0.9962 || age f1 0.8432 || gender f1 0.9948
#
# Epoch[43/50](50/242) || training loss -2.223 || training accuracy 100.00% || training f1_score  1.0 || lr 9.226007550895761e-08
#           training each f1 || mask f1  1.0 || age f1  1.0 || gender f1  1.0
# Epoch[43/50](100/242) || training loss -2.213 || training accuracy 100.00% || training f1_score  1.0 || lr 9.226007550895761e-08
#           training each f1 || mask f1  1.0 || age f1  1.0 || gender f1  1.0
# Epoch[43/50](150/242) || training loss -2.202 || training accuracy 100.00% || training f1_score  1.0 || lr 9.226007550895761e-08
#           training each f1 || mask f1  1.0 || age f1  1.0 || gender f1  1.0
# Epoch[43/50](200/242) || training loss -2.217 || training accuracy 100.00% || training f1_score  1.0 || lr 9.226007550895761e-08
#           training each f1 || mask f1  1.0 || age f1  1.0 || gender f1  1.0
# Calculating validation results...
# [Val] acc : 92.19%, loss: -0.7077, f1: 0.832 || best acc : 92.42%, best loss: -0.7214, best f1: 0.8373
# [Val] each f1 || mask f1 0.9962 || age f1 0.8402 || gender f1 0.9954
#
# Epoch[44/50](50/242) || training loss -2.213 || training accuracy 100.00% || training f1_score  1.0 || lr 7.842106418261397e-08
#           training each f1 || mask f1  1.0 || age f1  1.0 || gender f1  1.0
# Epoch[44/50](100/242) || training loss -2.206 || training accuracy 100.00% || training f1_score  1.0 || lr 7.842106418261397e-08
#           training each f1 || mask f1  1.0 || age f1  1.0 || gender f1  1.0
# Epoch[44/50](150/242) || training loss -2.214 || training accuracy 99.97% || training f1_score 0.9995 || lr 7.842106418261397e-08
#           training each f1 || mask f1  1.0 || age f1 0.9997 || gender f1  1.0
# Epoch[44/50](200/242) || training loss -2.209 || training accuracy 100.00% || training f1_score  1.0 || lr 7.842106418261397e-08
#           training each f1 || mask f1  1.0 || age f1 0.9998 || gender f1  1.0
# Calculating validation results...
# [Val] acc : 92.59%, loss: -0.7252, f1: 0.8334 || best acc : 92.42%, best loss: -0.7214, best f1: 0.8373
# [Val] each f1 || mask f1 0.9962 || age f1 0.843 || gender f1 0.9951
#
# Epoch[45/50](50/242) || training loss -2.213 || training accuracy 99.97% || training f1_score 0.9997 || lr 6.665790455522187e-08
#           training each f1 || mask f1 0.9996 || age f1  1.0 || gender f1  1.0
# Epoch[45/50](100/242) || training loss -2.214 || training accuracy 100.00% || training f1_score  1.0 || lr 6.665790455522187e-08
#           training each f1 || mask f1 0.9998 || age f1  1.0 || gender f1  1.0
# Epoch[45/50](150/242) || training loss -2.212 || training accuracy 100.00% || training f1_score  1.0 || lr 6.665790455522187e-08
#           training each f1 || mask f1 0.9999 || age f1  1.0 || gender f1  1.0
# Epoch[45/50](200/242) || training loss -2.208 || training accuracy 100.00% || training f1_score  1.0 || lr 6.665790455522187e-08
#           training each f1 || mask f1 0.9999 || age f1  1.0 || gender f1  1.0
# Calculating validation results...
# [Val] acc : 92.10%, loss: -0.7112, f1: 0.8319 || best acc : 92.42%, best loss: -0.7214, best f1: 0.8373
# [Val] each f1 || mask f1 0.995 || age f1 0.841 || gender f1 0.9948
#
# Epoch[46/50](50/242) || training loss -2.216 || training accuracy 100.00% || training f1_score  1.0 || lr 5.665921887193859e-08
#           training each f1 || mask f1  1.0 || age f1  1.0 || gender f1  1.0
# Epoch[46/50](100/242) || training loss -2.217 || training accuracy 100.00% || training f1_score  1.0 || lr 5.665921887193859e-08
#           training each f1 || mask f1  1.0 || age f1  1.0 || gender f1  1.0
# Epoch[46/50](150/242) || training loss -2.213 || training accuracy 100.00% || training f1_score  1.0 || lr 5.665921887193859e-08
#           training each f1 || mask f1  1.0 || age f1  1.0 || gender f1  1.0
# Epoch[46/50](200/242) || training loss -2.21 || training accuracy 100.00% || training f1_score  1.0 || lr 5.665921887193859e-08
#           training each f1 || mask f1  1.0 || age f1  1.0 || gender f1  1.0
# Calculating validation results...
# [Val] acc : 92.48%, loss: -0.7225, f1: 0.8317 || best acc : 92.42%, best loss: -0.7214, best f1: 0.8373
# [Val] each f1 || mask f1 0.9958 || age f1 0.8429 || gender f1 0.9947
#
# Epoch[47/50](50/242) || training loss -2.214 || training accuracy 100.00% || training f1_score  1.0 || lr 4.81603360411478e-08
#           training each f1 || mask f1  1.0 || age f1  1.0 || gender f1  1.0
# Epoch[47/50](100/242) || training loss -2.205 || training accuracy 100.00% || training f1_score  1.0 || lr 4.81603360411478e-08
#           training each f1 || mask f1  1.0 || age f1  1.0 || gender f1  1.0
# Epoch[47/50](150/242) || training loss -2.218 || training accuracy 100.00% || training f1_score  1.0 || lr 4.81603360411478e-08
#           training each f1 || mask f1  1.0 || age f1  1.0 || gender f1  1.0
# Epoch[47/50](200/242) || training loss -2.215 || training accuracy 100.00% || training f1_score  1.0 || lr 4.81603360411478e-08
#           training each f1 || mask f1  1.0 || age f1  1.0 || gender f1  1.0
# Calculating validation results...
# [Val] acc : 92.42%, loss: -0.7148, f1: 0.837 || best acc : 92.42%, best loss: -0.7214, best f1: 0.8373
# [Val] each f1 || mask f1 0.9962 || age f1 0.8453 || gender f1 0.9944
#
# Epoch[48/50](50/242) || training loss -2.209 || training accuracy 99.97% || training f1_score 0.9999 || lr 4.093628563497563e-08
#           training each f1 || mask f1  1.0 || age f1  1.0 || gender f1 0.9997
# Epoch[48/50](100/242) || training loss -2.215 || training accuracy 100.00% || training f1_score  1.0 || lr 4.093628563497563e-08
#           training each f1 || mask f1  1.0 || age f1  1.0 || gender f1 0.9998
# Epoch[48/50](150/242) || training loss -2.208 || training accuracy 100.00% || training f1_score  1.0 || lr 4.093628563497563e-08
#           training each f1 || mask f1  1.0 || age f1  1.0 || gender f1 0.9999
# Epoch[48/50](200/242) || training loss -2.205 || training accuracy 100.00% || training f1_score  1.0 || lr 4.093628563497563e-08
#           training each f1 || mask f1  1.0 || age f1  1.0 || gender f1 0.9999
# Calculating validation results...
# [Val] acc : 92.16%, loss: -0.7088, f1: 0.8324 || best acc : 92.42%, best loss: -0.7214, best f1: 0.8373
# [Val] each f1 || mask f1 0.9958 || age f1 0.842 || gender f1 0.9948
#
# Epoch[49/50](50/242) || training loss -2.212 || training accuracy 100.00% || training f1_score  1.0 || lr 3.479584278972928e-08
#           training each f1 || mask f1  1.0 || age f1  1.0 || gender f1  1.0
# Epoch[49/50](100/242) || training loss -2.21 || training accuracy 99.97% || training f1_score 0.9999 || lr 3.479584278972928e-08
#           training each f1 || mask f1  1.0 || age f1  1.0 || gender f1 0.9998
# Epoch[49/50](150/242) || training loss -2.211 || training accuracy 100.00% || training f1_score  1.0 || lr 3.479584278972928e-08
#           training each f1 || mask f1  1.0 || age f1  1.0 || gender f1 0.9999
# Epoch[49/50](200/242) || training loss -2.214 || training accuracy 100.00% || training f1_score  1.0 || lr 3.479584278972928e-08
#           training each f1 || mask f1  1.0 || age f1  1.0 || gender f1 0.9999
# Calculating validation results...
# [Val] acc : 92.22%, loss: -0.7142, f1: 0.8323 || best acc : 92.42%, best loss: -0.7214, best f1: 0.8373
# [Val] each f1 || mask f1 0.9954 || age f1 0.8414 || gender f1 0.9948
