# %%
import argparse
import glob
import json
import multiprocessing
import os
import random
import re
from pathlib import Path
from enum import Enum
from typing import Tuple, List
from collections import defaultdict
from sklearn.metrics import f1_score

import cv2
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import torch
import torch.nn as nn
import torch.nn.functional as F
from PIL import Image
from torch.optim import SGD, Adam, RMSprop
from torch.optim.lr_scheduler import StepLR, ReduceLROnPlateau, CosineAnnealingLR, ExponentialLR
from torch.utils.data import Dataset, Subset, random_split, DataLoader
from torch.utils.tensorboard import SummaryWriter
from torchvision import transforms, models
from albumentations import *
from albumentations.pytorch import ToTensorV2

from sklearn.model_selection import StratifiedKFold
from torchsampler import ImbalancedDatasetSampler

# %% [markdown]
# # config

# %%
# config
class Config():
    seed = 42
    
    # 데이터
#     data_dir = './face_input/train' #
    data_dir = './input/data/train'
    resize = [224, 224]
    val_ratio = 0.2
    
    # 학습 설정
    epochs = 50
    batch_size = 64
#     batch_size = 16
    valid_batch_size = 1000
    lr = 1e-4
    lr_decay_step = 5
    log_interval = 50
    patience = 10 # early stop
    n_splits = 5 # k - fold
    
    # 세이브 경로
    save_dir = './kfoldEnsemble_exp'
    

config = Config()

# %%
# 시드 고정 함수
def seed_everything(seed):
    torch.manual_seed(seed)
    torch.cuda.manual_seed(seed)
    torch.cuda.manual_seed_all(seed)  # if use multi-GPU
    torch.backends.cudnn.deterministic = True
    torch.backends.cudnn.benchmark = False
    np.random.seed(seed)
    random.seed(seed)

# %%
# 시드 고정
seed_everything(config.seed)

# %%
 # -- settings
use_cuda = torch.cuda.is_available()
device = torch.device("cuda" if use_cuda else "cpu")

# %% [markdown]
# # Dataset

# %%
# base setting
IMG_EXTENSIONS = [
    ".jpg", ".JPG", ".jpeg", ".JPEG", ".png",
    ".PNG", ".ppm", ".PPM", ".bmp", ".BMP",
]


def is_image_file(filename):
    return any(filename.endswith(extension) for extension in IMG_EXTENSIONS)

class MaskLabels(int, Enum):
    MASK = 0
    INCORRECT = 1
    NORMAL = 2

class GenderLabels(int, Enum):
    MALE = 0
    FEMALE = 1

    @classmethod
    def from_str(cls, value: str) -> int:
        value = value.lower()
        if value == "male":
            return cls.MALE
        elif value == "female":
            return cls.FEMALE
        else:
            raise ValueError(f"Gender value should be either 'male' or 'female', {value}")

class AgeLabels(int, Enum):
    YOUNG = 0
    MIDDLE = 1
    OLD = 2

    @classmethod
    def from_number(cls, value: str) -> int:
        try:
            value = int(value)
        except Exception:
            raise ValueError(f"Age value should be numeric, {value}")

        if value < 30:
            return cls.YOUNG
        elif value < 60:
            return cls.MIDDLE
        else:
            return cls.OLD

# %% [markdown]
# ### define transform (Augmentation)

# %%
mean=(0.548, 0.504, 0.479)
std=(0.237, 0.247, 0.246)
train_transform = Compose([
    CenterCrop(height=480, width=320),
    HorizontalFlip(p=0.5),
#     ShiftScaleRotate(p=0.5),
    HueSaturationValue(hue_shift_limit=0.2, sat_shift_limit=0.2, val_shift_limit=0.2, p=0.5),
    RandomScale(scale_limit=0.1, interpolation=cv2.INTER_LINEAR, p=0.5),
    RandomBrightnessContrast(brightness_limit=(-0.2, 0.2), contrast_limit=(-0.2, 0.2), p=0.5),
    GaussNoise(p=0.5),
    Resize(config.resize[0], config.resize[1], p=1.0, interpolation=cv2.INTER_LINEAR),
    Normalize(mean=mean, std=std, max_pixel_value=255.0, p=1.0),
    ToTensorV2(p=1.0),
], p=1.0)
val_transform = Compose([
    CenterCrop(height=480, width=320),
    Resize(config.resize[0], config.resize[1], p=1.0),
    Normalize(mean=mean, std=std, max_pixel_value=255.0, p=1.0),
    ToTensorV2(p=1.0),
], p=1.0)

# %% [markdown]
# ### define datasets

# %%
# base dataset class
class newBaseDataset(Dataset):

    def __init__(self, img_dir, indices, transform=None):
        """
        MaskBaseDataset을 initialize 합니다.

        Args:
            img_dir: 학습 이미지 폴더의 root directory 입니다.
            transform: Augmentation을 하는 함수입니다.
        """
        self.img_dir = img_dir
        self.transform = transform
        self.indices = indices
        self._file_names = {
            "mask1": MaskLabels.MASK,
            "mask2": MaskLabels.MASK,
            "mask3": MaskLabels.MASK,
            "mask4": MaskLabels.MASK,
            "mask5": MaskLabels.MASK,
            "incorrect_mask": MaskLabels.INCORRECT,
            "normal": MaskLabels.NORMAL
        }

        self.image_paths = []
        self.mask_labels = []
        self.gender_labels = []
        self.age_labels = []
        self.setup()

    def set_transform(self, transform):
        """
        transform 함수를 설정하는 함수입니다.
        """
        self.transform = transform

    def setup(self):
        """
        image의 경로와 각 이미지들의 label을 계산하여 저장해두는 함수입니다.
        """
        csv_path = os.path.join(self.img_dir, 'train.csv')
        csv_data = pd.read_csv(csv_path)
        
        csv_data = csv_data.loc[self.indices]
        csv_data_list = list(csv_data.values)
        cnt = 0
        for id, gender, _, age, path in csv_data_list:
            img_folder = os.path.join(self.img_dir, 'images', path)
            for file_name in os.listdir(img_folder):
                _file_name, ext = os.path.splitext(file_name)
                if _file_name not in self._file_names:  # "." 로 시작하는 파일 및 invalid 한 파일들은 무시합니다
                    continue
                    
                img_path = os.path.join(img_folder, file_name)  # (data_path, 000004_male_Asian_54, mask1.jpg)
                mask_label = self._file_names[_file_name]
                gender_label = GenderLabels.from_str(gender)
                age_label = AgeLabels.from_number(age)
                self.image_paths.append(img_path)
                self.mask_labels.append(mask_label)
                self.gender_labels.append(gender_label)
                self.age_labels.append(age_label)
                
    def __getitem__(self, index):
        """
        데이터를 불러오는 함수입니다. 
        데이터셋 class에 데이터 정보가 저장되어 있고, index를 통해 해당 위치에 있는 데이터 정보를 불러옵니다.
        
        Args:
            index: 불러올 데이터의 인덱스값입니다.
        """
        # 이미지를 불러옵니다.
        image_path = self.image_paths[index]
        image = cv2.imread(image_path)
        image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
#         image = Image.open(image_path)
        
        # 레이블을 불러옵니다.
        mask_label = self.mask_labels[index]
        gender_label = self.gender_labels[index]
        age_label = self.age_labels[index]
        multi_class_label = mask_label * 6 + gender_label * 3 + age_label
        
        # 이미지를 Augmentation 시킵니다.
        image_transform = self.transform(image=np.array(image))['image']
        return image_transform, (mask_label, gender_label, age_label, multi_class_label) # multi_class_label

    def __len__(self):
        return len(self.image_paths)
    
    
    # 이외 utils
#     @staticmethod
#     def split_data(val_ratio):
#         return val
#     @staticmethod
#     def encode_multi_class(mask_label, gender_label, age_label) -> int:
#         return mask_label * 6 + gender_label * 3 + age_label
    
#     @staticmethod
#     def decode_multi_class(multi_class_label) -> Tuple[MaskLabels, GenderLabels, AgeLabels]:
#         mask_label = (multi_class_label // 6) % 3
#         gender_label = (multi_class_label // 3) % 2
#         age_label = multi_class_label % 3
#         return mask_label, gender_label, age_label

# %%
# class Sampler(ImbalancedDatasetSampler):
#     def _get_labels(self, dataset):
#         return dataset.age_labels

# %%
def getDataloader(train_idx, valid_idx):
    train_dataset = newBaseDataset(img_dir = config.data_dir, indices = train_idx)
    val_dataset = newBaseDataset(img_dir = config.data_dir, indices = valid_idx)
    train_dataset.set_transform(train_transform)
    val_dataset.set_transform(val_transform)
    train_loader = DataLoader(
        train_dataset,
        batch_size=config.batch_size,
        num_workers=multiprocessing.cpu_count() // 2,
#         sampler=Sampler(train_dataset),
        shuffle=True,
        pin_memory=use_cuda
    )
    val_loader = DataLoader(
        val_dataset,
        batch_size=config.valid_batch_size,
        num_workers=multiprocessing.cpu_count() // 2,
        shuffle=False,
        pin_memory=use_cuda
    )
    return train_loader, val_loader

# %% [markdown]
# # define model

# %%
# class BaseModel(nn.Module):
#     def __init__(self, num_classes):
#         super().__init__()
#         self.base_model = models.vit_b_16(pretrained=True)
#         self.base_model.heads.head = nn.Linear(in_features=768, out_features=num_classes, bias=True)

#     def forward(self, x):
#         return self.base_model(x)

# %%
# class ResnextModel(nn.Module):
#     def __init__(self, num_classes):
#         super().__init__()
#         self.base_model = models.resnext50_32x4d(pretrained=True)
#         self.base_model.fc = nn.Sequential(
#             nn.Linear(in_features=2048, out_features=1000, bias=True),
#             nn.ELU(True),
#             nn.Dropout(),
#             nn.Linear(in_features=1000, out_features=num_classes, bias=True)
#         )
#     def forward(self, x):
#         return self.base_model(x)

# %%
# class Resnext101Model(nn.Module):
#     def __init__(self, num_classes):
#         super().__init__()
#         self.base_model = models.resnext101_32x8d(weights=models.ResNeXt101_32X8D_Weights.DEFAULT)
#         self.base_model.fc = nn.Sequential(
#             nn.Linear(in_features=2048, out_features=1000, bias=True),
#             nn.ELU(True),
#             nn.Dropout(),
#             nn.Linear(in_features=1000, out_features=num_classes, bias=True)
#         )
#     def forward(self, x):
#         return self.base_model(x)

# %%
class Identity(nn.Module):
    def __init__(self):
        super(Identity, self).__init__()
        
    def forward(self, x):
        return x
    
class ResnextMultiheadModel(nn.Module):
    def __init__(self):
        super().__init__()
        self.base_model = models.resnext50_32x4d(pretrained=True)
        self.base_model.fc = Identity()

        self.fc_mask_classifier = nn.Sequential(
            nn.Linear(in_features=2048, out_features=1000, bias=True),
            nn.ELU(True),
            nn.Dropout(0.5, inplace=True),
            nn.Linear(in_features=1000, out_features=3, bias=True)
        )
        self.fc_age_classifier = nn.Sequential(
            nn.Linear(in_features=2048, out_features=1000, bias=True),
            nn.ELU(True),
            nn.Dropout(0.5, inplace=True),
            nn.Linear(in_features=1000, out_features=1000, bias=True),
            nn.ELU(True),
            nn.Dropout(0.5, inplace=True),
            nn.Linear(in_features=1000, out_features=3, bias=True)
        )
        self.fc_gender_classifier = nn.Sequential(
            nn.Linear(in_features=2048, out_features=1000, bias=True),
            nn.ELU(True),
            nn.Dropout(0.5, inplace=True),
            nn.Linear(in_features=1000, out_features=2, bias=True)
        )
    def forward(self, x):
        x = self.base_model(x)
        mask = self.fc_mask_classifier(x)
        age = self.fc_age_classifier(x)
        gender = self.fc_gender_classifier(x)
        return mask, age, gender

# %% [markdown]
# # train

# %%
# model = ResnextMultiheadModel().to(device)
# model = torch.nn.DataParallel(model)

# %%
# https://discuss.pytorch.org/t/is-this-a-correct-implementation-for-focal-loss-in-pytorch/43327/8
class FocalLoss(nn.Module):
    def __init__(self, weight=None,
                 gamma=2., reduction='mean'):
        nn.Module.__init__(self)
        self.weight = weight
        self.gamma = gamma
        self.reduction = reduction

    def forward(self, input_tensor, target_tensor):
        log_prob = F.log_softmax(input_tensor, dim=-1)
        prob = torch.exp(log_prob)
        return F.nll_loss(
            ((1 - prob) ** self.gamma) * log_prob,
            target_tensor,
            weight=self.weight,
            reduction=self.reduction
        )

class F1Loss(nn.Module):
    def __init__(self, classes=3, epsilon=1e-7):
        super().__init__()
        self.classes = classes
        self.epsilon = epsilon

    def forward(self, y_pred, y_true):
        assert y_pred.ndim == 2
        assert y_true.ndim == 1
        y_true = F.one_hot(y_true, self.classes).to(torch.float32)
        y_pred = F.softmax(y_pred, dim=1)

        tp = (y_true * y_pred).sum(dim=0).to(torch.float32)
        tn = ((1 - y_true) * (1 - y_pred)).sum(dim=0).to(torch.float32)
        fp = ((1 - y_true) * y_pred).sum(dim=0).to(torch.float32)
        fn = (y_true * (1 - y_pred)).sum(dim=0).to(torch.float32)

        precision = tp / (tp + fp + self.epsilon)
        recall = tp / (tp + fn + self.epsilon)

        f1 = 2 * (precision * recall) / (precision + recall + self.epsilon)
        f1 = f1.clamp(min=self.epsilon, max=1 - self.epsilon)
        return 1 - f1.mean()
    
class LADELoss(nn.Module):
    def __init__(self, num_classes=10, img_num_per_cls=None, remine_lambda=0.1):
        super().__init__()
        if img_num_per_cls is not None:
#             self.img_num_per_cls = calculate_prior(num_classes, img_max, prior, prior_txt, return_num=True).float().cuda()
            self.img_num_per_cls = img_num_per_cls
            self.prior = self.img_num_per_cls / self.img_num_per_cls.sum()
        else:
            self.prior = None
        self.prior = self.prior.to(device)
        self.balanced_prior = torch.tensor(1. / num_classes).float().cuda()
        self.remine_lambda = remine_lambda

        self.num_classes = num_classes
        self.cls_weight = (self.img_num_per_cls.float() / torch.sum(self.img_num_per_cls.float())).cuda()

    def mine_lower_bound(self, x_p, x_q, num_samples_per_cls):
        N = x_p.size(-1)
        first_term = torch.sum(x_p, -1) / (num_samples_per_cls + 1e-8)
        second_term = torch.logsumexp(x_q, -1) - np.log(N)

        return first_term - second_term, first_term, second_term

    def remine_lower_bound(self, x_p, x_q, num_samples_per_cls):
        loss, first_term, second_term = self.mine_lower_bound(x_p, x_q, num_samples_per_cls)
        reg = (second_term ** 2) * self.remine_lambda
        return loss - reg, first_term, second_term

    def forward(self, y_pred, target, q_pred=None):
        """
        y_pred: N x C
        target: N
        """
        per_cls_pred_spread = y_pred.T * (target == torch.arange(0, self.num_classes).view(-1, 1).type_as(target))  # C x N
        pred_spread = (y_pred - torch.log(self.prior + 1e-9) + torch.log(self.balanced_prior + 1e-9)).T  # C x N

        num_samples_per_cls = torch.sum(target == torch.arange(0, self.num_classes).view(-1, 1).type_as(target), -1).float()  # C
        estim_loss, first_term, second_term = self.remine_lower_bound(per_cls_pred_spread, pred_spread, num_samples_per_cls)

        loss = -torch.sum(estim_loss * self.cls_weight)
        return loss

# %% [markdown]
# ### loss , metric , optimizer , scheduler

# %%
# criterion = FocalLoss()
# optimizer = Adam(
#     filter(lambda p: p.requires_grad, model.parameters()),
#     lr=config.lr,
#     weight_decay=5e-4
# )
# optimizer = SGD(
#     filter(lambda p: p.requires_grad, model.parameters()),
#     lr=config.lr,
#     momentum=0.9,
#     nesterov=True
# )
# optimizer = RMSprop(
#     filter(lambda p: p.requires_grad, model.parameters()),
#     lr=config.lr,
#     weight_decay=5e-4,
#     momentum=0.9
# )
# scheduler = StepLR(optimizer, config.lr_decay_step, gamma=0.5)
# -- scheduler: ReduceLROnPlateau
# 성능이 향상되지 않을 때 learning rate를 줄입니다. patience=10은 10회 동안 성능 향상이 없을 경우입니다.
# scheduler = ReduceLROnPlateau(optimizer, factor=0.1, patience=10)
# -- scheduler: CosineAnnealingLR
# CosineAnnealing은 learning rate를 cosine 그래프처럼 변화시킵니다.
# scheduler = CosineAnnealingLR(optimizer, T_max=2, eta_min=0.)
def get_lr(optimizer):
    for param_group in optimizer.param_groups:
        return param_group['lr']

# %%
# 세이브 경로
path = Path(config.save_dir)
if (not path.exists()):
    save_dir = str(path)
else:
    dirs = glob.glob(f"{path}*")
    matches = [re.search(rf"%s(\d+)" % path.stem, d) for d in dirs]
    i = [int(m.groups()[0]) for m in matches if m]
    n = max(i) + 1 if i else 2
    save_dir = f"{path}{n}"

print("save path : " + save_dir)
os.makedirs(save_dir)
# Out:
# save path : kfoldEnsemble_exp6

# %% [markdown]
# ### start training

# %%
# logger = SummaryWriter(log_dir=save_dir)
# with open(os.path.join(save_dir, 'config.json'), 'w', encoding='utf-8') as f:
#     json.dump(vars(config), f, ensure_ascii=False, indent=4)

# %%
# k-fold setting
skf = StratifiedKFold(n_splits=config.n_splits)
csv_path = os.path.join(config.data_dir,'train.csv')
data = pd.read_csv(csv_path)
age_img_num_per_cls =  torch.Tensor([data['age'][lambda x : x <30].count(), data['age'][lambda x : (x >= 30) & (x<60)].count(), data['age'][lambda x : x >= 60].count()])
labels = [ AgeLabels.from_number(d) for d in list(data.age.values)]
data_list = list(data.values)
# for i, (train_idx, valid_idx) in enumerate(skf.split(data_list, labels)):
#     print(i)
#     print(len(train_idx), len(valid_idx))
#     print(data.loc[valid_idx])


for i, (train_idx, valid_idx) in enumerate(skf.split(data_list, labels)):
    counter = 0
    best_val_acc = 0
    best_val_loss = np.inf
    best_val_f1 = 0
    train_loader, val_loader = getDataloader(train_idx, valid_idx)
    model = ResnextMultiheadModel().to(device)
    model = torch.nn.DataParallel(model)
#     criterion = FocalLoss()
    criterion_mask = FocalLoss() #F1Loss(classes=3)
    criterion_age = LADELoss(num_classes=3, img_num_per_cls=age_img_num_per_cls) #F1Loss(classes=3)
    criterion_gender = FocalLoss() #F1Loss(classes=2)
    optimizer = Adam(
        filter(lambda p: p.requires_grad, model.parameters()),
        lr=config.lr,
        weight_decay=5e-4
    )
    scheduler = ExponentialLR(optimizer, gamma=0.85)
#     scheduler = StepLR(optimizer, config.lr_decay_step, gamma=0.5)
    print(f"kfold[{i+1}/{config.n_splits}]")
    for epoch in range(config.epochs):
        # train loop
        model.train()
        loss_value = 0
        matches = 0
        label_list=[]
        pred_list=[]
        mask_label_list=[]
        mask_pred_list=[]
        age_label_list=[]
        age_pred_list=[]
        gender_label_list=[]
        gender_pred_list=[]
        for idx, train_batch in enumerate(train_loader):
            inputs, (mask_labels, gender_labels, age_labels, multi_class_labels) = train_batch
            inputs = inputs.to(device)
            mask_labels = mask_labels.to(device)
            gender_labels = gender_labels.to(device)
            age_labels = age_labels.to(device)
            multi_class_labels = multi_class_labels.to(device)

            optimizer.zero_grad()

            mask_outs, age_outs, gender_outs = model(inputs)
            mask_preds = torch.argmax(mask_outs, dim=-1)
            age_preds = torch.argmax(age_outs, dim=-1)
            gender_preds = torch.argmax(gender_outs, dim=-1)

            multi_preds = mask_preds * 6 + gender_preds * 3 + age_preds
            
            
#             mask_loss = criterion(mask_outs, mask_labels)
#             age_loss = criterion(age_outs, age_labels)
#             gender_loss = criterion(gender_outs, gender_labels)
            mask_loss = criterion_mask(mask_outs, mask_labels)
            age_loss = criterion_age(age_outs, age_labels)
            gender_loss = criterion_gender(gender_outs, gender_labels)

            loss = mask_loss + gender_loss + age_loss

            loss.backward()
            optimizer.step()

            label_list+=multi_class_labels.detach().cpu()
            pred_list+=multi_preds.detach().cpu()

            mask_label_list+=mask_labels.detach().cpu()
            mask_pred_list+=mask_preds.detach().cpu()
            age_label_list+=age_labels.detach().cpu()
            age_pred_list+=age_preds.detach().cpu()
            gender_label_list+=gender_labels.detach().cpu()
            gender_pred_list+=gender_preds.detach().cpu()

            loss_value += loss.item()
            matches += (multi_preds == multi_class_labels).sum().item()
            if (idx + 1) % config.log_interval == 0:
                train_loss = loss_value / config.log_interval
                train_acc = matches / config.batch_size / config.log_interval
                train_f1 = f1_score(label_list, pred_list, average='macro')
                mask_f1 = f1_score(mask_label_list, mask_pred_list, average='macro')
                age_f1 = f1_score(age_label_list, age_pred_list, average='macro')
                gender_f1 = f1_score(gender_label_list, gender_pred_list, average='macro')
                current_lr = get_lr(optimizer)
                print(
                    f"Epoch[{epoch}/{config.epochs}]({idx + 1}/{len(train_loader)}) || "
                    f"training loss {train_loss:4.4} || training accuracy {train_acc:4.2%} || training f1_score {train_f1:4.4} || lr {current_lr}"
                )
                print(f"          training each f1 || mask f1 {mask_f1:4.4} || age f1 {age_f1:4.4} || gender f1 {gender_f1:4.4}")
    #             logger.add_scalar("Train/loss", train_loss, epoch * len(train_loader) + idx)
    #             logger.add_scalar("Train/accuracy", train_acc, epoch * len(train_loader) + idx)
    #             logger.add_scalar("Train/f1_score", train_f1, epoch * len(train_loader) + idx)

                loss_value = 0
                matches = 0
                label_list=[]
                pred_list=[]

        scheduler.step()

        # val loop
        with torch.no_grad():
            print("Calculating validation results...")
            model.eval()
            val_loss_items = []
            val_acc_items = []
            label_list=[]
            pred_list=[]
            mask_label_list=[]
            mask_pred_list=[]
            age_label_list=[]
            age_pred_list=[]
            gender_label_list=[]
            gender_pred_list=[]
            data_len = 0
            for val_batch in val_loader:
                inputs, (mask_labels, gender_labels, age_labels, multi_class_labels) = val_batch
                data_len += len(multi_class_labels)
                inputs = inputs.to(device)
                mask_labels = mask_labels.to(device)
                gender_labels = gender_labels.to(device)
                age_labels = age_labels.to(device)
                multi_class_labels = multi_class_labels.to(device)

                mask_outs, age_outs, gender_outs = model(inputs)
                mask_preds = torch.argmax(mask_outs, dim=-1)
                age_preds = torch.argmax(age_outs, dim=-1)
                gender_preds = torch.argmax(gender_outs, dim=-1)
                multi_preds = mask_preds * 6 + gender_preds * 3 + age_preds
                
#                 mask_loss = criterion(mask_outs, mask_labels)
#                 age_loss = criterion(age_outs, age_labels)
#                 gender_loss = criterion(gender_outs, gender_labels)
                mask_loss = criterion_mask(mask_outs, mask_labels)
                age_loss = criterion_age(age_outs, age_labels)
                gender_loss = criterion_gender(gender_outs, gender_labels)
                loss = mask_loss + age_loss + gender_loss

                label_list+=multi_class_labels.detach().cpu()
                pred_list+=multi_preds.detach().cpu()
                mask_label_list+=mask_labels.detach().cpu()
                mask_pred_list+=mask_preds.detach().cpu()
                age_label_list+=age_labels.detach().cpu()
                age_pred_list+=age_preds.detach().cpu()
                gender_label_list+=gender_labels.detach().cpu()
                gender_pred_list+=gender_preds.detach().cpu()
                


                acc_item = (multi_class_labels == multi_preds).sum().item()
                val_loss_items.append(loss.item())
                val_acc_items.append(acc_item)

            val_loss = float(np.sum(val_loss_items) / len(val_loader))
            val_acc = float(np.sum(val_acc_items) / data_len)
            val_f1= float(f1_score(label_list,pred_list,average="macro"))
            val_mask_f1 = f1_score(mask_label_list, mask_pred_list, average='macro')
            val_age_f1 = f1_score(age_label_list, age_pred_list, average='macro')
            val_gender_f1 = f1_score(gender_label_list, gender_pred_list, average='macro')

            if val_f1 > best_val_f1:
                print(f"New best model for val f1 : {val_f1:4.4}! saving the best model..")
                torch.save(model.module.state_dict(), f"{save_dir}/best_{i}.pth")
                best_val_f1 = val_f1
                best_val_acc = val_acc
                best_val_loss = val_loss
                counter = 0
            else:
                counter += 1
            torch.save(model.module.state_dict(), f"{save_dir}/last_{i}.pth")
            print(
                f"[Val] acc : {val_acc:4.2%}, loss: {val_loss:4.4}, f1: {val_f1:4.4} || "
                f"best acc : {best_val_acc:4.2%}, best loss: {best_val_loss:4.4}, best f1: {best_val_f1:4.4}"
            )
            print(f"[Val] each f1 || mask f1 {val_mask_f1:4.4} || age f1 {val_age_f1:4.4} || gender f1 {val_gender_f1:4.4}")
            if counter > config.patience:
                print("Early Stopping!")
                counter = 0
                break
#             logger.add_scalar("Val/loss", val_loss, epoch)
#             logger.add_scalar("Val/accuracy", val_acc, epoch)
#             logger.add_scalar("Val/f1", val_f1, epoch)
            print()
# Out:
# /opt/conda/lib/python3.8/site-packages/torchvision/models/_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and will be removed in 0.15, please use 'weights' instead.
#   warnings.warn(
# /opt/conda/lib/python3.8/site-packages/torchvision/models/_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and will be removed in 0.15. The current behavior is equivalent to passing `weights=ResNeXt50_32X4D_Weights.IMAGENET1K_V1`. You can also use `weights=ResNeXt50_32X4D_Weights.DEFAULT` to get the most up-to-date weights.
#   warnings.warn(msg)
# kfold[1/5]
# Epoch[0/50](50/237) || training loss -0.486 || training accuracy 74.25% || training f1_score 0.5796 || lr 0.0001
#           training each f1 || mask f1 0.8991 || age f1 0.6683 || gender f1 0.9047
# Epoch[0/50](100/237) || training loss -0.7937 || training accuracy 87.91% || training f1_score 0.7535 || lr 0.0001
#           training each f1 || mask f1 0.9414 || age f1 0.7436 || gender f1 0.9375
# Epoch[0/50](150/237) || training loss -0.8551 || training accuracy 90.09% || training f1_score 0.8162 || lr 0.0001
#           training each f1 || mask f1 0.958 || age f1 0.7861 || gender f1 0.9478
# Epoch[0/50](200/237) || training loss -0.8884 || training accuracy 92.22% || training f1_score 0.8453 || lr 0.0001
#           training each f1 || mask f1 0.9659 || age f1 0.8152 || gender f1 0.9553
# Calculating validation results...
# New best model for val f1 : 0.6732! saving the best model..
# [Val] acc : 84.50%, loss: -0.6852, f1: 0.6732 || best acc : 84.50%, best loss: -0.6852, best f1: 0.6732
# [Val] each f1 || mask f1 0.9893 || age f1 0.7367 || gender f1 0.958
#
# Epoch[1/50](50/237) || training loss -0.9758 || training accuracy 96.34% || training f1_score 0.9249 || lr 8.5e-05
#           training each f1 || mask f1 0.9959 || age f1 0.958 || gender f1 0.9846
# Epoch[1/50](100/237) || training loss -0.9944 || training accuracy 96.56% || training f1_score 0.9249 || lr 8.5e-05
#           training each f1 || mask f1 0.9949 || age f1 0.9622 || gender f1 0.9847
# Epoch[1/50](150/237) || training loss -1.013 || training accuracy 97.84% || training f1_score 0.9466 || lr 8.5e-05
#           training each f1 || mask f1 0.9943 || age f1 0.9681 || gender f1 0.9876
# Epoch[1/50](200/237) || training loss -1.023 || training accuracy 98.00% || training f1_score 0.9541 || lr 8.5e-05
#           training each f1 || mask f1 0.9946 || age f1 0.97 || gender f1 0.9892
# Calculating validation results...
# New best model for val f1 : 0.7544! saving the best model..
# [Val] acc : 86.51%, loss: -0.6844, f1: 0.7544 || best acc : 86.51%, best loss: -0.6844, best f1: 0.7544
# [Val] each f1 || mask f1 0.987 || age f1 0.8137 || gender f1 0.9662
#
# Epoch[2/50](50/237) || training loss -1.037 || training accuracy 98.53% || training f1_score 0.9682 || lr 7.225000000000001e-05
#           training each f1 || mask f1 0.9929 || age f1 0.9917 || gender f1 0.9928
# Epoch[2/50](100/237) || training loss -1.043 || training accuracy 99.03% || training f1_score 0.9813 || lr 7.225000000000001e-05
#           training each f1 || mask f1 0.9947 || age f1 0.9922 || gender f1 0.9949
# Epoch[2/50](150/237) || training loss -1.05 || training accuracy 99.19% || training f1_score 0.9851 || lr 7.225000000000001e-05
#           training each f1 || mask f1 0.9956 || age f1 0.9925 || gender f1 0.9956
# Epoch[2/50](200/237) || training loss -1.049 || training accuracy 99.09% || training f1_score 0.9838 || lr 7.225000000000001e-05
#           training each f1 || mask f1 0.9952 || age f1 0.9923 || gender f1 0.9963
# Calculating validation results...
# [Val] acc : 86.77%, loss: -0.6946, f1: 0.7372 || best acc : 86.51%, best loss: -0.6844, best f1: 0.7544
# [Val] each f1 || mask f1 0.992 || age f1 0.7829 || gender f1 0.972
#
# Epoch[3/50](50/237) || training loss -1.055 || training accuracy 99.59% || training f1_score 0.9939 || lr 6.141250000000001e-05
#           training each f1 || mask f1  1.0 || age f1 0.9974 || gender f1 0.9977
# Epoch[3/50](100/237) || training loss -1.066 || training accuracy 99.69% || training f1_score 0.9955 || lr 6.141250000000001e-05
#           training each f1 || mask f1 0.9998 || age f1 0.998 || gender f1 0.998
# Epoch[3/50](150/237) || training loss -1.067 || training accuracy 99.38% || training f1_score 0.9885 || lr 6.141250000000001e-05
#           training each f1 || mask f1 0.9996 || age f1 0.9973 || gender f1 0.9975
# Epoch[3/50](200/237) || training loss -1.065 || training accuracy 99.16% || training f1_score 0.9868 || lr 6.141250000000001e-05
#           training each f1 || mask f1 0.9988 || age f1 0.997 || gender f1 0.9971
# Calculating validation results...
# [Val] acc : 86.90%, loss: -0.584, f1: 0.7257 || best acc : 86.51%, best loss: -0.6844, best f1: 0.7544
# [Val] each f1 || mask f1 0.9929 || age f1 0.7815 || gender f1 0.9629
#
# Epoch[4/50](50/237) || training loss -1.07 || training accuracy 99.41% || training f1_score 0.9855 || lr 5.2200625000000005e-05
#           training each f1 || mask f1 0.9984 || age f1 0.997 || gender f1 0.9964
# Epoch[4/50](100/237) || training loss -1.079 || training accuracy 99.59% || training f1_score 0.9885 || lr 5.2200625000000005e-05
#           training each f1 || mask f1 0.9988 || age f1 0.9979 || gender f1 0.9967
# Epoch[4/50](150/237) || training loss -1.075 || training accuracy 99.62% || training f1_score 0.9963 || lr 5.2200625000000005e-05
#           training each f1 || mask f1 0.9987 || age f1 0.9981 || gender f1 0.9971
# Epoch[4/50](200/237) || training loss -1.076 || training accuracy 99.53% || training f1_score 0.9866 || lr 5.2200625000000005e-05
#           training each f1 || mask f1 0.9987 || age f1 0.9971 || gender f1 0.9975
# Calculating validation results...
# New best model for val f1 : 0.7653! saving the best model..
# [Val] acc : 86.83%, loss: -0.616, f1: 0.7653 || best acc : 86.83%, best loss: -0.616, best f1: 0.7653
# [Val] each f1 || mask f1 0.995 || age f1 0.8074 || gender f1 0.9666
#
# Epoch[5/50](50/237) || training loss -1.083 || training accuracy 99.75% || training f1_score 0.994 || lr 4.437053125e-05
#           training each f1 || mask f1 0.9991 || age f1 0.9971 || gender f1 0.9993
# Epoch[5/50](100/237) || training loss -1.085 || training accuracy 99.62% || training f1_score 0.9902 || lr 4.437053125e-05
#           training each f1 || mask f1 0.9987 || age f1 0.9972 || gender f1 0.9988
# Epoch[5/50](150/237) || training loss -1.083 || training accuracy 99.75% || training f1_score 0.9964 || lr 4.437053125e-05
#           training each f1 || mask f1 0.9987 || age f1 0.9976 || gender f1 0.9988
# Epoch[5/50](200/237) || training loss -1.083 || training accuracy 99.81% || training f1_score 0.9976 || lr 4.437053125e-05
#           training each f1 || mask f1 0.9985 || age f1 0.9978 || gender f1 0.9991
# Calculating validation results...
# New best model for val f1 : 0.7837! saving the best model..
# [Val] acc : 88.20%, loss: -0.664, f1: 0.7837 || best acc : 88.20%, best loss: -0.664, best f1: 0.7837
# [Val] each f1 || mask f1 0.995 || age f1 0.8111 || gender f1 0.9733
#
# Epoch[6/50](50/237) || training loss -1.09 || training accuracy 100.00% || training f1_score  1.0 || lr 3.77149515625e-05
#           training each f1 || mask f1  1.0 || age f1  1.0 || gender f1  1.0
# Epoch[6/50](100/237) || training loss -1.094 || training accuracy 99.97% || training f1_score 0.9997 || lr 3.77149515625e-05
#           training each f1 || mask f1  1.0 || age f1 0.9996 || gender f1  1.0
# Epoch[6/50](150/237) || training loss -1.09 || training accuracy 99.81% || training f1_score 0.9965 || lr 3.77149515625e-05
#           training each f1 || mask f1 0.9992 || age f1 0.9997 || gender f1 0.9998
# Epoch[6/50](200/237) || training loss -1.088 || training accuracy 99.94% || training f1_score 0.9991 || lr 3.77149515625e-05
#           training each f1 || mask f1 0.9994 || age f1 0.9996 || gender f1 0.9998
# Calculating validation results...
# [Val] acc : 88.12%, loss: -0.6783, f1: 0.71 || best acc : 88.20%, best loss: -0.664, best f1: 0.7837
# [Val] each f1 || mask f1 0.9939 || age f1 0.7802 || gender f1 0.9677
#
# Epoch[7/50](50/237) || training loss -1.092 || training accuracy 99.91% || training f1_score 0.9991 || lr 3.2057708828124995e-05
#           training each f1 || mask f1 0.9993 || age f1  1.0 || gender f1 0.9993
# Epoch[7/50](100/237) || training loss -1.089 || training accuracy 99.81% || training f1_score 0.9963 || lr 3.2057708828124995e-05
#           training each f1 || mask f1 0.9996 || age f1 0.9985 || gender f1 0.9995
# Epoch[7/50](150/237) || training loss -1.091 || training accuracy 99.91% || training f1_score 0.9993 || lr 3.2057708828124995e-05
#           training each f1 || mask f1 0.9998 || age f1 0.999 || gender f1 0.9993
# Epoch[7/50](200/237) || training loss -1.092 || training accuracy 99.88% || training f1_score 0.9987 || lr 3.2057708828124995e-05
#           training each f1 || mask f1 0.9996 || age f1 0.9992 || gender f1 0.9994
# Calculating validation results...
# [Val] acc : 87.80%, loss: -0.7081, f1: 0.7541 || best acc : 88.20%, best loss: -0.664, best f1: 0.7837
# [Val] each f1 || mask f1 0.9954 || age f1 0.7967 || gender f1 0.9708
#
# Epoch[8/50](50/237) || training loss -1.094 || training accuracy 99.88% || training f1_score 0.9989 || lr 2.7249052503906245e-05
#           training each f1 || mask f1  1.0 || age f1 0.9991 || gender f1  1.0
# Epoch[8/50](100/237) || training loss -1.096 || training accuracy 99.88% || training f1_score 0.9993 || lr 2.7249052503906245e-05
#           training each f1 || mask f1 0.9998 || age f1 0.9992 || gender f1  1.0
# Epoch[8/50](150/237) || training loss -1.089 || training accuracy 99.91% || training f1_score 0.9994 || lr 2.7249052503906245e-05
#           training each f1 || mask f1 0.9999 || age f1 0.9993 || gender f1 0.9999
# Epoch[8/50](200/237) || training loss -1.094 || training accuracy 99.88% || training f1_score 0.9993 || lr 2.7249052503906245e-05
#           training each f1 || mask f1 0.9998 || age f1 0.9994 || gender f1 0.9998
# Calculating validation results...
# New best model for val f1 : 0.7938! saving the best model..
# [Val] acc : 88.60%, loss: -0.8193, f1: 0.7938 || best acc : 88.60%, best loss: -0.8193, best f1: 0.7938
# [Val] each f1 || mask f1 0.9947 || age f1 0.8325 || gender f1 0.9709
#
# Epoch[9/50](50/237) || training loss -1.092 || training accuracy 99.75% || training f1_score 0.997 || lr 2.3161694628320308e-05
#           training each f1 || mask f1  1.0 || age f1 0.9996 || gender f1 0.998
# Epoch[9/50](100/237) || training loss -1.1 || training accuracy 99.88% || training f1_score 0.9991 || lr 2.3161694628320308e-05
#           training each f1 || mask f1  1.0 || age f1 0.9998 || gender f1 0.9984
# Epoch[9/50](150/237) || training loss -1.098 || training accuracy 99.84% || training f1_score 0.9982 || lr 2.3161694628320308e-05
#           training each f1 || mask f1 0.9999 || age f1 0.9999 || gender f1 0.9985
# Epoch[9/50](200/237) || training loss -1.098 || training accuracy 100.00% || training f1_score  1.0 || lr 2.3161694628320308e-05
#           training each f1 || mask f1 0.9999 || age f1 0.9999 || gender f1 0.9989
# Calculating validation results...
# [Val] acc : 87.78%, loss: -0.647, f1: 0.7702 || best acc : 88.60%, best loss: -0.8193, best f1: 0.7938
# [Val] each f1 || mask f1 0.9943 || age f1 0.8066 || gender f1 0.9701
#
# Epoch[10/50](50/237) || training loss -1.095 || training accuracy 99.97% || training f1_score 0.9994 || lr 1.9687440434072263e-05
#           training each f1 || mask f1  1.0 || age f1  1.0 || gender f1 0.9997
# Epoch[10/50](100/237) || training loss -1.098 || training accuracy 99.94% || training f1_score 0.999 || lr 1.9687440434072263e-05
#           training each f1 || mask f1  1.0 || age f1  1.0 || gender f1 0.9995
# Epoch[10/50](150/237) || training loss -1.101 || training accuracy 100.00% || training f1_score  1.0 || lr 1.9687440434072263e-05
#           training each f1 || mask f1  1.0 || age f1  1.0 || gender f1 0.9997
# Epoch[10/50](200/237) || training loss -1.104 || training accuracy 99.97% || training f1_score 0.9999 || lr 1.9687440434072263e-05
#           training each f1 || mask f1  1.0 || age f1 0.9999 || gender f1 0.9998
# Calculating validation results...
# [Val] acc : 86.90%, loss: -0.5129, f1: 0.7425 || best acc : 88.60%, best loss: -0.8193, best f1: 0.7938
# [Val] each f1 || mask f1 0.9947 || age f1 0.777 || gender f1 0.973
#
# Epoch[11/50](50/237) || training loss -1.098 || training accuracy 99.88% || training f1_score 0.9982 || lr 1.673432436896142e-05
#           training each f1 || mask f1  1.0 || age f1  1.0 || gender f1 0.9987
# Epoch[11/50](100/237) || training loss -1.097 || training accuracy 100.00% || training f1_score  1.0 || lr 1.673432436896142e-05
#           training each f1 || mask f1  1.0 || age f1  1.0 || gender f1 0.9993
# Epoch[11/50](150/237) || training loss -1.101 || training accuracy 100.00% || training f1_score  1.0 || lr 1.673432436896142e-05
#           training each f1 || mask f1  1.0 || age f1  1.0 || gender f1 0.9996
# Epoch[11/50](200/237) || training loss -1.097 || training accuracy 99.97% || training f1_score 0.9994 || lr 1.673432436896142e-05
#           training each f1 || mask f1 0.9998 || age f1  1.0 || gender f1 0.9997
# Calculating validation results...
# [Val] acc : 87.14%, loss: -0.5418, f1: 0.7582 || best acc : 88.60%, best loss: -0.8193, best f1: 0.7938
# [Val] each f1 || mask f1 0.9931 || age f1 0.7976 || gender f1 0.9671
#
# Epoch[12/50](50/237) || training loss -1.1 || training accuracy 99.97% || training f1_score 0.9999 || lr 1.4224175713617208e-05
#           training each f1 || mask f1  1.0 || age f1  1.0 || gender f1 0.9997
# Epoch[12/50](100/237) || training loss -1.102 || training accuracy 99.94% || training f1_score 0.9998 || lr 1.4224175713617208e-05
#           training each f1 || mask f1  1.0 || age f1 0.9998 || gender f1 0.9998
# Epoch[12/50](150/237) || training loss -1.1 || training accuracy 99.97% || training f1_score 0.9994 || lr 1.4224175713617208e-05
#           training each f1 || mask f1  1.0 || age f1 0.9999 || gender f1 0.9998
# Epoch[12/50](200/237) || training loss -1.1 || training accuracy 100.00% || training f1_score  1.0 || lr 1.4224175713617208e-05
#           training each f1 || mask f1  1.0 || age f1 0.9999 || gender f1 0.9998
# Calculating validation results...
# [Val] acc : 87.35%, loss: -0.4966, f1: 0.7195 || best acc : 88.60%, best loss: -0.8193, best f1: 0.7938
# [Val] each f1 || mask f1 0.9939 || age f1 0.7721 || gender f1 0.9744
#
# Epoch[13/50](50/237) || training loss -1.108 || training accuracy 100.00% || training f1_score  1.0 || lr 1.2090549356574626e-05
#           training each f1 || mask f1  1.0 || age f1  1.0 || gender f1  1.0
# Epoch[13/50](100/237) || training loss -1.101 || training accuracy 100.00% || training f1_score  1.0 || lr 1.2090549356574626e-05
#           training each f1 || mask f1  1.0 || age f1  1.0 || gender f1  1.0
# Epoch[13/50](150/237) || training loss -1.105 || training accuracy 100.00% || training f1_score  1.0 || lr 1.2090549356574626e-05
#           training each f1 || mask f1  1.0 || age f1  1.0 || gender f1  1.0
# Epoch[13/50](200/237) || training loss -1.102 || training accuracy 99.94% || training f1_score 0.9991 || lr 1.2090549356574626e-05
#           training each f1 || mask f1 0.9999 || age f1 0.9999 || gender f1  1.0
# Calculating validation results...
# [Val] acc : 89.76%, loss: -0.6903, f1: 0.7914 || best acc : 88.60%, best loss: -0.8193, best f1: 0.7938
# [Val] each f1 || mask f1 0.9947 || age f1 0.8262 || gender f1 0.9744
#
# Epoch[14/50](50/237) || training loss -1.097 || training accuracy 99.81% || training f1_score 0.9981 || lr 1.0276966953088432e-05
#           training each f1 || mask f1 0.998 || age f1 0.9998 || gender f1 0.9993
# Epoch[14/50](100/237) || training loss -1.105 || training accuracy 99.97% || training f1_score 0.9996 || lr 1.0276966953088432e-05
#           training each f1 || mask f1 0.9986 || age f1 0.9999 || gender f1 0.9997
# Epoch[14/50](150/237) || training loss -1.1 || training accuracy 100.00% || training f1_score  1.0 || lr 1.0276966953088432e-05
#           training each f1 || mask f1 0.9991 || age f1 0.9999 || gender f1 0.9998
# Epoch[14/50](200/237) || training loss -1.105 || training accuracy 99.97% || training f1_score 0.9994 || lr 1.0276966953088432e-05
#           training each f1 || mask f1 0.9991 || age f1 0.9999 || gender f1 0.9998
# Calculating validation results...
# [Val] acc : 88.92%, loss: -0.6739, f1: 0.7843 || best acc : 88.60%, best loss: -0.8193, best f1: 0.7938
# [Val] each f1 || mask f1 0.9947 || age f1 0.8147 || gender f1 0.9722
#
# Epoch[15/50](50/237) || training loss -1.102 || training accuracy 99.97% || training f1_score 0.9999 || lr 8.735421910125167e-06
#           training each f1 || mask f1  1.0 || age f1 0.9998 || gender f1  1.0
# Epoch[15/50](100/237) || training loss -1.102 || training accuracy 100.00% || training f1_score  1.0 || lr 8.735421910125167e-06
#           training each f1 || mask f1  1.0 || age f1 0.9999 || gender f1  1.0
# Epoch[15/50](150/237) || training loss -1.107 || training accuracy 100.00% || training f1_score  1.0 || lr 8.735421910125167e-06
#           training each f1 || mask f1  1.0 || age f1 0.9999 || gender f1  1.0
# Epoch[15/50](200/237) || training loss -1.105 || training accuracy 100.00% || training f1_score  1.0 || lr 8.735421910125167e-06
#           training each f1 || mask f1  1.0 || age f1 0.9999 || gender f1  1.0
# Calculating validation results...
# [Val] acc : 89.29%, loss: -0.6517, f1: 0.7843 || best acc : 88.60%, best loss: -0.8193, best f1: 0.7938
# [Val] each f1 || mask f1 0.9939 || age f1 0.8148 || gender f1 0.9733
#
# Epoch[16/50](50/237) || training loss -1.103 || training accuracy 100.00% || training f1_score  1.0 || lr 7.425108623606392e-06
#           training each f1 || mask f1  1.0 || age f1  1.0 || gender f1  1.0
# Epoch[16/50](100/237) || training loss -1.105 || training accuracy 100.00% || training f1_score  1.0 || lr 7.425108623606392e-06
#           training each f1 || mask f1  1.0 || age f1  1.0 || gender f1  1.0
# Epoch[16/50](150/237) || training loss -1.107 || training accuracy 100.00% || training f1_score  1.0 || lr 7.425108623606392e-06
#           training each f1 || mask f1  1.0 || age f1  1.0 || gender f1  1.0
# Epoch[16/50](200/237) || training loss -1.107 || training accuracy 99.97% || training f1_score 0.9999 || lr 7.425108623606392e-06
#           training each f1 || mask f1  1.0 || age f1  1.0 || gender f1 0.9999
# Calculating validation results...
# [Val] acc : 88.47%, loss: -0.5726, f1: 0.7713 || best acc : 88.60%, best loss: -0.8193, best f1: 0.7938
# [Val] each f1 || mask f1 0.995 || age f1 0.8077 || gender f1 0.9725
#
# Epoch[17/50](50/237) || training loss -1.104 || training accuracy 99.97% || training f1_score 0.9999 || lr 6.3113423300654325e-06
#           training each f1 || mask f1  1.0 || age f1  1.0 || gender f1 0.9997
# Epoch[17/50](100/237) || training loss -1.099 || training accuracy 100.00% || training f1_score  1.0 || lr 6.3113423300654325e-06
#           training each f1 || mask f1  1.0 || age f1  1.0 || gender f1 0.9998
# Epoch[17/50](150/237) || training loss -1.105 || training accuracy 100.00% || training f1_score  1.0 || lr 6.3113423300654325e-06
#           training each f1 || mask f1  1.0 || age f1  1.0 || gender f1 0.9999
# Epoch[17/50](200/237) || training loss -1.104 || training accuracy 100.00% || training f1_score  1.0 || lr 6.3113423300654325e-06
#           training each f1 || mask f1  1.0 || age f1  1.0 || gender f1 0.9999
# Calculating validation results...
# [Val] acc : 87.57%, loss: -0.5147, f1: 0.7689 || best acc : 88.60%, best loss: -0.8193, best f1: 0.7938
# [Val] each f1 || mask f1 0.9954 || age f1 0.8036 || gender f1 0.9723
#
# Epoch[18/50](50/237) || training loss -1.103 || training accuracy 100.00% || training f1_score  1.0 || lr 5.3646409805556175e-06
#           training each f1 || mask f1  1.0 || age f1  1.0 || gender f1  1.0
# Epoch[18/50](100/237) || training loss -1.103 || training accuracy 99.97% || training f1_score 0.9999 || lr 5.3646409805556175e-06
#           training each f1 || mask f1  1.0 || age f1 0.9999 || gender f1  1.0
# Epoch[18/50](150/237) || training loss -1.109 || training accuracy 99.97% || training f1_score 0.9994 || lr 5.3646409805556175e-06
#           training each f1 || mask f1  1.0 || age f1 0.9999 || gender f1 0.9999
# Epoch[18/50](200/237) || training loss -1.103 || training accuracy 99.97% || training f1_score 0.9996 || lr 5.3646409805556175e-06
#           training each f1 || mask f1  1.0 || age f1 0.9999 || gender f1 0.9999
# Calculating validation results...
# [Val] acc : 88.07%, loss: -0.5503, f1: 0.759 || best acc : 88.60%, best loss: -0.8193, best f1: 0.7938
# [Val] each f1 || mask f1 0.9935 || age f1 0.7961 || gender f1 0.9733
#
# Epoch[19/50](50/237) || training loss -1.105 || training accuracy 100.00% || training f1_score  1.0 || lr 4.559944833472275e-06
#           training each f1 || mask f1  1.0 || age f1  1.0 || gender f1  1.0
# Epoch[19/50](100/237) || training loss -1.102 || training accuracy 100.00% || training f1_score  1.0 || lr 4.559944833472275e-06
#           training each f1 || mask f1  1.0 || age f1  1.0 || gender f1  1.0
# Epoch[19/50](150/237) || training loss -1.103 || training accuracy 100.00% || training f1_score  1.0 || lr 4.559944833472275e-06
#           training each f1 || mask f1  1.0 || age f1  1.0 || gender f1  1.0
# Epoch[19/50](200/237) || training loss -1.104 || training accuracy 100.00% || training f1_score  1.0 || lr 4.559944833472275e-06
#           training each f1 || mask f1  1.0 || age f1  1.0 || gender f1  1.0
# Calculating validation results...
# [Val] acc : 87.33%, loss: -0.4894, f1: 0.7611 || best acc : 88.60%, best loss: -0.8193, best f1: 0.7938
# [Val] each f1 || mask f1 0.995 || age f1 0.7941 || gender f1 0.9734
# Early Stopping!
# /opt/conda/lib/python3.8/site-packages/torchvision/models/_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and will be removed in 0.15, please use 'weights' instead.
#   warnings.warn(
# /opt/conda/lib/python3.8/site-packages/torchvision/models/_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and will be removed in 0.15. The current behavior is equivalent to passing `weights=ResNeXt50_32X4D_Weights.IMAGENET1K_V1`. You can also use `weights=ResNeXt50_32X4D_Weights.DEFAULT` to get the most up-to-date weights.
#   warnings.warn(msg)
# kfold[2/5]
# Epoch[0/50](50/237) || training loss -0.4784 || training accuracy 72.25% || training f1_score 0.5338 || lr 0.0001
#           training each f1 || mask f1 0.8946 || age f1 0.6635 || gender f1 0.8909
# Epoch[0/50](100/237) || training loss -0.805 || training accuracy 88.66% || training f1_score 0.7957 || lr 0.0001
#           training each f1 || mask f1 0.9414 || age f1 0.7572 || gender f1 0.9241
# Epoch[0/50](150/237) || training loss -0.8579 || training accuracy 90.97% || training f1_score 0.8089 || lr 0.0001
#           training each f1 || mask f1 0.9549 || age f1 0.7986 || gender f1 0.9403
# Epoch[0/50](200/237) || training loss -0.909 || training accuracy 92.91% || training f1_score 0.8591 || lr 0.0001
#           training each f1 || mask f1 0.9644 || age f1 0.8248 || gender f1 0.9501
# Calculating validation results...
# New best model for val f1 : 0.6586! saving the best model..
# [Val] acc : 80.32%, loss: -0.7333, f1: 0.6586 || best acc : 80.32%, best loss: -0.7333, best f1: 0.6586
# [Val] each f1 || mask f1 0.9948 || age f1 0.6885 || gender f1 0.9822
#
# Epoch[1/50](50/237) || training loss -0.9879 || training accuracy 97.09% || training f1_score 0.9437 || lr 8.5e-05
#           training each f1 || mask f1 0.9925 || age f1 0.9639 || gender f1 0.9898
# Epoch[1/50](100/237) || training loss -1.002 || training accuracy 97.81% || training f1_score 0.9476 || lr 8.5e-05
#           training each f1 || mask f1 0.9952 || age f1 0.9666 || gender f1 0.9919
# Epoch[1/50](150/237) || training loss -1.019 || training accuracy 97.94% || training f1_score 0.9618 || lr 8.5e-05
#           training each f1 || mask f1 0.9957 || age f1 0.9728 || gender f1 0.9908
# Epoch[1/50](200/237) || training loss -1.019 || training accuracy 97.66% || training f1_score 0.9611 || lr 8.5e-05
#           training each f1 || mask f1 0.9942 || age f1 0.9759 || gender f1 0.9906
# Calculating validation results...
# [Val] acc : 82.88%, loss: -0.6486, f1: 0.6444 || best acc : 80.32%, best loss: -0.7333, best f1: 0.6586
# [Val] each f1 || mask f1 0.9949 || age f1 0.6657 || gender f1 0.9829
#
# Epoch[2/50](50/237) || training loss -1.028 || training accuracy 98.34% || training f1_score 0.9686 || lr 7.225000000000001e-05
#           training each f1 || mask f1 0.9946 || age f1 0.9901 || gender f1 0.9922
# Epoch[2/50](100/237) || training loss -1.046 || training accuracy 98.91% || training f1_score 0.9754 || lr 7.225000000000001e-05
#           training each f1 || mask f1 0.9956 || age f1 0.9918 || gender f1 0.9931
# Epoch[2/50](150/237) || training loss -1.051 || training accuracy 98.75% || training f1_score 0.9837 || lr 7.225000000000001e-05
#           training each f1 || mask f1 0.9965 || age f1 0.9927 || gender f1 0.9927
# Epoch[2/50](200/237) || training loss -1.044 || training accuracy 98.44% || training f1_score 0.9723 || lr 7.225000000000001e-05
#           training each f1 || mask f1 0.9957 || age f1 0.9906 || gender f1 0.9936
# Calculating validation results...
# [Val] acc : 83.76%, loss: -0.6928, f1: 0.6535 || best acc : 80.32%, best loss: -0.7333, best f1: 0.6586
# [Val] each f1 || mask f1 0.9974 || age f1 0.6712 || gender f1 0.9861
#
# Epoch[3/50](50/237) || training loss -1.061 || training accuracy 99.25% || training f1_score 0.9883 || lr 6.141250000000001e-05
#           training each f1 || mask f1 0.9964 || age f1 0.9976 || gender f1 0.9955
# Epoch[3/50](100/237) || training loss -1.069 || training accuracy 99.50% || training f1_score 0.9915 || lr 6.141250000000001e-05
#           training each f1 || mask f1 0.996 || age f1 0.9984 || gender f1 0.9966
# Epoch[3/50](150/237) || training loss -1.063 || training accuracy 99.31% || training f1_score 0.987 || lr 6.141250000000001e-05
#           training each f1 || mask f1 0.9953 || age f1 0.9979 || gender f1 0.9973
# Epoch[3/50](200/237) || training loss -1.066 || training accuracy 99.25% || training f1_score 0.9879 || lr 6.141250000000001e-05
#           training each f1 || mask f1 0.9946 || age f1 0.9975 || gender f1 0.9975
# Calculating validation results...
# [Val] acc : 82.22%, loss: -0.6301, f1: 0.6489 || best acc : 80.32%, best loss: -0.7333, best f1: 0.6586
# [Val] each f1 || mask f1 0.9959 || age f1 0.668 || gender f1 0.985
#
# Epoch[4/50](50/237) || training loss -1.068 || training accuracy 99.53% || training f1_score 0.9945 || lr 5.2200625000000005e-05
#           training each f1 || mask f1 0.9991 || age f1 0.9964 || gender f1 0.9981
# Epoch[4/50](100/237) || training loss -1.076 || training accuracy 99.66% || training f1_score 0.9953 || lr 5.2200625000000005e-05
#           training each f1 || mask f1 0.9991 || age f1 0.9968 || gender f1 0.9987
# Epoch[4/50](150/237) || training loss -1.071 || training accuracy 99.38% || training f1_score 0.9911 || lr 5.2200625000000005e-05
#           training each f1 || mask f1 0.9985 || age f1 0.9967 || gender f1 0.9985
# Epoch[4/50](200/237) || training loss -1.083 || training accuracy 99.75% || training f1_score 0.9954 || lr 5.2200625000000005e-05
#           training each f1 || mask f1 0.9986 || age f1 0.9966 || gender f1 0.9987
# Calculating validation results...
# New best model for val f1 : 0.6614! saving the best model..
# [Val] acc : 83.54%, loss: -0.6622, f1: 0.6614 || best acc : 83.54%, best loss: -0.6622, best f1: 0.6614
# [Val] each f1 || mask f1 0.9952 || age f1 0.6805 || gender f1 0.9893
#
# Epoch[5/50](50/237) || training loss -1.083 || training accuracy 99.72% || training f1_score 0.9941 || lr 4.437053125e-05
#           training each f1 || mask f1 0.9976 || age f1 0.9987 || gender f1 0.9997
# Epoch[5/50](100/237) || training loss -1.085 || training accuracy 99.88% || training f1_score 0.9993 || lr 4.437053125e-05
#           training each f1 || mask f1 0.9984 || age f1 0.9992 || gender f1 0.9995
# Epoch[5/50](150/237) || training loss -1.085 || training accuracy 99.78% || training f1_score 0.9973 || lr 4.437053125e-05
#           training each f1 || mask f1 0.9989 || age f1 0.9994 || gender f1 0.999
# Epoch[5/50](200/237) || training loss -1.086 || training accuracy 99.84% || training f1_score 0.9981 || lr 4.437053125e-05
#           training each f1 || mask f1 0.9988 || age f1 0.9995 || gender f1 0.9993
# Calculating validation results...
# New best model for val f1 : 0.6621! saving the best model..
# [Val] acc : 82.83%, loss: -0.6043, f1: 0.6621 || best acc : 82.83%, best loss: -0.6043, best f1: 0.6621
# [Val] each f1 || mask f1 0.9981 || age f1 0.6754 || gender f1 0.9866
#
# Epoch[6/50](50/237) || training loss -1.091 || training accuracy 99.81% || training f1_score 0.9927 || lr 3.77149515625e-05
#           training each f1 || mask f1 0.9989 || age f1 0.9991 || gender f1 0.999
# Epoch[6/50](100/237) || training loss -1.087 || training accuracy 99.66% || training f1_score 0.9905 || lr 3.77149515625e-05
#           training each f1 || mask f1 0.9994 || age f1 0.9976 || gender f1 0.9989
# Epoch[6/50](150/237) || training loss -1.087 || training accuracy 99.91% || training f1_score 0.9993 || lr 3.77149515625e-05
#           training each f1 || mask f1 0.9994 || age f1 0.9982 || gender f1 0.9992
# Epoch[6/50](200/237) || training loss -1.088 || training accuracy 99.81% || training f1_score 0.998 || lr 3.77149515625e-05
#           training each f1 || mask f1 0.9993 || age f1 0.9983 || gender f1 0.9992
# Calculating validation results...
# [Val] acc : 82.86%, loss: -0.544, f1: 0.6359 || best acc : 82.83%, best loss: -0.6043, best f1: 0.6621
# [Val] each f1 || mask f1 0.997 || age f1 0.6484 || gender f1 0.9887
#
# Epoch[7/50](50/237) || training loss -1.094 || training accuracy 99.81% || training f1_score 0.9962 || lr 3.2057708828124995e-05
#           training each f1 || mask f1  1.0 || age f1 0.9991 || gender f1 0.9984
# Epoch[7/50](100/237) || training loss -1.091 || training accuracy 99.84% || training f1_score 0.9985 || lr 3.2057708828124995e-05
#           training each f1 || mask f1  1.0 || age f1 0.9996 || gender f1 0.9984
# Epoch[7/50](150/237) || training loss -1.09 || training accuracy 99.81% || training f1_score 0.9959 || lr 3.2057708828124995e-05
#           training each f1 || mask f1 0.9999 || age f1 0.9996 || gender f1 0.9985
# Epoch[7/50](200/237) || training loss -1.093 || training accuracy 99.94% || training f1_score 0.9989 || lr 3.2057708828124995e-05
#           training each f1 || mask f1 0.9999 || age f1 0.9997 || gender f1 0.9987
# Calculating validation results...
# [Val] acc : 81.14%, loss: -0.5435, f1: 0.6419 || best acc : 82.83%, best loss: -0.6043, best f1: 0.6621
# [Val] each f1 || mask f1 0.9974 || age f1 0.6621 || gender f1 0.9874
#
# Epoch[8/50](50/237) || training loss -1.094 || training accuracy 99.88% || training f1_score 0.9984 || lr 2.7249052503906245e-05
#           training each f1 || mask f1  1.0 || age f1 0.9981 || gender f1 0.9997
# Epoch[8/50](100/237) || training loss -1.093 || training accuracy 99.97% || training f1_score 0.9975 || lr 2.7249052503906245e-05
#           training each f1 || mask f1  1.0 || age f1 0.9986 || gender f1 0.9998
# Epoch[8/50](150/237) || training loss -1.099 || training accuracy 100.00% || training f1_score  1.0 || lr 2.7249052503906245e-05
#           training each f1 || mask f1  1.0 || age f1 0.9991 || gender f1 0.9999
# Epoch[8/50](200/237) || training loss -1.093 || training accuracy 99.84% || training f1_score 0.9962 || lr 2.7249052503906245e-05
#           training each f1 || mask f1 0.9999 || age f1 0.9985 || gender f1 0.9999
# Calculating validation results...
# New best model for val f1 : 0.6651! saving the best model..
# [Val] acc : 81.43%, loss: -0.5448, f1: 0.6651 || best acc : 81.43%, best loss: -0.5448, best f1: 0.6651
# [Val] each f1 || mask f1 0.9985 || age f1 0.6763 || gender f1 0.9829
#
# Epoch[9/50](50/237) || training loss -1.092 || training accuracy 99.94% || training f1_score 0.9968 || lr 2.3161694628320308e-05
#           training each f1 || mask f1  1.0 || age f1 0.9992 || gender f1 0.9997
# Epoch[9/50](100/237) || training loss -1.097 || training accuracy 100.00% || training f1_score  1.0 || lr 2.3161694628320308e-05
#           training each f1 || mask f1  1.0 || age f1 0.9996 || gender f1 0.9998
# Epoch[9/50](150/237) || training loss -1.096 || training accuracy 99.94% || training f1_score 0.9991 || lr 2.3161694628320308e-05
#           training each f1 || mask f1 0.9999 || age f1 0.9997 || gender f1 0.9998
# Epoch[9/50](200/237) || training loss -1.1 || training accuracy 99.97% || training f1_score 0.9999 || lr 2.3161694628320308e-05
#           training each f1 || mask f1 0.9999 || age f1 0.9998 || gender f1 0.9998
# Calculating validation results...
# [Val] acc : 82.12%, loss: -0.4464, f1: 0.6466 || best acc : 81.43%, best loss: -0.5448, best f1: 0.6651
# [Val] each f1 || mask f1 0.9978 || age f1 0.6574 || gender f1 0.9896
#
# Epoch[10/50](50/237) || training loss -1.1 || training accuracy 99.97% || training f1_score 0.9997 || lr 1.9687440434072263e-05
#           training each f1 || mask f1  1.0 || age f1 0.9991 || gender f1  1.0
# Epoch[10/50](100/237) || training loss -1.1 || training accuracy 99.97% || training f1_score 0.9999 || lr 1.9687440434072263e-05
#           training each f1 || mask f1  1.0 || age f1 0.9995 || gender f1  1.0
# Epoch[10/50](150/237) || training loss -1.1 || training accuracy 99.94% || training f1_score 0.9992 || lr 1.9687440434072263e-05
#           training each f1 || mask f1  1.0 || age f1 0.9996 || gender f1 0.9998
# Epoch[10/50](200/237) || training loss -1.098 || training accuracy 99.94% || training f1_score 0.9994 || lr 1.9687440434072263e-05
#           training each f1 || mask f1 0.9999 || age f1 0.9997 || gender f1 0.9998
# Calculating validation results...
# New best model for val f1 : 0.6725! saving the best model..
# [Val] acc : 82.43%, loss: -0.5713, f1: 0.6725 || best acc : 82.43%, best loss: -0.5713, best f1: 0.6725
# [Val] each f1 || mask f1 0.9981 || age f1 0.6824 || gender f1 0.9899
#
# Epoch[11/50](50/237) || training loss -1.098 || training accuracy 99.88% || training f1_score 0.9989 || lr 1.673432436896142e-05
#           training each f1 || mask f1 0.9989 || age f1  1.0 || gender f1 0.9994
# Epoch[11/50](100/237) || training loss -1.099 || training accuracy 99.97% || training f1_score 0.9999 || lr 1.673432436896142e-05
#           training each f1 || mask f1 0.9994 || age f1  1.0 || gender f1 0.9995
# Epoch[11/50](150/237) || training loss -1.097 || training accuracy 99.97% || training f1_score 0.9997 || lr 1.673432436896142e-05
#           training each f1 || mask f1 0.9995 || age f1  1.0 || gender f1 0.9997
# Epoch[11/50](200/237) || training loss -1.097 || training accuracy 100.00% || training f1_score  1.0 || lr 1.673432436896142e-05
#           training each f1 || mask f1 0.9996 || age f1  1.0 || gender f1 0.9998
# Calculating validation results...
# [Val] acc : 83.36%, loss: -0.5661, f1: 0.6607 || best acc : 82.43%, best loss: -0.5713, best f1: 0.6725
# [Val] each f1 || mask f1 0.9985 || age f1 0.6707 || gender f1 0.9925
#
# Epoch[12/50](50/237) || training loss -1.1 || training accuracy 99.84% || training f1_score 0.9987 || lr 1.4224175713617208e-05
#           training each f1 || mask f1 0.9996 || age f1 0.9993 || gender f1 0.9997
# Epoch[12/50](100/237) || training loss -1.099 || training accuracy 99.97% || training f1_score 0.9995 || lr 1.4224175713617208e-05
#           training each f1 || mask f1 0.9998 || age f1 0.9997 || gender f1 0.9997
# Epoch[12/50](150/237) || training loss -1.102 || training accuracy 99.97% || training f1_score 0.9999 || lr 1.4224175713617208e-05
#           training each f1 || mask f1 0.9999 || age f1 0.9997 || gender f1 0.9998
# Epoch[12/50](200/237) || training loss -1.101 || training accuracy 99.97% || training f1_score 0.9999 || lr 1.4224175713617208e-05
#           training each f1 || mask f1 0.9999 || age f1 0.9998 || gender f1 0.9998
# Calculating validation results...
# [Val] acc : 82.04%, loss: -0.5554, f1: 0.665 || best acc : 82.43%, best loss: -0.5713, best f1: 0.6725
# [Val] each f1 || mask f1 0.9985 || age f1 0.6727 || gender f1 0.9903
#
# Epoch[13/50](50/237) || training loss -1.099 || training accuracy 100.00% || training f1_score  1.0 || lr 1.2090549356574626e-05
#           training each f1 || mask f1  1.0 || age f1  1.0 || gender f1  1.0
# Epoch[13/50](100/237) || training loss -1.099 || training accuracy 100.00% || training f1_score  1.0 || lr 1.2090549356574626e-05
#           training each f1 || mask f1  1.0 || age f1  1.0 || gender f1  1.0
# Epoch[13/50](150/237) || training loss -1.101 || training accuracy 99.94% || training f1_score 0.9992 || lr 1.2090549356574626e-05
#           training each f1 || mask f1  1.0 || age f1  1.0 || gender f1 0.9998
# Epoch[13/50](200/237) || training loss -1.1 || training accuracy 99.97% || training f1_score 0.9999 || lr 1.2090549356574626e-05
#           training each f1 || mask f1  1.0 || age f1 0.9999 || gender f1 0.9998
# Calculating validation results...
# [Val] acc : 83.36%, loss: -0.5693, f1: 0.6707 || best acc : 82.43%, best loss: -0.5713, best f1: 0.6725
# [Val] each f1 || mask f1 0.9978 || age f1 0.6867 || gender f1 0.9842
#
# Epoch[14/50](50/237) || training loss -1.102 || training accuracy 100.00% || training f1_score  1.0 || lr 1.0276966953088432e-05
#           training each f1 || mask f1  1.0 || age f1  1.0 || gender f1  1.0
# Epoch[14/50](100/237) || training loss -1.099 || training accuracy 99.97% || training f1_score 0.9997 || lr 1.0276966953088432e-05
#           training each f1 || mask f1 0.9998 || age f1  1.0 || gender f1  1.0
# Epoch[14/50](150/237) || training loss -1.102 || training accuracy 99.94% || training f1_score 0.9977 || lr 1.0276966953088432e-05
#           training each f1 || mask f1 0.9999 || age f1 0.9997 || gender f1 0.9999
# Epoch[14/50](200/237) || training loss -1.104 || training accuracy 100.00% || training f1_score  1.0 || lr 1.0276966953088432e-05
#           training each f1 || mask f1 0.9999 || age f1 0.9998 || gender f1 0.9999
# Calculating validation results...
# [Val] acc : 82.75%, loss: -0.5294, f1: 0.668 || best acc : 82.43%, best loss: -0.5713, best f1: 0.6725
# [Val] each f1 || mask f1 0.9978 || age f1 0.6756 || gender f1 0.9916
#
# Epoch[15/50](50/237) || training loss -1.101 || training accuracy 100.00% || training f1_score  1.0 || lr 8.735421910125167e-06
#           training each f1 || mask f1  1.0 || age f1  1.0 || gender f1  1.0
# Epoch[15/50](100/237) || training loss -1.104 || training accuracy 100.00% || training f1_score  1.0 || lr 8.735421910125167e-06
#           training each f1 || mask f1  1.0 || age f1  1.0 || gender f1  1.0
# Epoch[15/50](150/237) || training loss -1.103 || training accuracy 100.00% || training f1_score  1.0 || lr 8.735421910125167e-06
#           training each f1 || mask f1  1.0 || age f1  1.0 || gender f1  1.0
# Epoch[15/50](200/237) || training loss -1.102 || training accuracy 100.00% || training f1_score  1.0 || lr 8.735421910125167e-06
#           training each f1 || mask f1  1.0 || age f1  1.0 || gender f1  1.0
# Calculating validation results...
# New best model for val f1 : 0.6803! saving the best model..
# [Val] acc : 84.39%, loss: -0.5962, f1: 0.6803 || best acc : 84.39%, best loss: -0.5962, best f1: 0.6803
# [Val] each f1 || mask f1 0.9981 || age f1 0.6875 || gender f1 0.9925
#
# Epoch[16/50](50/237) || training loss -1.104 || training accuracy 100.00% || training f1_score  1.0 || lr 7.425108623606392e-06
#           training each f1 || mask f1  1.0 || age f1  1.0 || gender f1  1.0
# Epoch[16/50](100/237) || training loss -1.108 || training accuracy 100.00% || training f1_score  1.0 || lr 7.425108623606392e-06
#           training each f1 || mask f1  1.0 || age f1  1.0 || gender f1  1.0
# Epoch[16/50](150/237) || training loss -1.103 || training accuracy 99.97% || training f1_score 0.9999 || lr 7.425108623606392e-06
#           training each f1 || mask f1  1.0 || age f1 0.9999 || gender f1  1.0
# Epoch[16/50](200/237) || training loss -1.104 || training accuracy 100.00% || training f1_score  1.0 || lr 7.425108623606392e-06
#           training each f1 || mask f1  1.0 || age f1 0.9999 || gender f1  1.0
# Calculating validation results...
# [Val] acc : 83.07%, loss: -0.5578, f1: 0.6758 || best acc : 84.39%, best loss: -0.5962, best f1: 0.6803
# [Val] each f1 || mask f1 0.9978 || age f1 0.6817 || gender f1 0.9883
#
# Epoch[17/50](50/237) || training loss -1.099 || training accuracy 99.97% || training f1_score 0.9995 || lr 6.3113423300654325e-06
#           training each f1 || mask f1  1.0 || age f1 0.9992 || gender f1  1.0
# Epoch[17/50](100/237) || training loss -1.101 || training accuracy 99.97% || training f1_score 0.9997 || lr 6.3113423300654325e-06
#           training each f1 || mask f1 0.9998 || age f1 0.9996 || gender f1  1.0
# Epoch[17/50](150/237) || training loss -1.104 || training accuracy 99.97% || training f1_score 0.9993 || lr 6.3113423300654325e-06
#           training each f1 || mask f1 0.9999 || age f1 0.9997 || gender f1  1.0
# Epoch[17/50](200/237) || training loss -1.104 || training accuracy 100.00% || training f1_score  1.0 || lr 6.3113423300654325e-06
#           training each f1 || mask f1 0.9999 || age f1 0.9997 || gender f1  1.0
# Calculating validation results...
# [Val] acc : 83.68%, loss: -0.5652, f1: 0.6742 || best acc : 84.39%, best loss: -0.5962, best f1: 0.6803
# [Val] each f1 || mask f1 0.9981 || age f1 0.6811 || gender f1 0.9883
#
# Epoch[18/50](50/237) || training loss -1.106 || training accuracy 100.00% || training f1_score  1.0 || lr 5.3646409805556175e-06
#           training each f1 || mask f1  1.0 || age f1  1.0 || gender f1  1.0
# Epoch[18/50](100/237) || training loss -1.104 || training accuracy 100.00% || training f1_score  1.0 || lr 5.3646409805556175e-06
#           training each f1 || mask f1  1.0 || age f1  1.0 || gender f1  1.0
# Epoch[18/50](150/237) || training loss -1.103 || training accuracy 100.00% || training f1_score  1.0 || lr 5.3646409805556175e-06
#           training each f1 || mask f1  1.0 || age f1  1.0 || gender f1  1.0
# Epoch[18/50](200/237) || training loss -1.104 || training accuracy 100.00% || training f1_score  1.0 || lr 5.3646409805556175e-06
#           training each f1 || mask f1  1.0 || age f1  1.0 || gender f1  1.0
# Calculating validation results...
# [Val] acc : 82.94%, loss: -0.5299, f1: 0.6613 || best acc : 84.39%, best loss: -0.5962, best f1: 0.6803
# [Val] each f1 || mask f1 0.9985 || age f1 0.6708 || gender f1 0.9909
#
# Epoch[19/50](50/237) || training loss -1.102 || training accuracy 100.00% || training f1_score  1.0 || lr 4.559944833472275e-06
#           training each f1 || mask f1  1.0 || age f1  1.0 || gender f1  1.0
# Epoch[19/50](100/237) || training loss -1.107 || training accuracy 100.00% || training f1_score  1.0 || lr 4.559944833472275e-06
#           training each f1 || mask f1  1.0 || age f1  1.0 || gender f1  1.0
# Epoch[19/50](150/237) || training loss -1.103 || training accuracy 99.97% || training f1_score 0.9999 || lr 4.559944833472275e-06
#           training each f1 || mask f1  1.0 || age f1  1.0 || gender f1 0.9999
# Epoch[19/50](200/237) || training loss -1.1 || training accuracy 100.00% || training f1_score  1.0 || lr 4.559944833472275e-06
#           training each f1 || mask f1  1.0 || age f1  1.0 || gender f1 0.9999
# Calculating validation results...
# [Val] acc : 83.70%, loss: -0.5802, f1: 0.6683 || best acc : 84.39%, best loss: -0.5962, best f1: 0.6803
# [Val] each f1 || mask f1 0.9978 || age f1 0.6798 || gender f1 0.9903
#
# Epoch[20/50](50/237) || training loss -1.11 || training accuracy 100.00% || training f1_score  1.0 || lr 3.875953108451433e-06
#           training each f1 || mask f1  1.0 || age f1  1.0 || gender f1  1.0
# Epoch[20/50](100/237) || training loss -1.106 || training accuracy 100.00% || training f1_score  1.0 || lr 3.875953108451433e-06
#           training each f1 || mask f1  1.0 || age f1  1.0 || gender f1  1.0
# Epoch[20/50](150/237) || training loss -1.1 || training accuracy 100.00% || training f1_score  1.0 || lr 3.875953108451433e-06
#           training each f1 || mask f1  1.0 || age f1  1.0 || gender f1  1.0
# Epoch[20/50](200/237) || training loss -1.112 || training accuracy 99.97% || training f1_score 0.9972 || lr 3.875953108451433e-06
#           training each f1 || mask f1  1.0 || age f1 0.9998 || gender f1  1.0
# Calculating validation results...
# [Val] acc : 83.10%, loss: -0.5513, f1: 0.6647 || best acc : 84.39%, best loss: -0.5962, best f1: 0.6803
# [Val] each f1 || mask f1 0.9985 || age f1 0.6728 || gender f1 0.9899
#
# Epoch[21/50](50/237) || training loss -1.106 || training accuracy 100.00% || training f1_score  1.0 || lr 3.2945601421837183e-06
#           training each f1 || mask f1  1.0 || age f1  1.0 || gender f1  1.0
# Epoch[21/50](100/237) || training loss -1.105 || training accuracy 100.00% || training f1_score  1.0 || lr 3.2945601421837183e-06
#           training each f1 || mask f1  1.0 || age f1  1.0 || gender f1  1.0
# Epoch[21/50](150/237) || training loss -1.105 || training accuracy 100.00% || training f1_score  1.0 || lr 3.2945601421837183e-06
#           training each f1 || mask f1  1.0 || age f1  1.0 || gender f1  1.0
# Epoch[21/50](200/237) || training loss -1.105 || training accuracy 100.00% || training f1_score  1.0 || lr 3.2945601421837183e-06
#           training each f1 || mask f1  1.0 || age f1  1.0 || gender f1  1.0
# Calculating validation results...
# [Val] acc : 83.02%, loss: -0.5472, f1: 0.6766 || best acc : 84.39%, best loss: -0.5962, best f1: 0.6803
# [Val] each f1 || mask f1 0.9981 || age f1 0.6798 || gender f1 0.9903
#
# Epoch[22/50](50/237) || training loss -1.102 || training accuracy 100.00% || training f1_score  1.0 || lr 2.8003761208561607e-06
#           training each f1 || mask f1  1.0 || age f1  1.0 || gender f1  1.0
# Epoch[22/50](100/237) || training loss -1.103 || training accuracy 100.00% || training f1_score  1.0 || lr 2.8003761208561607e-06
#           training each f1 || mask f1  1.0 || age f1  1.0 || gender f1  1.0
# Epoch[22/50](150/237) || training loss -1.102 || training accuracy 100.00% || training f1_score  1.0 || lr 2.8003761208561607e-06
#           training each f1 || mask f1  1.0 || age f1  1.0 || gender f1  1.0
# Epoch[22/50](200/237) || training loss -1.11 || training accuracy 99.97% || training f1_score 0.9999 || lr 2.8003761208561607e-06
#           training each f1 || mask f1  1.0 || age f1  1.0 || gender f1 0.9999
# Calculating validation results...
# [Val] acc : 83.47%, loss: -0.5536, f1: 0.6739 || best acc : 84.39%, best loss: -0.5962, best f1: 0.6803
# [Val] each f1 || mask f1 0.9978 || age f1 0.6794 || gender f1 0.9912
#
# Epoch[23/50](50/237) || training loss -1.1 || training accuracy 100.00% || training f1_score  1.0 || lr 2.3803197027277364e-06
#           training each f1 || mask f1  1.0 || age f1  1.0 || gender f1  1.0
# Epoch[23/50](100/237) || training loss -1.104 || training accuracy 100.00% || training f1_score  1.0 || lr 2.3803197027277364e-06
#           training each f1 || mask f1  1.0 || age f1  1.0 || gender f1  1.0
# Epoch[23/50](150/237) || training loss -1.105 || training accuracy 99.97% || training f1_score 0.9971 || lr 2.3803197027277364e-06
#           training each f1 || mask f1  1.0 || age f1 0.9997 || gender f1  1.0
# Epoch[23/50](200/237) || training loss -1.108 || training accuracy 100.00% || training f1_score  1.0 || lr 2.3803197027277364e-06
#           training each f1 || mask f1  1.0 || age f1 0.9998 || gender f1  1.0
# Calculating validation results...
# [Val] acc : 83.54%, loss: -0.5512, f1: 0.6653 || best acc : 84.39%, best loss: -0.5962, best f1: 0.6803
# [Val] each f1 || mask f1 0.9985 || age f1 0.6756 || gender f1 0.9919
#
# Epoch[24/50](50/237) || training loss -1.104 || training accuracy 99.97% || training f1_score 0.9995 || lr 2.0232717473185757e-06
#           training each f1 || mask f1 0.9993 || age f1  1.0 || gender f1  1.0
# Epoch[24/50](100/237) || training loss -1.109 || training accuracy 100.00% || training f1_score  1.0 || lr 2.0232717473185757e-06
#           training each f1 || mask f1 0.9996 || age f1  1.0 || gender f1  1.0
# ...
#           training each f1 || mask f1 0.9999 || age f1  1.0 || gender f1 0.9997
# Calculating validation results...
# [Val] acc : 80.26%, loss: -0.8009, f1: 0.6953 || best acc : 80.13%, best loss: -0.8004, best f1: 0.6977
# [Val] each f1 || mask f1 0.9975 || age f1 0.6921 || gender f1 0.9747
#
# Epoch[12/50](50/237) || training loss -1.103 || training accuracy 99.94% || training f1_score 0.9993 || lr 1.4224175713617208e-05
#           training each f1 || mask f1 0.9993 || age f1  1.0 || gender f1 0.9997
# Epoch[12/50](100/237) || training loss -1.101 || training accuracy 99.97% || training f1_score 0.9996 || lr 1.4224175713617208e-05
#           training each f1 || mask f1 0.9994 || age f1  1.0 || gender f1 0.9998
# Epoch[12/50](150/237) || training loss -1.098 || training accuracy 99.97% || training f1_score 0.9995 || lr 1.4224175713617208e-05
#           training each f1 || mask f1 0.9996 || age f1  1.0 || gender f1 0.9998
# Epoch[12/50](200/237) || training loss -1.103 || training accuracy 100.00% || training f1_score  1.0 || lr 1.4224175713617208e-05
#           training each f1 || mask f1 0.9997 || age f1  1.0 || gender f1 0.9998
# Calculating validation results...
# [Val] acc : 78.36%, loss: -0.7555, f1: 0.6927 || best acc : 80.13%, best loss: -0.8004, best f1: 0.6977
# [Val] each f1 || mask f1 0.9972 || age f1 0.6838 || gender f1 0.975
#
# Epoch[13/50](50/237) || training loss -1.098 || training accuracy 99.97% || training f1_score 0.9994 || lr 1.2090549356574626e-05
#           training each f1 || mask f1  1.0 || age f1  1.0 || gender f1 0.9997
# Epoch[13/50](100/237) || training loss -1.101 || training accuracy 100.00% || training f1_score  1.0 || lr 1.2090549356574626e-05
#           training each f1 || mask f1  1.0 || age f1  1.0 || gender f1 0.9998
# Epoch[13/50](150/237) || training loss -1.103 || training accuracy 99.94% || training f1_score 0.9993 || lr 1.2090549356574626e-05
#           training each f1 || mask f1  1.0 || age f1  1.0 || gender f1 0.9997
# Epoch[13/50](200/237) || training loss -1.104 || training accuracy 100.00% || training f1_score  1.0 || lr 1.2090549356574626e-05
#           training each f1 || mask f1  1.0 || age f1  1.0 || gender f1 0.9998
# Calculating validation results...
# [Val] acc : 76.72%, loss: -0.6729, f1: 0.6684 || best acc : 80.13%, best loss: -0.8004, best f1: 0.6977
# [Val] each f1 || mask f1 0.9972 || age f1 0.6648 || gender f1 0.9733
#
# Epoch[14/50](50/237) || training loss -1.1 || training accuracy 99.97% || training f1_score 0.9999 || lr 1.0276966953088432e-05
#           training each f1 || mask f1  1.0 || age f1  1.0 || gender f1 0.9997
# Epoch[14/50](100/237) || training loss -1.103 || training accuracy 100.00% || training f1_score  1.0 || lr 1.0276966953088432e-05
#           training each f1 || mask f1  1.0 || age f1  1.0 || gender f1 0.9998
# Epoch[14/50](150/237) || training loss -1.105 || training accuracy 99.97% || training f1_score 0.9999 || lr 1.0276966953088432e-05
#           training each f1 || mask f1  1.0 || age f1  1.0 || gender f1 0.9998
# Epoch[14/50](200/237) || training loss -1.102 || training accuracy 100.00% || training f1_score  1.0 || lr 1.0276966953088432e-05
#           training each f1 || mask f1  1.0 || age f1  1.0 || gender f1 0.9998
# Calculating validation results...
# New best model for val f1 : 0.7104! saving the best model..
# [Val] acc : 80.85%, loss: -0.8519, f1: 0.7104 || best acc : 80.85%, best loss: -0.8519, best f1: 0.7104
# [Val] each f1 || mask f1 0.9979 || age f1 0.7126 || gender f1 0.9685
#
# Epoch[15/50](50/237) || training loss -1.101 || training accuracy 100.00% || training f1_score  1.0 || lr 8.735421910125167e-06
#           training each f1 || mask f1  1.0 || age f1  1.0 || gender f1  1.0
# Epoch[15/50](100/237) || training loss -1.099 || training accuracy 99.97% || training f1_score 0.9999 || lr 8.735421910125167e-06
#           training each f1 || mask f1  1.0 || age f1  1.0 || gender f1 0.9998
# Epoch[15/50](150/237) || training loss -1.102 || training accuracy 100.00% || training f1_score  1.0 || lr 8.735421910125167e-06
#           training each f1 || mask f1  1.0 || age f1  1.0 || gender f1 0.9999
# Epoch[15/50](200/237) || training loss -1.103 || training accuracy 99.97% || training f1_score 0.9999 || lr 8.735421910125167e-06
#           training each f1 || mask f1  1.0 || age f1  1.0 || gender f1 0.9998
# Calculating validation results...
# New best model for val f1 : 0.7107! saving the best model..
# [Val] acc : 81.38%, loss: -0.8297, f1: 0.7107 || best acc : 81.38%, best loss: -0.8297, best f1: 0.7107
# [Val] each f1 || mask f1 0.9975 || age f1 0.7086 || gender f1 0.9752
#
# Epoch[16/50](50/237) || training loss -1.102 || training accuracy 99.84% || training f1_score 0.999 || lr 7.425108623606392e-06
#           training each f1 || mask f1  1.0 || age f1  1.0 || gender f1 0.9984
# Epoch[16/50](100/237) || training loss -1.102 || training accuracy 100.00% || training f1_score  1.0 || lr 7.425108623606392e-06
#           training each f1 || mask f1  1.0 || age f1  1.0 || gender f1 0.9992
# Epoch[16/50](150/237) || training loss -1.103 || training accuracy 99.97% || training f1_score 0.9999 || lr 7.425108623606392e-06
#           training each f1 || mask f1  1.0 || age f1 0.9999 || gender f1 0.9994
# Epoch[16/50](200/237) || training loss -1.099 || training accuracy 100.00% || training f1_score  1.0 || lr 7.425108623606392e-06
#           training each f1 || mask f1  1.0 || age f1 0.9999 || gender f1 0.9996
# Calculating validation results...
# [Val] acc : 80.26%, loss: -0.8269, f1: 0.6994 || best acc : 81.38%, best loss: -0.8297, best f1: 0.7107
# [Val] each f1 || mask f1 0.9975 || age f1 0.6989 || gender f1 0.9693
#
# Epoch[17/50](50/237) || training loss -1.103 || training accuracy 100.00% || training f1_score  1.0 || lr 6.3113423300654325e-06
#           training each f1 || mask f1  1.0 || age f1  1.0 || gender f1  1.0
# Epoch[17/50](100/237) || training loss -1.101 || training accuracy 99.97% || training f1_score 0.9999 || lr 6.3113423300654325e-06
#           training each f1 || mask f1  1.0 || age f1  1.0 || gender f1 0.9998
# Epoch[17/50](150/237) || training loss -1.103 || training accuracy 100.00% || training f1_score  1.0 || lr 6.3113423300654325e-06
#           training each f1 || mask f1  1.0 || age f1  1.0 || gender f1 0.9999
# Epoch[17/50](200/237) || training loss -1.103 || training accuracy 100.00% || training f1_score  1.0 || lr 6.3113423300654325e-06
#           training each f1 || mask f1  1.0 || age f1  1.0 || gender f1 0.9999
# Calculating validation results...
# [Val] acc : 79.68%, loss: -0.798, f1: 0.7002 || best acc : 81.38%, best loss: -0.8297, best f1: 0.7107
# [Val] each f1 || mask f1 0.9963 || age f1 0.6989 || gender f1 0.9701
#
# Epoch[18/50](50/237) || training loss -1.106 || training accuracy 100.00% || training f1_score  1.0 || lr 5.3646409805556175e-06
#           training each f1 || mask f1  1.0 || age f1  1.0 || gender f1  1.0
# Epoch[18/50](100/237) || training loss -1.104 || training accuracy 100.00% || training f1_score  1.0 || lr 5.3646409805556175e-06
#           training each f1 || mask f1  1.0 || age f1  1.0 || gender f1  1.0
# Epoch[18/50](150/237) || training loss -1.106 || training accuracy 100.00% || training f1_score  1.0 || lr 5.3646409805556175e-06
#           training each f1 || mask f1  1.0 || age f1  1.0 || gender f1  1.0
# Epoch[18/50](200/237) || training loss -1.105 || training accuracy 100.00% || training f1_score  1.0 || lr 5.3646409805556175e-06
#           training each f1 || mask f1  1.0 || age f1  1.0 || gender f1  1.0
# Calculating validation results...
# [Val] acc : 80.40%, loss: -0.7954, f1: 0.6929 || best acc : 81.38%, best loss: -0.8297, best f1: 0.7107
# [Val] each f1 || mask f1 0.9963 || age f1 0.6984 || gender f1 0.9707
#
# Epoch[19/50](50/237) || training loss -1.105 || training accuracy 100.00% || training f1_score  1.0 || lr 4.559944833472275e-06
#           training each f1 || mask f1  1.0 || age f1  1.0 || gender f1  1.0
# Epoch[19/50](100/237) || training loss -1.107 || training accuracy 100.00% || training f1_score  1.0 || lr 4.559944833472275e-06
#           training each f1 || mask f1  1.0 || age f1  1.0 || gender f1  1.0
# Epoch[19/50](150/237) || training loss -1.1 || training accuracy 100.00% || training f1_score  1.0 || lr 4.559944833472275e-06
#           training each f1 || mask f1  1.0 || age f1  1.0 || gender f1  1.0
# Epoch[19/50](200/237) || training loss -1.105 || training accuracy 100.00% || training f1_score  1.0 || lr 4.559944833472275e-06
#           training each f1 || mask f1  1.0 || age f1  1.0 || gender f1  1.0
# Calculating validation results...
# [Val] acc : 80.29%, loss: -0.8024, f1: 0.7017 || best acc : 81.38%, best loss: -0.8297, best f1: 0.7107
# [Val] each f1 || mask f1 0.9959 || age f1 0.6969 || gender f1 0.9732
#
# Epoch[20/50](50/237) || training loss -1.105 || training accuracy 100.00% || training f1_score  1.0 || lr 3.875953108451433e-06
#           training each f1 || mask f1  1.0 || age f1  1.0 || gender f1  1.0
# Epoch[20/50](100/237) || training loss -1.104 || training accuracy 100.00% || training f1_score  1.0 || lr 3.875953108451433e-06
#           training each f1 || mask f1  1.0 || age f1  1.0 || gender f1  1.0
# Epoch[20/50](150/237) || training loss -1.109 || training accuracy 100.00% || training f1_score  1.0 || lr 3.875953108451433e-06
#           training each f1 || mask f1  1.0 || age f1  1.0 || gender f1  1.0
# Epoch[20/50](200/237) || training loss -1.105 || training accuracy 99.97% || training f1_score 0.9999 || lr 3.875953108451433e-06
#           training each f1 || mask f1  1.0 || age f1 0.9999 || gender f1  1.0
# Calculating validation results...
# [Val] acc : 78.47%, loss: -0.7302, f1: 0.6849 || best acc : 81.38%, best loss: -0.8297, best f1: 0.7107
# [Val] each f1 || mask f1 0.9969 || age f1 0.6805 || gender f1 0.9752
#
# Epoch[21/50](50/237) || training loss -1.103 || training accuracy 100.00% || training f1_score  1.0 || lr 3.2945601421837183e-06
#           training each f1 || mask f1  1.0 || age f1  1.0 || gender f1  1.0
# Epoch[21/50](100/237) || training loss -1.106 || training accuracy 100.00% || training f1_score  1.0 || lr 3.2945601421837183e-06
#           training each f1 || mask f1  1.0 || age f1  1.0 || gender f1  1.0
# Epoch[21/50](150/237) || training loss -1.1 || training accuracy 100.00% || training f1_score  1.0 || lr 3.2945601421837183e-06
#           training each f1 || mask f1  1.0 || age f1  1.0 || gender f1  1.0
# Epoch[21/50](200/237) || training loss -1.103 || training accuracy 100.00% || training f1_score  1.0 || lr 3.2945601421837183e-06
#           training each f1 || mask f1  1.0 || age f1  1.0 || gender f1  1.0
# Calculating validation results...
# [Val] acc : 77.43%, loss: -0.7116, f1: 0.6818 || best acc : 81.38%, best loss: -0.8297, best f1: 0.7107
# [Val] each f1 || mask f1 0.9959 || age f1 0.6759 || gender f1 0.9738
#
# Epoch[22/50](50/237) || training loss -1.106 || training accuracy 100.00% || training f1_score  1.0 || lr 2.8003761208561607e-06
#           training each f1 || mask f1  1.0 || age f1  1.0 || gender f1  1.0
# Epoch[22/50](100/237) || training loss -1.109 || training accuracy 100.00% || training f1_score  1.0 || lr 2.8003761208561607e-06
#           training each f1 || mask f1  1.0 || age f1  1.0 || gender f1  1.0
# Epoch[22/50](150/237) || training loss -1.106 || training accuracy 100.00% || training f1_score  1.0 || lr 2.8003761208561607e-06
#           training each f1 || mask f1  1.0 || age f1  1.0 || gender f1  1.0
# Epoch[22/50](200/237) || training loss -1.105 || training accuracy 100.00% || training f1_score  1.0 || lr 2.8003761208561607e-06
#           training each f1 || mask f1  1.0 || age f1  1.0 || gender f1  1.0
# Calculating validation results...
# [Val] acc : 80.29%, loss: -0.7906, f1: 0.6946 || best acc : 81.38%, best loss: -0.8297, best f1: 0.7107
# [Val] each f1 || mask f1 0.9973 || age f1 0.6938 || gender f1 0.976
#
# Epoch[23/50](50/237) || training loss -1.104 || training accuracy 100.00% || training f1_score  1.0 || lr 2.3803197027277364e-06
#           training each f1 || mask f1  1.0 || age f1  1.0 || gender f1  1.0
# Epoch[23/50](100/237) || training loss -1.105 || training accuracy 100.00% || training f1_score  1.0 || lr 2.3803197027277364e-06
#           training each f1 || mask f1  1.0 || age f1  1.0 || gender f1  1.0
# Epoch[23/50](150/237) || training loss -1.105 || training accuracy 100.00% || training f1_score  1.0 || lr 2.3803197027277364e-06
#           training each f1 || mask f1  1.0 || age f1  1.0 || gender f1  1.0
# Epoch[23/50](200/237) || training loss -1.104 || training accuracy 100.00% || training f1_score  1.0 || lr 2.3803197027277364e-06
#           training each f1 || mask f1  1.0 || age f1  1.0 || gender f1  1.0
# Calculating validation results...
# [Val] acc : 79.15%, loss: -0.7623, f1: 0.6885 || best acc : 81.38%, best loss: -0.8297, best f1: 0.7107
# [Val] each f1 || mask f1 0.9963 || age f1 0.688 || gender f1 0.9749
#
# Epoch[24/50](50/237) || training loss -1.102 || training accuracy 100.00% || training f1_score  1.0 || lr 2.0232717473185757e-06
#           training each f1 || mask f1  1.0 || age f1  1.0 || gender f1  1.0
# Epoch[24/50](100/237) || training loss -1.102 || training accuracy 99.97% || training f1_score 0.9995 || lr 2.0232717473185757e-06
#           training each f1 || mask f1  1.0 || age f1  1.0 || gender f1 0.9998
# Epoch[24/50](150/237) || training loss -1.111 || training accuracy 100.00% || training f1_score  1.0 || lr 2.0232717473185757e-06
#           training each f1 || mask f1  1.0 || age f1  1.0 || gender f1 0.9999
# Epoch[24/50](200/237) || training loss -1.107 || training accuracy 100.00% || training f1_score  1.0 || lr 2.0232717473185757e-06
#           training each f1 || mask f1  1.0 || age f1  1.0 || gender f1 0.9999
# Calculating validation results...
# [Val] acc : 78.36%, loss: -0.7264, f1: 0.6874 || best acc : 81.38%, best loss: -0.8297, best f1: 0.7107
# [Val] each f1 || mask f1 0.9963 || age f1 0.6774 || gender f1 0.9772
#
# Epoch[25/50](50/237) || training loss -1.104 || training accuracy 100.00% || training f1_score  1.0 || lr 1.7197809852207893e-06
#           training each f1 || mask f1  1.0 || age f1  1.0 || gender f1  1.0
# Epoch[25/50](100/237) || training loss -1.104 || training accuracy 100.00% || training f1_score  1.0 || lr 1.7197809852207893e-06
#           training each f1 || mask f1  1.0 || age f1  1.0 || gender f1  1.0
# Epoch[25/50](150/237) || training loss -1.112 || training accuracy 100.00% || training f1_score  1.0 || lr 1.7197809852207893e-06
#           training each f1 || mask f1  1.0 || age f1  1.0 || gender f1  1.0
# Epoch[25/50](200/237) || training loss -1.105 || training accuracy 100.00% || training f1_score  1.0 || lr 1.7197809852207893e-06
#           training each f1 || mask f1  1.0 || age f1  1.0 || gender f1  1.0
# Calculating validation results...
# [Val] acc : 79.97%, loss: -0.7848, f1: 0.6968 || best acc : 81.38%, best loss: -0.8297, best f1: 0.7107
# [Val] each f1 || mask f1 0.9963 || age f1 0.6892 || gender f1 0.9775
#
# Epoch[26/50](50/237) || training loss -1.103 || training accuracy 100.00% || training f1_score  1.0 || lr 1.4618138374376709e-06
#           training each f1 || mask f1  1.0 || age f1  1.0 || gender f1  1.0
# Epoch[26/50](100/237) || training loss -1.103 || training accuracy 100.00% || training f1_score  1.0 || lr 1.4618138374376709e-06
#           training each f1 || mask f1  1.0 || age f1  1.0 || gender f1  1.0
# Epoch[26/50](150/237) || training loss -1.103 || training accuracy 100.00% || training f1_score  1.0 || lr 1.4618138374376709e-06
#           training each f1 || mask f1  1.0 || age f1  1.0 || gender f1  1.0
# Epoch[26/50](200/237) || training loss -1.105 || training accuracy 100.00% || training f1_score  1.0 || lr 1.4618138374376709e-06
#           training each f1 || mask f1  1.0 || age f1  1.0 || gender f1  1.0
# Calculating validation results...
# [Val] acc : 80.08%, loss: -0.7916, f1: 0.6949 || best acc : 81.38%, best loss: -0.8297, best f1: 0.7107
# [Val] each f1 || mask f1 0.9963 || age f1 0.694 || gender f1 0.9743
# Early Stopping!
