# %%
import argparse
import glob
import json
import multiprocessing
import os
import random
import re
from pathlib import Path
from enum import Enum
from typing import Tuple, List
from collections import defaultdict
from sklearn.metrics import f1_score

import cv2
import matplotlib.pyplot as plt
import numpy as np
import torch
import torch.nn as nn
import torch.nn.functional as F
from PIL import Image
from torch.optim import SGD, Adam
from torch.optim.lr_scheduler import StepLR, ReduceLROnPlateau, CosineAnnealingLR
from torch.utils.data import Dataset, Subset, random_split, DataLoader
from torch.utils.tensorboard import SummaryWriter
from torchvision import transforms, models
from albumentations import *
from albumentations.pytorch import ToTensorV2

# %% [markdown]
# # config

# %%
# config
class Config():
    seed = 42
    
    # 데이터
#     data_dir = './face_input/train' #
    data_dir = './input/data/train'
    resize = [224, 224]
    val_ratio = 0.2
    
    # 학습 설정
    epochs = 70
    batch_size = 64
#     batch_size = 16
    valid_batch_size = 1000
    lr = 1e-4
    lr_decay_step = 10
    log_interval = 50
    
    # 세이브 경로
    save_dir = './resnextmultihead_exp'
    

config = Config()

# %%
# 시드 고정 함수
def seed_everything(seed):
    torch.manual_seed(seed)
    torch.cuda.manual_seed(seed)
    torch.cuda.manual_seed_all(seed)  # if use multi-GPU
    torch.backends.cudnn.deterministic = True
    torch.backends.cudnn.benchmark = False
    np.random.seed(seed)
    random.seed(seed)

# %%
# 시드 고정
seed_everything(config.seed)

# %%
 # -- settings
use_cuda = torch.cuda.is_available()
device = torch.device("cuda" if use_cuda else "cpu")

# %% [markdown]
# # Dataset

# %%
# base setting
IMG_EXTENSIONS = [
    ".jpg", ".JPG", ".jpeg", ".JPEG", ".png",
    ".PNG", ".ppm", ".PPM", ".bmp", ".BMP",
]


def is_image_file(filename):
    return any(filename.endswith(extension) for extension in IMG_EXTENSIONS)

class MaskLabels(int, Enum):
    MASK = 0
    INCORRECT = 1
    NORMAL = 2

class GenderLabels(int, Enum):
    MALE = 0
    FEMALE = 1

    @classmethod
    def from_str(cls, value: str) -> int:
        value = value.lower()
        if value == "male":
            return cls.MALE
        elif value == "female":
            return cls.FEMALE
        else:
            raise ValueError(f"Gender value should be either 'male' or 'female', {value}")

class AgeLabels(int, Enum):
    YOUNG = 0
    MIDDLE = 1
    OLD = 2

    @classmethod
    def from_number(cls, value: str) -> int:
        try:
            value = int(value)
        except Exception:
            raise ValueError(f"Age value should be numeric, {value}")

        if value < 30:
            return cls.YOUNG
        elif value < 60:
            return cls.MIDDLE
        else:
            return cls.OLD

# %% [markdown]
# ### define transform (Augmentation)

# %%
mean=(0.548, 0.504, 0.479)
std=(0.237, 0.247, 0.246)
train_transform = Compose([
    CenterCrop(height=440, width=320),
    Resize(config.resize[0], config.resize[1], p=1.0, interpolation=cv2.INTER_LINEAR),
    HorizontalFlip(p=0.5),
#     ShiftScaleRotate(p=0.5),
#     HueSaturationValue(hue_shift_limit=0.2, sat_shift_limit=0.2, val_shift_limit=0.2, p=0.5),
    RandomBrightnessContrast(brightness_limit=(-0.1, 0.1), contrast_limit=(-0.1, 0.1), p=0.5),
    GaussNoise(p=0.5),
    Normalize(mean=mean, std=std, max_pixel_value=255.0, p=1.0),
    ToTensorV2(p=1.0),
], p=1.0)
val_transform = Compose([
    CenterCrop(height=440, width=320),
    Resize(config.resize[0], config.resize[1], p=1.0),
    Normalize(mean=mean, std=std, max_pixel_value=255.0, p=1.0),
    ToTensorV2(p=1.0),
], p=1.0)

# %% [markdown]
# ### define datasets

# %%
# base dataset class
class BaseDataset(Dataset):
    num_classes = 3*2*3
    
    _file_names = {
        "mask1": MaskLabels.MASK,
        "mask2": MaskLabels.MASK,
        "mask3": MaskLabels.MASK,
        "mask4": MaskLabels.MASK,
        "mask5": MaskLabels.MASK,
        "incorrect_mask": MaskLabels.INCORRECT,
        "normal": MaskLabels.NORMAL
    }
    
    image_paths = []
    mask_labels = []
    gender_labels = []
    age_labels = []

    def __init__(self, img_dir, val_ratio=0.2, transform=None):
        """
        MaskBaseDataset을 initialize 합니다.

        Args:
            img_dir: 학습 이미지 폴더의 root directory 입니다.
            transform: Augmentation을 하는 함수입니다.
        """
        self.img_dir = img_dir
        self.transform = transform
        self.indices = defaultdict(list)
        
        self.val_ratio = val_ratio
        
        
        self.setup()

    def set_transform(self, transform):
        """
        transform 함수를 설정하는 함수입니다.
        """
        self.transform = transform
    
    def setup(self):
        """
        image의 경로와 각 이미지들의 label을 계산하여 저장해두는 함수입니다.
        """
        profiles = os.listdir(self.img_dir)
        profiles = [profile for profile in profiles if not profile.startswith(".")]
        split_profiles = self._split_profile(profiles, self.val_ratio)

        cnt = 0
        for phase, indices in split_profiles.items():
            for _idx in indices:
                profile = profiles[_idx]
                img_folder = os.path.join(self.img_dir, profile)
                for file_name in os.listdir(img_folder):
                    _file_name, ext = os.path.splitext(file_name)
                    if _file_name not in self._file_names:  # "." 로 시작하는 파일 및 invalid 한 파일들은 무시합니다
                        continue

                    img_path = os.path.join(self.img_dir, profile, file_name)  # (resized_data, 000004_male_Asian_54, mask1.jpg)
                    mask_label = self._file_names[_file_name]

                    id, gender, race, age = profile.split("_")
                    gender_label = GenderLabels.from_str(gender)
                    age_label = AgeLabels.from_number(age)

                    self.image_paths.append(img_path)
                    self.mask_labels.append(mask_label)
                    self.gender_labels.append(gender_label)
                    self.age_labels.append(age_label)

                    self.indices[phase].append(cnt)
                    cnt += 1
                    
    def split_dataset(self) -> List[Subset]:
        return [Subset(self, indices) for phase, indices in self.indices.items()]
                
    def __getitem__(self, index):
        """
        데이터를 불러오는 함수입니다. 
        데이터셋 class에 데이터 정보가 저장되어 있고, index를 통해 해당 위치에 있는 데이터 정보를 불러옵니다.
        
        Args:
            index: 불러올 데이터의 인덱스값입니다.
        """
        # 이미지를 불러옵니다.
        image_path = self.image_paths[index]
        image = cv2.imread(image_path)
        image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)


#         image = Image.open(image_path)
        
        # 레이블을 불러옵니다.
        mask_label = self.mask_labels[index]
        gender_label = self.gender_labels[index]
        age_label = self.age_labels[index]
        multi_class_label = mask_label * 6 + gender_label * 3 + age_label
        
        # 이미지를 Augmentation 시킵니다.
        image_transform = self.transform(image=np.array(image))['image']
        return image_transform, (mask_label, gender_label, age_label, multi_class_label) # multi_class_label

    def __len__(self):
        return len(self.image_paths)
    
    
    # 이외 utils
    @staticmethod
    def _split_profile(profiles, val_ratio):
        length = len(profiles)
        n_val = int(length * val_ratio)

        val_indices = set(random.choices(range(length), k=n_val))
        train_indices = set(range(length)) - val_indices
        return {
            "train": train_indices,
            "val": val_indices
        }
    
    @staticmethod
    def encode_multi_class(mask_label, gender_label, age_label) -> int:
        return mask_label * 6 + gender_label * 3 + age_label
    
    @staticmethod
    def decode_multi_class(multi_class_label) -> Tuple[MaskLabels, GenderLabels, AgeLabels]:
        mask_label = (multi_class_label // 6) % 3
        gender_label = (multi_class_label // 3) % 2
        age_label = multi_class_label % 3
        return mask_label, gender_label, age_label

# %%
dataset = BaseDataset(img_dir = f'{config.data_dir}/images', val_ratio = config.val_ratio)

train_dataset, val_dataset = dataset.split_dataset()

train_dataset.dataset.set_transform(train_transform)
val_dataset.dataset.set_transform(val_transform)

train_loader = DataLoader(
    train_dataset,
    batch_size=config.batch_size,
    num_workers=multiprocessing.cpu_count() // 2,
    shuffle=True,
    pin_memory=use_cuda
)

val_loader = DataLoader(
    val_dataset,
    batch_size=config.valid_batch_size,
    num_workers=multiprocessing.cpu_count() // 2,
    shuffle=False,
    pin_memory=use_cuda
)

# %% [markdown]
# # define model

# %%
# class BaseModel(nn.Module):
#     def __init__(self, num_classes):
#         super().__init__()
#         self.base_model = models.vit_b_16(pretrained=True)
#         self.base_model.heads.head = nn.Linear(in_features=768, out_features=num_classes, bias=True)

#     def forward(self, x):
#         return self.base_model(x)

# %%
# class ResnextModel(nn.Module):
#     def __init__(self, num_classes):
#         super().__init__()
#         self.base_model = models.resnext50_32x4d(pretrained=True)
#         self.base_model.fc = nn.Sequential(
#             nn.Linear(in_features=2048, out_features=1000, bias=True),
#             nn.ELU(True),
#             nn.Dropout(),
#             nn.Linear(in_features=1000, out_features=num_classes, bias=True)
#         )
#     def forward(self, x):
#         return self.base_model(x)

# %%
# class Resnext101Model(nn.Module):
#     def __init__(self, num_classes):
#         super().__init__()
#         self.base_model = models.resnext101_32x8d(weights=models.ResNeXt101_32X8D_Weights.DEFAULT)
#         self.base_model.fc = nn.Sequential(
#             nn.Linear(in_features=2048, out_features=1000, bias=True),
#             nn.ELU(True),
#             nn.Dropout(),
#             nn.Linear(in_features=1000, out_features=num_classes, bias=True)
#         )
#     def forward(self, x):
#         return self.base_model(x)

# %%
class Identity(nn.Module):
    def __init__(self):
        super(Identity, self).__init__()
        
    def forward(self, x):
        return x
    
class ResnextMultiheadModel(nn.Module):
    def __init__(self):
        super().__init__()
        self.base_model = models.resnext50_32x4d(pretrained=True)
        self.base_model.fc = Identity()
#         self.base_model = nn.Sequential(*list(self.base_model.children())[:-2])
#         self.avgpool = nn.AdaptiveAvgPool2d(output_size=(1, 1))

        self.fc_mask_classifier = nn.Sequential(
            nn.Linear(in_features=2048, out_features=1000, bias=True),
            nn.ELU(True),
            nn.Dropout(0.5, inplace=True),
            nn.Linear(in_features=1000, out_features=3, bias=True)
#             nn.Softmax(dim=1)
        )
        self.fc_age_classifier = nn.Sequential(
            nn.Linear(in_features=2048, out_features=1000, bias=True),
            nn.ELU(True),
            nn.Dropout(0.5, inplace=True),
            nn.Linear(in_features=1000, out_features=1000, bias=True),
            nn.ELU(True),
            nn.Dropout(0.5, inplace=True),
            nn.Linear(in_features=1000, out_features=3, bias=True)
#             nn.Softmax(dim=1)
        )
        self.fc_gender_classifier = nn.Sequential(
            nn.Linear(in_features=2048, out_features=1000, bias=True),
            nn.ELU(True),
            nn.Dropout(0.5, inplace=True),
            nn.Linear(in_features=1000, out_features=2, bias=True)
#             nn.Sigmoid()
        )
    def forward(self, x):
        x = self.base_model(x)
#         x = self.avgpool(x)
#         print(x.shape)
        mask = self.fc_mask_classifier(x)
        age = self.fc_age_classifier(x)
        gender = self.fc_gender_classifier(x)
        return mask, age, gender
#         return x

# %% [markdown]
# # train

# %%
# model
# num_classes = train_dataset.dataset.num_classes
# print(num_classes)
# model = BaseModel(num_classes=num_classes).to(device)
# model = Resnext101Model(num_classes=num_classes).to(device)
# a = torch.tensor(np.ones([64, 3, 224, 224]), dtype=torch.float32).to(device)
model = ResnextMultiheadModel().to(device)
model = torch.nn.DataParallel(model)
# Out:
# /opt/conda/lib/python3.8/site-packages/torchvision/models/_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and will be removed in 0.15, please use 'weights' instead.
#   warnings.warn(
# /opt/conda/lib/python3.8/site-packages/torchvision/models/_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and will be removed in 0.15. The current behavior is equivalent to passing `weights=ResNeXt50_32X4D_Weights.IMAGENET1K_V1`. You can also use `weights=ResNeXt50_32X4D_Weights.DEFAULT` to get the most up-to-date weights.
#   warnings.warn(msg)

# %%
# https://discuss.pytorch.org/t/is-this-a-correct-implementation-for-focal-loss-in-pytorch/43327/8
class FocalLoss(nn.Module):
    def __init__(self, weight=None,
                 gamma=2., reduction='mean'):
        nn.Module.__init__(self)
        self.weight = weight
        self.gamma = gamma
        self.reduction = reduction

    def forward(self, input_tensor, target_tensor):
        log_prob = F.log_softmax(input_tensor, dim=-1)
        prob = torch.exp(log_prob)
        return F.nll_loss(
            ((1 - prob) ** self.gamma) * log_prob,
            target_tensor,
            weight=self.weight,
            reduction=self.reduction
        )

# %% [markdown]
# ### loss , metric , optimizer , scheduler

# %%
criterion = FocalLoss()
optimizer = Adam(
    filter(lambda p: p.requires_grad, model.parameters()),
    lr=config.lr,
    weight_decay=5e-4
)
# scheduler = StepLR(optimizer, config.lr_decay_step, gamma=0.5)
# -- scheduler: ReduceLROnPlateau
# 성능이 향상되지 않을 때 learning rate를 줄입니다. patience=10은 10회 동안 성능 향상이 없을 경우입니다.
# scheduler = ReduceLROnPlateau(optimizer, factor=0.1, patience=10)
# -- scheduler: CosineAnnealingLR
# CosineAnnealing은 learning rate를 cosine 그래프처럼 변화시킵니다.
scheduler = CosineAnnealingLR(optimizer, T_max=2, eta_min=0.)
def get_lr(optimizer):
    for param_group in optimizer.param_groups:
        return param_group['lr']

# %%
# 세이브 경로
path = Path(config.save_dir)
if (not path.exists()):
    save_dir = str(path)
else:
    dirs = glob.glob(f"{path}*")
    matches = [re.search(rf"%s(\d+)" % path.stem, d) for d in dirs]
    i = [int(m.groups()[0]) for m in matches if m]
    n = max(i) + 1 if i else 2
    save_dir = f"{path}{n}"

print("save path : " + save_dir)
# Out:
# save path : resnextmultihead_exp4

# %% [markdown]
# ### start training

# %%
logger = SummaryWriter(log_dir=save_dir)
with open(os.path.join(save_dir, 'config.json'), 'w', encoding='utf-8') as f:
    json.dump(vars(config), f, ensure_ascii=False, indent=4)

# %%
best_val_acc = 0
best_val_loss = np.inf
best_val_f1 = 0
for epoch in range(config.epochs):
    # train loop
    model.train()
    loss_value = 0
    matches = 0
#     f1_sum = 0
    label_list=[]
    pred_list=[]
    mask_label_list=[]
    mask_pred_list=[]
    age_label_list=[]
    age_pred_list=[]
    gender_label_list=[]
    gender_pred_list=[]
    for idx, train_batch in enumerate(train_loader):
        inputs, (mask_labels, gender_labels, age_labels, multi_class_labels) = train_batch
        inputs = inputs.to(device)
        mask_labels = mask_labels.to(device)
        gender_labels = gender_labels.to(device)
        age_labels = age_labels.to(device)
        multi_class_labels = multi_class_labels.to(device)

        optimizer.zero_grad()

        mask_outs, age_outs, gender_outs = model(inputs)
        mask_preds = torch.argmax(mask_outs, dim=-1)
        age_preds = torch.argmax(age_outs, dim=-1)
        gender_preds = torch.argmax(gender_outs, dim=-1)
        
        multi_preds = mask_preds * 6 + gender_preds * 3 + age_preds
        
        mask_loss = criterion(mask_outs, mask_labels)
        age_loss = criterion(age_outs, age_labels)
        gender_loss = criterion(gender_outs, gender_labels)
        
        loss = mask_loss + gender_loss + 2*age_loss
        
        loss.backward()
#         mask_loss.backward()
#         age_loss.backward()
#         gender_loss.backward()
        optimizer.step()
        
        label_list+=multi_class_labels.detach().cpu()
        pred_list+=multi_preds.detach().cpu()
        
        mask_label_list+=mask_labels.detach().cpu()
        mask_pred_list+=mask_preds.detach().cpu()
        age_label_list+=age_labels.detach().cpu()
        age_pred_list+=age_preds.detach().cpu()
        gender_label_list+=gender_labels.detach().cpu()
        gender_pred_list+=gender_preds.detach().cpu()

        loss_value += loss.item()
        matches += (multi_preds == multi_class_labels).sum().item()
#         f1_sum += f1_score(labels.cpu(), preds.cpu(), average='macro')
        if (idx + 1) % config.log_interval == 0:
            train_loss = loss_value / config.log_interval
            train_acc = matches / config.batch_size / config.log_interval
#             train_f1 = f1_sum / config.log_interval
            train_f1 = f1_score(label_list, pred_list, average='macro')
            mask_f1 = f1_score(mask_label_list, mask_pred_list, average='macro')
            age_f1 = f1_score(age_label_list, age_pred_list, average='macro')
            gender_f1 = f1_score(gender_label_list, gender_pred_list, average='macro')
            current_lr = get_lr(optimizer)
            print(
                f"Epoch[{epoch}/{config.epochs}]({idx + 1}/{len(train_loader)}) || "
                f"training loss {train_loss:4.4} || training accuracy {train_acc:4.2%} || training f1_score {train_f1:4.4} || lr {current_lr}"
            )
            print(f"          training each f1 || mask f1 {mask_f1:4.4} || age f1 {age_f1:4.4} || gender f1 {gender_f1:4.4}")
            logger.add_scalar("Train/loss", train_loss, epoch * len(train_loader) + idx)
            logger.add_scalar("Train/accuracy", train_acc, epoch * len(train_loader) + idx)
            logger.add_scalar("Train/f1_score", train_f1, epoch * len(train_loader) + idx)

            loss_value = 0
            matches = 0
#             f1_sum = 0
            label_list=[]
            pred_list=[]

    scheduler.step()

    # val loop
    with torch.no_grad():
        print("Calculating validation results...")
        model.eval()
        val_loss_items = []
        val_acc_items = []
#         val_f1_items = []
        label_list=[]
        pred_list=[]
        mask_label_list=[]
        mask_pred_list=[]
        age_label_list=[]
        age_pred_list=[]
        gender_label_list=[]
        gender_pred_list=[]
        for val_batch in val_loader:
            inputs, (mask_labels, gender_labels, age_labels, multi_class_labels) = val_batch
            inputs = inputs.to(device)
            mask_labels = mask_labels.to(device)
            gender_labels = gender_labels.to(device)
            age_labels = age_labels.to(device)
            multi_class_labels = multi_class_labels.to(device)

            mask_outs, age_outs, gender_outs = model(inputs)
            mask_preds = torch.argmax(mask_outs, dim=-1)
            age_preds = torch.argmax(age_outs, dim=-1)
            gender_preds = torch.argmax(gender_outs, dim=-1)
            multi_preds = mask_preds * 6 + gender_preds * 3 + age_preds
            
            label_list+=multi_class_labels.detach().cpu()
            pred_list+=multi_preds.detach().cpu()
            mask_label_list+=mask_labels.detach().cpu()
            mask_pred_list+=mask_preds.detach().cpu()
            age_label_list+=age_labels.detach().cpu()
            age_pred_list+=age_preds.detach().cpu()
            gender_label_list+=gender_labels.detach().cpu()
            gender_pred_list+=gender_preds.detach().cpu()

#             loss_item = criterion(outs, labels).item() 
            mask_loss = criterion(mask_outs, mask_labels)
            age_loss = criterion(age_outs, age_labels)
            gender_loss = criterion(gender_outs, gender_labels)
            loss = mask_loss + age_loss + gender_loss
            
            acc_item = (multi_class_labels == multi_preds).sum().item()
#             f1_item = f1_score(labels.cpu(), preds.cpu(), average='macro').item()
            val_loss_items.append(loss.item())
            val_acc_items.append(acc_item)
#             val_f1_items.append(f1_item)

        val_loss = float(np.sum(val_loss_items) / len(val_loader))
        val_acc = float(np.sum(val_acc_items) / len(val_dataset))
        val_f1= float(f1_score(label_list,pred_list,average="macro"))
        val_mask_f1 = f1_score(mask_label_list, mask_pred_list, average='macro')
        val_age_f1 = f1_score(age_label_list, age_pred_list, average='macro')
        val_gender_f1 = f1_score(gender_label_list, gender_pred_list, average='macro')
#         val_f1 = np.sum(val_f1_items) / len(val_dataset)
        
#         best_val_loss = min(best_val_loss, val_loss)
#         if val_acc > best_val_acc:
        if val_f1 > best_val_f1:
            print(f"New best model for val f1 : {val_f1:4.4}! saving the best model..")
            torch.save(model.module.state_dict(), f"{save_dir}/best.pth")
            best_val_f1 = val_f1
            best_val_acc = val_acc
            best_val_loss = val_loss
        torch.save(model.module.state_dict(), f"{save_dir}/last.pth")
        print(
            f"[Val] acc : {val_acc:4.2%}, loss: {val_loss:4.4}, f1: {val_f1:4.4} || "
            f"best acc : {best_val_acc:4.2%}, best loss: {best_val_loss:4.4}, best f1: {best_val_f1:4.4}"
        )
        print(f"[Val] each f1 || mask f1 {val_mask_f1:4.4} || age f1 {val_age_f1:4.4} || gender f1 {val_gender_f1:4.4}")
        logger.add_scalar("Val/loss", val_loss, epoch)
        logger.add_scalar("Val/accuracy", val_acc, epoch)
        logger.add_scalar("Val/f1", val_f1, epoch)
        print()
# Out:
# Epoch[0/70](50/242) || training loss 0.4622 || training accuracy 72.28% || training f1_score 0.5562 || lr 0.0001
#           training each f1 || mask f1 0.8939 || age f1 0.6773 || gender f1 0.8964
# Epoch[0/70](100/242) || training loss 0.1736 || training accuracy 87.47% || training f1_score 0.7621 || lr 0.0001
#           training each f1 || mask f1 0.9408 || age f1 0.7516 || gender f1 0.9309
# Epoch[0/70](150/242) || training loss 0.1076 || training accuracy 91.81% || training f1_score 0.8482 || lr 0.0001
#           training each f1 || mask f1 0.9573 || age f1 0.7987 || gender f1 0.947
# Epoch[0/70](200/242) || training loss 0.09275 || training accuracy 93.62% || training f1_score 0.8787 || lr 0.0001
#           training each f1 || mask f1 0.9655 || age f1 0.8286 || gender f1 0.9558
# Calculating validation results...
# New best model for val f1 : 0.783! saving the best model..
# [Val] acc : 87.91%, loss: 0.1226, f1: 0.783 || best acc : 87.91%, best loss: 0.1226, best f1: 0.783
# [Val] each f1 || mask f1 0.9909 || age f1 0.8225 || gender f1 0.9771
#
# Epoch[1/70](50/242) || training loss 0.02625 || training accuracy 98.59% || training f1_score 0.9599 || lr 5e-05
#           training each f1 || mask f1 0.9974 || age f1 0.9828 || gender f1 0.996
# Epoch[1/70](100/242) || training loss 0.01771 || training accuracy 98.88% || training f1_score 0.975 || lr 5e-05
#           training each f1 || mask f1 0.9973 || age f1 0.9833 || gender f1 0.9972
# Epoch[1/70](150/242) || training loss 0.01112 || training accuracy 99.16% || training f1_score 0.9866 || lr 5e-05
#           training each f1 || mask f1 0.9973 || age f1 0.987 || gender f1 0.997
# Epoch[1/70](200/242) || training loss 0.009146 || training accuracy 99.50% || training f1_score 0.9951 || lr 5e-05
#           training each f1 || mask f1 0.9974 || age f1 0.9895 || gender f1 0.9975
# Calculating validation results...
# New best model for val f1 : 0.8149! saving the best model..
# [Val] acc : 90.57%, loss: 0.1538, f1: 0.8149 || best acc : 90.57%, best loss: 0.1538, best f1: 0.8149
# [Val] each f1 || mask f1 0.9923 || age f1 0.8341 || gender f1 0.9859
#
# Epoch[2/70](50/242) || training loss 0.004995 || training accuracy 99.62% || training f1_score 0.9938 || lr 0.0
#           training each f1 || mask f1 0.9965 || age f1 0.9996 || gender f1 0.9987
# Epoch[2/70](100/242) || training loss 0.003928 || training accuracy 99.69% || training f1_score 0.9959 || lr 0.0
#           training each f1 || mask f1 0.9963 || age f1 0.9994 || gender f1 0.9992
# Epoch[2/70](150/242) || training loss 0.004357 || training accuracy 99.75% || training f1_score 0.9917 || lr 0.0
#           training each f1 || mask f1 0.9968 || age f1 0.9991 || gender f1 0.9992
# Epoch[2/70](200/242) || training loss 0.004718 || training accuracy 99.66% || training f1_score 0.9959 || lr 0.0
#           training each f1 || mask f1 0.9967 || age f1 0.9992 || gender f1 0.9992
# Calculating validation results...
# [Val] acc : 90.31%, loss: 0.1556, f1: 0.8121 || best acc : 90.57%, best loss: 0.1538, best f1: 0.8149
# [Val] each f1 || mask f1 0.9927 || age f1 0.8315 || gender f1 0.9849
#
# Epoch[3/70](50/242) || training loss 0.009261 || training accuracy 99.53% || training f1_score 0.9941 || lr 4.9999999999999996e-05
#           training each f1 || mask f1 0.9987 || age f1 0.9967 || gender f1 0.9997
# Epoch[3/70](100/242) || training loss 0.009467 || training accuracy 99.28% || training f1_score 0.9927 || lr 4.9999999999999996e-05
#           training each f1 || mask f1 0.9984 || age f1 0.9968 || gender f1 0.9988
# Epoch[3/70](150/242) || training loss 0.01083 || training accuracy 99.25% || training f1_score 0.9879 || lr 4.9999999999999996e-05
#           training each f1 || mask f1 0.9987 || age f1 0.995 || gender f1 0.9988
# Epoch[3/70](200/242) || training loss 0.01385 || training accuracy 99.06% || training f1_score 0.9849 || lr 4.9999999999999996e-05
#           training each f1 || mask f1 0.9983 || age f1 0.9935 || gender f1 0.9986
# Calculating validation results...
# [Val] acc : 88.47%, loss: 0.2254, f1: 0.794 || best acc : 90.57%, best loss: 0.1538, best f1: 0.8149
# [Val] each f1 || mask f1 0.9967 || age f1 0.8085 || gender f1 0.9855
#
# Epoch[4/70](50/242) || training loss 0.04215 || training accuracy 97.09% || training f1_score 0.93 || lr 0.00010000000000000002
#           training each f1 || mask f1 0.9965 || age f1 0.9596 || gender f1 0.9904
# Epoch[4/70](100/242) || training loss 0.1077 || training accuracy 93.59% || training f1_score 0.839 || lr 0.00010000000000000002
#           training each f1 || mask f1 0.9904 || age f1 0.9384 || gender f1 0.9856
# Epoch[4/70](150/242) || training loss 0.08729 || training accuracy 94.19% || training f1_score 0.8993 || lr 0.00010000000000000002
#           training each f1 || mask f1 0.99 || age f1 0.9391 || gender f1 0.9838
# Epoch[4/70](200/242) || training loss 0.04822 || training accuracy 96.53% || training f1_score 0.938 || lr 0.00010000000000000002
#           training each f1 || mask f1 0.9888 || age f1 0.9486 || gender f1 0.9847
# Calculating validation results...
# [Val] acc : 84.75%, loss: 0.2456, f1: 0.7494 || best acc : 90.57%, best loss: 0.1538, best f1: 0.8149
# [Val] each f1 || mask f1 0.9515 || age f1 0.8059 || gender f1 0.9754
#
# Epoch[5/70](50/242) || training loss 0.02879 || training accuracy 97.88% || training f1_score 0.9631 || lr 5.000000000000002e-05
#           training each f1 || mask f1 0.9931 || age f1 0.9818 || gender f1 0.9956
# Epoch[5/70](100/242) || training loss 0.01724 || training accuracy 98.84% || training f1_score 0.9868 || lr 5.000000000000002e-05
#           training each f1 || mask f1 0.9937 || age f1 0.9872 || gender f1 0.996
# Epoch[5/70](150/242) || training loss 0.008106 || training accuracy 99.38% || training f1_score 0.9907 || lr 5.000000000000002e-05
#           training each f1 || mask f1 0.9954 || age f1 0.99 || gender f1 0.9963
# Epoch[5/70](200/242) || training loss 0.007471 || training accuracy 99.53% || training f1_score 0.9934 || lr 5.000000000000002e-05
#           training each f1 || mask f1 0.9959 || age f1 0.9916 || gender f1 0.9968
# Calculating validation results...
# New best model for val f1 : 0.8407! saving the best model..
# [Val] acc : 91.28%, loss: 0.1825, f1: 0.8407 || best acc : 91.28%, best loss: 0.1825, best f1: 0.8407
# [Val] each f1 || mask f1 0.9975 || age f1 0.8474 || gender f1 0.9883
#
# Epoch[6/70](50/242) || training loss 0.003626 || training accuracy 99.72% || training f1_score 0.9975 || lr 0.0
#           training each f1 || mask f1 0.9984 || age f1 0.9993 || gender f1 0.999
# Epoch[6/70](100/242) || training loss 0.00432 || training accuracy 99.69% || training f1_score 0.9971 || lr 0.0
#           training each f1 || mask f1 0.999 || age f1 0.999 || gender f1 0.999
# Epoch[6/70](150/242) || training loss 0.003032 || training accuracy 99.91% || training f1_score 0.9962 || lr 0.0
#           training each f1 || mask f1 0.9993 || age f1 0.9989 || gender f1 0.9993
# Epoch[6/70](200/242) || training loss 0.002895 || training accuracy 99.88% || training f1_score 0.9986 || lr 0.0
#           training each f1 || mask f1 0.9995 || age f1 0.9988 || gender f1 0.9994
# Calculating validation results...
# [Val] acc : 91.31%, loss: 0.1849, f1: 0.8372 || best acc : 91.28%, best loss: 0.1825, best f1: 0.8407
# [Val] each f1 || mask f1 0.9975 || age f1 0.8456 || gender f1 0.988
#
# Epoch[7/70](50/242) || training loss 0.002665 || training accuracy 99.72% || training f1_score 0.9975 || lr 4.9999999999999996e-05
#           training each f1 || mask f1 0.9988 || age f1 0.9989 || gender f1 0.9984
# Epoch[7/70](100/242) || training loss 0.002396 || training accuracy 99.88% || training f1_score 0.9989 || lr 4.9999999999999996e-05
#           training each f1 || mask f1 0.9991 || age f1 0.9992 || gender f1 0.999
# Epoch[7/70](150/242) || training loss 0.002557 || training accuracy 99.84% || training f1_score 0.9988 || lr 4.9999999999999996e-05
#           training each f1 || mask f1 0.9992 || age f1 0.9993 || gender f1 0.9992
# Epoch[7/70](200/242) || training loss 0.004952 || training accuracy 99.66% || training f1_score 0.9914 || lr 4.9999999999999996e-05
#           training each f1 || mask f1 0.9991 || age f1 0.9987 || gender f1 0.9993
# Calculating validation results...
# [Val] acc : 90.98%, loss: 0.2057, f1: 0.8374 || best acc : 91.28%, best loss: 0.1825, best f1: 0.8407
# [Val] each f1 || mask f1 0.995 || age f1 0.8505 || gender f1 0.9865
#
# Epoch[8/70](50/242) || training loss 0.01833 || training accuracy 98.75% || training f1_score 0.9834 || lr 0.00010000000000000003
#           training each f1 || mask f1 0.989 || age f1 0.9957 || gender f1 0.9984
# Epoch[8/70](100/242) || training loss 0.05109 || training accuracy 97.03% || training f1_score 0.9482 || lr 0.00010000000000000003
#           training each f1 || mask f1 0.9918 || age f1 0.9837 || gender f1 0.9955
# Epoch[8/70](150/242) || training loss 0.07618 || training accuracy 94.53% || training f1_score 0.8873 || lr 0.00010000000000000003
#           training each f1 || mask f1 0.9917 || age f1 0.9729 || gender f1 0.9878
# Epoch[8/70](200/242) || training loss 0.04097 || training accuracy 96.62% || training f1_score 0.9417 || lr 0.00010000000000000003
#           training each f1 || mask f1 0.9923 || age f1 0.9728 || gender f1 0.9873
# Calculating validation results...
# [Val] acc : 88.32%, loss: 0.1699, f1: 0.8097 || best acc : 91.28%, best loss: 0.1825, best f1: 0.8407
# [Val] each f1 || mask f1 0.9967 || age f1 0.829 || gender f1 0.9789
#
# Epoch[9/70](50/242) || training loss 0.02072 || training accuracy 98.53% || training f1_score 0.965 || lr 5.0000000000000036e-05
#           training each f1 || mask f1 0.9959 || age f1 0.9811 || gender f1 0.9963
# Epoch[9/70](100/242) || training loss 0.01128 || training accuracy 99.19% || training f1_score 0.9906 || lr 5.0000000000000036e-05
#           training each f1 || mask f1 0.9974 || age f1 0.9868 || gender f1 0.997
# Epoch[9/70](150/242) || training loss 0.007322 || training accuracy 99.44% || training f1_score 0.9931 || lr 5.0000000000000036e-05
#           training each f1 || mask f1 0.997 || age f1 0.99 || gender f1 0.9975
# Epoch[9/70](200/242) || training loss 0.005736 || training accuracy 99.59% || training f1_score 0.9828 || lr 5.0000000000000036e-05
#           training each f1 || mask f1 0.9971 || age f1 0.9913 || gender f1 0.9978
# Calculating validation results...
# [Val] acc : 92.15%, loss: 0.1598, f1: 0.8399 || best acc : 91.28%, best loss: 0.1825, best f1: 0.8407
# [Val] each f1 || mask f1 0.9971 || age f1 0.8576 || gender f1 0.9879
#
# Epoch[10/70](50/242) || training loss 0.001257 || training accuracy 99.94% || training f1_score 0.9998 || lr 0.0
#           training each f1 || mask f1  1.0 || age f1 0.9998 || gender f1 0.9997
# Epoch[10/70](100/242) || training loss 0.001309 || training accuracy 99.94% || training f1_score 0.9991 || lr 0.0
#           training each f1 || mask f1 0.9998 || age f1 0.9999 || gender f1 0.9997
# Epoch[10/70](150/242) || training loss 0.002616 || training accuracy 99.78% || training f1_score 0.9973 || lr 0.0
#           training each f1 || mask f1 0.9996 || age f1 0.9999 || gender f1 0.9991
# Epoch[10/70](200/242) || training loss 0.003035 || training accuracy 99.84% || training f1_score 0.9965 || lr 0.0
#           training each f1 || mask f1 0.9994 || age f1 0.9995 || gender f1 0.9993
# Calculating validation results...
# [Val] acc : 92.36%, loss: 0.1583, f1: 0.837 || best acc : 91.28%, best loss: 0.1825, best f1: 0.8407
# [Val] each f1 || mask f1 0.9971 || age f1 0.8561 || gender f1 0.9898
#
# Epoch[11/70](50/242) || training loss 0.002652 || training accuracy 99.78% || training f1_score 0.9972 || lr 4.9999999999999996e-05
#           training each f1 || mask f1 0.9996 || age f1 0.9991 || gender f1 0.9983
# Epoch[11/70](100/242) || training loss 0.002272 || training accuracy 99.75% || training f1_score 0.9976 || lr 4.9999999999999996e-05
#           training each f1 || mask f1 0.9991 || age f1 0.9989 || gender f1 0.9988
# Epoch[11/70](150/242) || training loss 0.00107 || training accuracy 99.97% || training f1_score 0.9994 || lr 4.9999999999999996e-05
#           training each f1 || mask f1 0.9992 || age f1 0.9993 || gender f1 0.9992
# Epoch[11/70](200/242) || training loss 0.001974 || training accuracy 99.88% || training f1_score 0.999 || lr 4.9999999999999996e-05
#           training each f1 || mask f1 0.9992 || age f1 0.9993 || gender f1 0.9993
# Calculating validation results...
# New best model for val f1 : 0.8451! saving the best model..
# [Val] acc : 91.69%, loss: 0.164, f1: 0.8451 || best acc : 91.69%, best loss: 0.164, best f1: 0.8451
# [Val] each f1 || mask f1 0.9979 || age f1 0.857 || gender f1 0.9888
#
# Epoch[12/70](50/242) || training loss 0.001481 || training accuracy 99.91% || training f1_score 0.9985 || lr 0.00010000000000000024
#           training each f1 || mask f1 0.9996 || age f1  1.0 || gender f1 0.9993
# Epoch[12/70](100/242) || training loss 0.00114 || training accuracy 99.91% || training f1_score 0.9994 || lr 0.00010000000000000024
#           training each f1 || mask f1 0.9994 || age f1  1.0 || gender f1 0.9995
# Epoch[12/70](150/242) || training loss 0.0009808 || training accuracy 99.94% || training f1_score 0.997 || lr 0.00010000000000000024
#           training each f1 || mask f1 0.9996 || age f1 0.9997 || gender f1 0.9996
# Epoch[12/70](200/242) || training loss 0.01422 || training accuracy 99.00% || training f1_score 0.9737 || lr 0.00010000000000000024
#           training each f1 || mask f1 0.9992 || age f1 0.9956 || gender f1 0.9994
# Calculating validation results...
# [Val] acc : 87.85%, loss: 0.1509, f1: 0.7892 || best acc : 91.69%, best loss: 0.164, best f1: 0.8451
# [Val] each f1 || mask f1 0.9947 || age f1 0.8226 || gender f1 0.9822
#
# Epoch[13/70](50/242) || training loss 0.03666 || training accuracy 97.62% || training f1_score 0.9364 || lr 5.000000000000007e-05
#           training each f1 || mask f1 0.9912 || age f1 0.9823 || gender f1 0.9919
# Epoch[13/70](100/242) || training loss 0.01684 || training accuracy 98.94% || training f1_score 0.9802 || lr 5.000000000000007e-05
#           training each f1 || mask f1 0.9931 || age f1 0.9875 || gender f1 0.9942
# Epoch[13/70](150/242) || training loss 0.01268 || training accuracy 99.28% || training f1_score 0.986 || lr 5.000000000000007e-05
#           training each f1 || mask f1 0.9942 || age f1 0.9903 || gender f1 0.9956
# Epoch[13/70](200/242) || training loss 0.009754 || training accuracy 99.34% || training f1_score 0.9959 || lr 5.000000000000007e-05
#           training each f1 || mask f1 0.9948 || age f1 0.992 || gender f1 0.9963
# Calculating validation results...
# [Val] acc : 91.36%, loss: 0.1771, f1: 0.8215 || best acc : 91.69%, best loss: 0.164, best f1: 0.8451
# [Val] each f1 || mask f1 0.9967 || age f1 0.8335 || gender f1 0.991
#
# Epoch[14/70](50/242) || training loss 0.002709 || training accuracy 99.72% || training f1_score 0.9961 || lr 0.0
#           training each f1 || mask f1 0.9992 || age f1 0.9984 || gender f1 0.9984
# Epoch[14/70](100/242) || training loss 0.004477 || training accuracy 99.62% || training f1_score 0.9964 || lr 0.0
#           training each f1 || mask f1 0.9986 || age f1 0.9987 || gender f1 0.9985
# Epoch[14/70](150/242) || training loss 0.005665 || training accuracy 99.53% || training f1_score 0.9918 || lr 0.0
#           training each f1 || mask f1 0.9984 || age f1 0.9979 || gender f1 0.9985
# Epoch[14/70](200/242) || training loss 0.002754 || training accuracy 99.91% || training f1_score 0.999 || lr 0.0
#           training each f1 || mask f1 0.9987 || age f1 0.9984 || gender f1 0.9987
# Calculating validation results...
# [Val] acc : 90.84%, loss: 0.1767, f1: 0.8258 || best acc : 91.69%, best loss: 0.164, best f1: 0.8451
# [Val] each f1 || mask f1 0.9967 || age f1 0.8348 || gender f1 0.9907
#
# Epoch[15/70](50/242) || training loss 0.002372 || training accuracy 99.94% || training f1_score 0.9997 || lr 4.9999999999999996e-05
#           training each f1 || mask f1 0.9996 || age f1 0.9998 || gender f1  1.0
# Epoch[15/70](100/242) || training loss 0.003244 || training accuracy 99.88% || training f1_score 0.9991 || lr 4.9999999999999996e-05
#           training each f1 || mask f1 0.9991 || age f1 0.9999 || gender f1 0.9998
# Epoch[15/70](150/242) || training loss 0.002444 || training accuracy 99.81% || training f1_score 0.9979 || lr 4.9999999999999996e-05
#           training each f1 || mask f1 0.999 || age f1 0.9998 || gender f1 0.9998
# Epoch[15/70](200/242) || training loss 0.01681 || training accuracy 99.22% || training f1_score 0.9936 || lr 4.9999999999999996e-05
#           training each f1 || mask f1 0.9987 || age f1 0.9983 || gender f1 0.9996
# Calculating validation results...
# [Val] acc : 90.75%, loss: 0.1921, f1: 0.8269 || best acc : 91.69%, best loss: 0.164, best f1: 0.8451
# [Val] each f1 || mask f1 0.9975 || age f1 0.8344 || gender f1 0.9916
#
# Epoch[16/70](50/242) || training loss 0.0009064 || training accuracy 100.00% || training f1_score  1.0 || lr 0.00010000000000000026
#           training each f1 || mask f1  1.0 || age f1  1.0 || gender f1  1.0
# Epoch[16/70](100/242) || training loss 0.002523 || training accuracy 99.78% || training f1_score 0.9981 || lr 0.00010000000000000026
#           training each f1 || mask f1  1.0 || age f1 0.9985 || gender f1 0.9997
# Epoch[16/70](150/242) || training loss 0.06753 || training accuracy 95.78% || training f1_score 0.9119 || lr 0.00010000000000000026
#           training each f1 || mask f1 0.9991 || age f1 0.9809 || gender f1 0.9944
# Epoch[16/70](200/242) || training loss 0.08768 || training accuracy 94.41% || training f1_score 0.9111 || lr 0.00010000000000000026
#           training each f1 || mask f1 0.9966 || age f1 0.9719 || gender f1 0.9919
# Calculating validation results...
# [Val] acc : 87.06%, loss: 0.2129, f1: 0.7409 || best acc : 91.69%, best loss: 0.164, best f1: 0.8451
# [Val] each f1 || mask f1 0.982 || age f1 0.7912 || gender f1 0.9743
#
# Epoch[17/70](50/242) || training loss 0.03693 || training accuracy 97.56% || training f1_score 0.9654 || lr 5.000000000000009e-05
#           training each f1 || mask f1 0.9895 || age f1 0.9822 || gender f1 0.9927
# Epoch[17/70](100/242) || training loss 0.0181 || training accuracy 98.81% || training f1_score 0.9751 || lr 5.000000000000009e-05
#           training each f1 || mask f1 0.9934 || age f1 0.9843 || gender f1 0.9949
# Epoch[17/70](150/242) || training loss 0.01139 || training accuracy 99.44% || training f1_score 0.9881 || lr 5.000000000000009e-05
#           training each f1 || mask f1 0.9955 || age f1 0.9867 || gender f1 0.996
# Epoch[17/70](200/242) || training loss 0.006399 || training accuracy 99.56% || training f1_score 0.9953 || lr 5.000000000000009e-05
#           training each f1 || mask f1 0.9966 || age f1 0.9888 || gender f1 0.9967
# Calculating validation results...
# [Val] acc : 90.40%, loss: 0.1855, f1: 0.8055 || best acc : 91.69%, best loss: 0.164, best f1: 0.8451
# [Val] each f1 || mask f1 0.9964 || age f1 0.8171 || gender f1 0.9874
#
# Epoch[18/70](50/242) || training loss 0.003353 || training accuracy 99.78% || training f1_score 0.9989 || lr 0.0
#           training each f1 || mask f1 0.9987 || age f1 0.9996 || gender f1 0.9993
# Epoch[18/70](100/242) || training loss 0.003077 || training accuracy 99.78% || training f1_score 0.9965 || lr 0.0
#           training each f1 || mask f1 0.9985 || age f1 0.9998 || gender f1 0.999
# Epoch[18/70](150/242) || training loss 0.003373 || training accuracy 99.81% || training f1_score 0.9985 || lr 0.0
#           training each f1 || mask f1 0.9986 || age f1 0.9996 || gender f1 0.9991
# Epoch[18/70](200/242) || training loss 0.003793 || training accuracy 99.75% || training f1_score 0.9937 || lr 0.0
#           training each f1 || mask f1 0.9984 || age f1 0.9992 || gender f1 0.9992
# Calculating validation results...
# [Val] acc : 90.69%, loss: 0.1783, f1: 0.8075 || best acc : 91.69%, best loss: 0.164, best f1: 0.8451
# [Val] each f1 || mask f1 0.9967 || age f1 0.8131 || gender f1 0.9898
#
# Epoch[19/70](50/242) || training loss 0.003278 || training accuracy 99.94% || training f1_score 0.9998 || lr 4.9999999999999996e-05
#           training each f1 || mask f1  1.0 || age f1 0.9996 || gender f1  1.0
# Epoch[19/70](100/242) || training loss 0.001699 || training accuracy 99.91% || training f1_score 0.9992 || lr 4.9999999999999996e-05
#           training each f1 || mask f1 0.9996 || age f1 0.9997 || gender f1 0.9998
# Epoch[19/70](150/242) || training loss 0.001893 || training accuracy 99.88% || training f1_score 0.9984 || lr 4.9999999999999996e-05
#           training each f1 || mask f1 0.9995 || age f1 0.9997 || gender f1 0.9998
# Epoch[19/70](200/242) || training loss 0.003246 || training accuracy 99.66% || training f1_score 0.9937 || lr 4.9999999999999996e-05
#           training each f1 || mask f1 0.9991 || age f1 0.9995 || gender f1 0.9994
# Calculating validation results...
# [Val] acc : 90.60%, loss: 0.1834, f1: 0.8031 || best acc : 91.69%, best loss: 0.164, best f1: 0.8451
# [Val] each f1 || mask f1 0.9971 || age f1 0.8135 || gender f1 0.9877
#
# Epoch[20/70](50/242) || training loss 0.008537 || training accuracy 99.56% || training f1_score 0.9829 || lr 0.00010000000000000028
#           training each f1 || mask f1 0.9982 || age f1 0.9958 || gender f1 0.9983
# Epoch[20/70](100/242) || training loss 0.01251 || training accuracy 99.25% || training f1_score 0.985 || lr 0.00010000000000000028
#           training each f1 || mask f1 0.9987 || age f1 0.9935 || gender f1 0.9981
# Epoch[20/70](150/242) || training loss 0.03718 || training accuracy 97.59% || training f1_score 0.9632 || lr 0.00010000000000000028
#           training each f1 || mask f1 0.998 || age f1 0.9887 || gender f1 0.9957
# Epoch[20/70](200/242) || training loss 0.03119 || training accuracy 97.44% || training f1_score 0.9509 || lr 0.00010000000000000028
#           training each f1 || mask f1 0.9968 || age f1 0.9849 || gender f1 0.9943
# Calculating validation results...
# [Val] acc : 86.42%, loss: 0.2382, f1: 0.735 || best acc : 91.69%, best loss: 0.164, best f1: 0.8451
# [Val] each f1 || mask f1 0.9922 || age f1 0.7909 || gender f1 0.9693
#
# Epoch[21/70](50/242) || training loss 0.02753 || training accuracy 98.16% || training f1_score 0.9654 || lr 5.000000000000012e-05
#           training each f1 || mask f1 0.9951 || age f1 0.9826 || gender f1 0.9964
# Epoch[21/70](100/242) || training loss 0.01041 || training accuracy 99.44% || training f1_score 0.9921 || lr 5.000000000000012e-05
#           training each f1 || mask f1 0.9962 || age f1 0.99 || gender f1 0.9972
# Epoch[21/70](150/242) || training loss 0.005977 || training accuracy 99.62% || training f1_score 0.9962 || lr 5.000000000000012e-05
#           training each f1 || mask f1 0.9968 || age f1 0.9925 || gender f1 0.9979
# Epoch[21/70](200/242) || training loss 0.003864 || training accuracy 99.66% || training f1_score 0.9925 || lr 5.000000000000012e-05
#           training each f1 || mask f1 0.9976 || age f1 0.9936 || gender f1 0.998
# Calculating validation results...
# [Val] acc : 91.22%, loss: 0.1832, f1: 0.8078 || best acc : 91.69%, best loss: 0.164, best f1: 0.8451
# [Val] each f1 || mask f1 0.9971 || age f1 0.8288 || gender f1 0.9877
#
# Epoch[22/70](50/242) || training loss 0.002141 || training accuracy 99.91% || training f1_score 0.9965 || lr 0.0
#           training each f1 || mask f1 0.9993 || age f1 0.9988 || gender f1  1.0
# Epoch[22/70](100/242) || training loss 0.001022 || training accuracy 100.00% || training f1_score  1.0 || lr 0.0
#           training each f1 || mask f1 0.9996 || age f1 0.9994 || gender f1  1.0
# Epoch[22/70](150/242) || training loss 0.001874 || training accuracy 99.94% || training f1_score 0.9992 || lr 0.0
#           training each f1 || mask f1 0.9995 || age f1 0.9996 || gender f1  1.0
# Epoch[22/70](200/242) || training loss 0.002414 || training accuracy 99.78% || training f1_score 0.9971 || lr 0.0
#           training each f1 || mask f1 0.9994 || age f1 0.9994 || gender f1 0.9998
# Calculating validation results...
# [Val] acc : 91.01%, loss: 0.1896, f1: 0.7962 || best acc : 91.69%, best loss: 0.164, best f1: 0.8451
# [Val] each f1 || mask f1 0.9953 || age f1 0.8152 || gender f1 0.9889
#
# Epoch[23/70](50/242) || training loss 0.003653 || training accuracy 99.69% || training f1_score 0.9964 || lr 4.9999999999999996e-05
#           training each f1 || mask f1 0.9993 || age f1 0.9993 || gender f1 0.998
# Epoch[23/70](100/242) || training loss 0.002936 || training accuracy 99.78% || training f1_score 0.998 || lr 4.9999999999999996e-05
#           training each f1 || mask f1 0.9994 || age f1 0.9993 || gender f1 0.9985
# Epoch[23/70](150/242) || training loss 0.002264 || training accuracy 99.78% || training f1_score 0.9978 || lr 4.9999999999999996e-05
#           training each f1 || mask f1 0.9994 || age f1 0.9994 || gender f1 0.9986
# Epoch[23/70](200/242) || training loss 0.00183 || training accuracy 99.88% || training f1_score 0.9968 || lr 4.9999999999999996e-05
#           training each f1 || mask f1 0.9995 || age f1 0.9993 || gender f1 0.9988
# Calculating validation results...
# [Val] acc : 91.16%, loss: 0.2074, f1: 0.7919 || best acc : 91.69%, best loss: 0.164, best f1: 0.8451
# [Val] each f1 || mask f1 0.9969 || age f1 0.8088 || gender f1 0.991
#
# Epoch[24/70](50/242) || training loss 0.00396 || training accuracy 99.69% || training f1_score 0.9978 || lr 0.00010000000000000033
#           training each f1 || mask f1  1.0 || age f1 0.998 || gender f1 0.9997
# Epoch[24/70](100/242) || training loss 0.0228 || training accuracy 98.72% || training f1_score 0.9873 || lr 0.00010000000000000033
#           training each f1 || mask f1 0.9977 || age f1 0.9952 || gender f1 0.999
# Epoch[24/70](150/242) || training loss 0.04078 || training accuracy 96.97% || training f1_score 0.9404 || lr 0.00010000000000000033
#           training each f1 || mask f1 0.997 || age f1 0.986 || gender f1 0.9947
# Epoch[24/70](200/242) || training loss 0.0532 || training accuracy 96.81% || training f1_score 0.947 || lr 0.00010000000000000033
#           training each f1 || mask f1 0.9961 || age f1 0.982 || gender f1 0.9928
# Calculating validation results...
# [Val] acc : 84.22%, loss: 0.2325, f1: 0.7693 || best acc : 91.69%, best loss: 0.164, best f1: 0.8451
# [Val] each f1 || mask f1 0.9923 || age f1 0.8318 || gender f1 0.9394
#
# Epoch[25/70](50/242) || training loss 0.02079 || training accuracy 98.50% || training f1_score 0.9747 || lr 5.000000000000015e-05
#           training each f1 || mask f1 0.9937 || age f1 0.9907 || gender f1 0.9944
# Epoch[25/70](100/242) || training loss 0.007103 || training accuracy 99.38% || training f1_score 0.9905 || lr 5.000000000000015e-05
#           training each f1 || mask f1 0.9954 || age f1 0.9933 || gender f1 0.9962
# Epoch[25/70](150/242) || training loss 0.01093 || training accuracy 99.12% || training f1_score 0.9825 || lr 5.000000000000015e-05
#           training each f1 || mask f1 0.9932 || age f1 0.9944 || gender f1 0.9972
# Epoch[25/70](200/242) || training loss 0.006594 || training accuracy 99.59% || training f1_score 0.9947 || lr 5.000000000000015e-05
#           training each f1 || mask f1 0.9947 || age f1 0.9949 || gender f1 0.9978
# Calculating validation results...
# [Val] acc : 91.39%, loss: 0.1661, f1: 0.8161 || best acc : 91.69%, best loss: 0.164, best f1: 0.8451
# [Val] each f1 || mask f1 0.9954 || age f1 0.8243 || gender f1 0.9913
#
# Epoch[26/70](50/242) || training loss 0.004069 || training accuracy 99.75% || training f1_score 0.9953 || lr 0.0
#           training each f1 || mask f1 0.9971 || age f1 0.9977 || gender f1  1.0
# Epoch[26/70](100/242) || training loss 0.00246 || training accuracy 99.88% || training f1_score 0.9977 || lr 0.0
#           training each f1 || mask f1 0.9982 || age f1 0.9984 || gender f1 0.9998
# Epoch[26/70](150/242) || training loss 0.003845 || training accuracy 99.72% || training f1_score 0.9966 || lr 0.0
#           training each f1 || mask f1 0.9984 || age f1 0.9983 || gender f1 0.9994
# Epoch[26/70](200/242) || training loss 0.004457 || training accuracy 99.66% || training f1_score 0.9959 || lr 0.0
#           training each f1 || mask f1 0.9978 || age f1 0.9983 || gender f1 0.9995
# Calculating validation results...
# [Val] acc : 91.42%, loss: 0.1751, f1: 0.8121 || best acc : 91.69%, best loss: 0.164, best f1: 0.8451
# [Val] each f1 || mask f1 0.995 || age f1 0.8206 || gender f1 0.9919
#
# Epoch[27/70](50/242) || training loss 0.001852 || training accuracy 99.91% || training f1_score 0.9992 || lr 4.9999999999999996e-05
#           training each f1 || mask f1 0.9993 || age f1 0.9992 || gender f1 0.9997
# Epoch[27/70](100/242) || training loss 0.001586 || training accuracy 99.88% || training f1_score 0.9985 || lr 4.9999999999999996e-05
#           training each f1 || mask f1 0.9993 || age f1 0.9993 || gender f1 0.9997
# Epoch[27/70](150/242) || training loss 0.001922 || training accuracy 99.91% || training f1_score 0.9987 || lr 4.9999999999999996e-05
#           training each f1 || mask f1 0.9995 || age f1 0.9995 || gender f1 0.9996
# Epoch[27/70](200/242) || training loss 0.001013 || training accuracy 99.94% || training f1_score 0.9998 || lr 4.9999999999999996e-05
#           training each f1 || mask f1 0.9996 || age f1 0.9996 || gender f1 0.9995
# Calculating validation results...
# [Val] acc : 91.48%, loss: 0.1696, f1: 0.8131 || best acc : 91.69%, best loss: 0.164, best f1: 0.8451
# [Val] each f1 || mask f1 0.9965 || age f1 0.8213 || gender f1 0.9916
#
# Epoch[28/70](50/242) || training loss 0.01931 || training accuracy 99.12% || training f1_score 0.9942 || lr 0.00010000000000000034
#           training each f1 || mask f1 0.9993 || age f1 0.9969 || gender f1 0.9957
# Epoch[28/70](100/242) || training loss 0.05422 || training accuracy 97.25% || training f1_score 0.9478 || lr 0.00010000000000000034
#           training each f1 || mask f1 0.9989 || age f1 0.9805 || gender f1 0.9921
# Epoch[28/70](150/242) || training loss 0.05379 || training accuracy 96.50% || training f1_score 0.9383 || lr 0.00010000000000000034
#           training each f1 || mask f1 0.9988 || age f1 0.9705 || gender f1 0.9909
# Epoch[28/70](200/242) || training loss 0.03197 || training accuracy 97.78% || training f1_score 0.9698 || lr 0.00010000000000000034
#           training each f1 || mask f1 0.9976 || age f1 0.973 || gender f1 0.9908
# Calculating validation results...
# [Val] acc : 89.81%, loss: 0.1617, f1: 0.8081 || best acc : 91.69%, best loss: 0.164, best f1: 0.8451
# [Val] each f1 || mask f1 0.9944 || age f1 0.8274 || gender f1 0.9841
#
# Epoch[29/70](50/242) || training loss 0.0121 || training accuracy 99.25% || training f1_score 0.9853 || lr 5.000000000000017e-05
#           training each f1 || mask f1 0.9974 || age f1 0.9939 || gender f1 0.998
# Epoch[29/70](100/242) || training loss 0.00514 || training accuracy 99.62% || training f1_score 0.9946 || lr 5.000000000000017e-05
#           training each f1 || mask f1 0.9978 || age f1 0.9957 || gender f1 0.9983
# Epoch[29/70](150/242) || training loss 0.006587 || training accuracy 99.59% || training f1_score 0.9904 || lr 5.000000000000017e-05
#           training each f1 || mask f1 0.9974 || age f1 0.9957 || gender f1 0.9988
# Epoch[29/70](200/242) || training loss 0.004411 || training accuracy 99.72% || training f1_score 0.997 || lr 5.000000000000017e-05
#           training each f1 || mask f1 0.9975 || age f1 0.9961 || gender f1 0.999
# Calculating validation results...
# [Val] acc : 90.90%, loss: 0.171, f1: 0.8155 || best acc : 91.69%, best loss: 0.164, best f1: 0.8451
# [Val] each f1 || mask f1 0.9955 || age f1 0.8325 || gender f1 0.9873
#
# Epoch[30/70](50/242) || training loss 0.001718 || training accuracy 99.94% || training f1_score 0.9997 || lr 0.0
#           training each f1 || mask f1 0.9996 || age f1 0.9998 || gender f1  1.0
# Epoch[30/70](100/242) || training loss 0.002229 || training accuracy 99.84% || training f1_score 0.9966 || lr 0.0
#           training each f1 || mask f1 0.9993 || age f1 0.9995 || gender f1 0.9997
# Epoch[30/70](150/242) || training loss 0.004449 || training accuracy 99.88% || training f1_score 0.9978 || lr 0.0
#           training each f1 || mask f1 0.9991 || age f1 0.9994 || gender f1 0.9998
# Epoch[30/70](200/242) || training loss 0.002997 || training accuracy 99.81% || training f1_score 0.9978 || lr 0.0
#           training each f1 || mask f1 0.9988 || age f1 0.9994 || gender f1 0.9998
# Calculating validation results...
# [Val] acc : 91.25%, loss: 0.1839, f1: 0.8231 || best acc : 91.69%, best loss: 0.164, best f1: 0.8451
# [Val] each f1 || mask f1 0.9951 || age f1 0.8375 || gender f1 0.987
#
# Epoch[31/70](50/242) || training loss 0.00236 || training accuracy 99.84% || training f1_score 0.9982 || lr 4.9999999999999996e-05
#           training each f1 || mask f1 0.9974 || age f1 0.9998 || gender f1  1.0
# Epoch[31/70](100/242) || training loss 0.002779 || training accuracy 99.88% || training f1_score 0.9984 || lr 4.9999999999999996e-05
#           training each f1 || mask f1 0.9985 || age f1 0.9994 || gender f1 0.9998
# Epoch[31/70](150/242) || training loss 0.00147 || training accuracy 99.94% || training f1_score 0.999 || lr 4.9999999999999996e-05
#           training each f1 || mask f1 0.9987 || age f1 0.9995 || gender f1 0.9999
# Epoch[31/70](200/242) || training loss 0.002762 || training accuracy 99.91% || training f1_score 0.9991 || lr 4.9999999999999996e-05
#           training each f1 || mask f1 0.999 || age f1 0.9994 || gender f1 0.9999
# Calculating validation results...
# [Val] acc : 91.31%, loss: 0.1764, f1: 0.8233 || best acc : 91.69%, best loss: 0.164, best f1: 0.8451
# [Val] each f1 || mask f1 0.9967 || age f1 0.8329 || gender f1 0.991
#
# Epoch[32/70](50/242) || training loss 0.001634 || training accuracy 99.88% || training f1_score 0.9977 || lr 0.00010000000000000037
#           training each f1 || mask f1  1.0 || age f1  1.0 || gender f1 0.9987
# Epoch[32/70](100/242) || training loss 0.001704 || training accuracy 99.88% || training f1_score 0.9984 || lr 0.00010000000000000037
#           training each f1 || mask f1  1.0 || age f1 0.9996 || gender f1 0.9988
# Epoch[32/70](150/242) || training loss 0.001424 || training accuracy 99.91% || training f1_score 0.9997 || lr 0.00010000000000000037
#           training each f1 || mask f1  1.0 || age f1 0.9997 || gender f1 0.9989
# Epoch[32/70](200/242) || training loss 0.001975 || training accuracy 99.84% || training f1_score 0.9987 || lr 0.00010000000000000037
#           training each f1 || mask f1 0.9999 || age f1 0.9998 || gender f1 0.9988
# Calculating validation results...
# [Val] acc : 88.73%, loss: 0.2004, f1: 0.7734 || best acc : 91.69%, best loss: 0.164, best f1: 0.8451
# [Val] each f1 || mask f1 0.993 || age f1 0.8211 || gender f1 0.9757
#
# Epoch[33/70](50/242) || training loss 0.01211 || training accuracy 99.22% || training f1_score 0.9914 || lr 5.00000000000002e-05
#           training each f1 || mask f1  1.0 || age f1 0.9914 || gender f1 0.998
# Epoch[33/70](100/242) || training loss 0.004482 || training accuracy 99.75% || training f1_score 0.9951 || lr 5.00000000000002e-05
#           training each f1 || mask f1  1.0 || age f1 0.9942 || gender f1 0.9985
# Epoch[33/70](150/242) || training loss 0.005239 || training accuracy 99.59% || training f1_score 0.993 || lr 5.00000000000002e-05
#           training each f1 || mask f1  1.0 || age f1 0.9944 || gender f1 0.9984
# Epoch[33/70](200/242) || training loss 0.008368 || training accuracy 99.22% || training f1_score 0.9781 || lr 5.00000000000002e-05
#           training each f1 || mask f1 0.9998 || age f1 0.994 || gender f1 0.9977
# Calculating validation results...
# [Val] acc : 90.72%, loss: 0.2209, f1: 0.7767 || best acc : 91.69%, best loss: 0.164, best f1: 0.8451
# [Val] each f1 || mask f1 0.9975 || age f1 0.8005 || gender f1 0.9852
#
# Epoch[34/70](50/242) || training loss 0.00506 || training accuracy 99.56% || training f1_score 0.9879 || lr 0.0
#           training each f1 || mask f1  1.0 || age f1 0.9914 || gender f1 0.9993
# Epoch[34/70](100/242) || training loss 0.004496 || training accuracy 99.88% || training f1_score 0.9936 || lr 0.0
#           training each f1 || mask f1 0.9996 || age f1 0.9949 || gender f1 0.9997
# Epoch[34/70](150/242) || training loss 0.003475 || training accuracy 99.81% || training f1_score 0.9978 || lr 0.0
#           training each f1 || mask f1 0.9998 || age f1 0.9955 || gender f1 0.9997
# Epoch[34/70](200/242) || training loss 0.004086 || training accuracy 99.75% || training f1_score 0.9901 || lr 0.0
#           training each f1 || mask f1 0.9997 || age f1 0.9954 || gender f1 0.9997
# Calculating validation results...
# [Val] acc : 90.69%, loss: 0.2342, f1: 0.7661 || best acc : 91.69%, best loss: 0.164, best f1: 0.8451
# [Val] each f1 || mask f1 0.9975 || age f1 0.7887 || gender f1 0.9865
#
# Epoch[35/70](50/242) || training loss 0.001359 || training accuracy 99.97% || training f1_score 0.9993 || lr 4.9999999999999996e-05
#           training each f1 || mask f1  1.0 || age f1  1.0 || gender f1 0.9997
# Epoch[35/70](100/242) || training loss 0.001823 || training accuracy 99.91% || training f1_score 0.999 || lr 4.9999999999999996e-05
#           training each f1 || mask f1 0.9993 || age f1  1.0 || gender f1 0.9998
# Epoch[35/70](150/242) || training loss 0.001334 || training accuracy 99.94% || training f1_score 0.9991 || lr 4.9999999999999996e-05
#           training each f1 || mask f1 0.9994 || age f1 0.9999 || gender f1 0.9999
# Epoch[35/70](200/242) || training loss 0.0006627 || training accuracy 100.00% || training f1_score  1.0 || lr 4.9999999999999996e-05
#           training each f1 || mask f1 0.9996 || age f1 0.9999 || gender f1 0.9999
# Calculating validation results...
# [Val] acc : 92.39%, loss: 0.1841, f1: 0.8377 || best acc : 91.69%, best loss: 0.164, best f1: 0.8451
# [Val] each f1 || mask f1 0.9971 || age f1 0.8472 || gender f1 0.9934
#
# Epoch[36/70](50/242) || training loss 0.000682 || training accuracy 100.00% || training f1_score  1.0 || lr 0.00010000000000000038
#           training each f1 || mask f1  1.0 || age f1  1.0 || gender f1  1.0
# Epoch[36/70](100/242) || training loss 0.003575 || training accuracy 99.72% || training f1_score 0.9942 || lr 0.00010000000000000038
#           training each f1 || mask f1 0.9989 || age f1 0.9983 || gender f1 0.9997
# Epoch[36/70](150/242) || training loss 0.04828 || training accuracy 97.38% || training f1_score 0.9301 || lr 0.00010000000000000038
#           training each f1 || mask f1 0.9988 || age f1 0.9837 || gender f1 0.9978
# Epoch[36/70](200/242) || training loss 0.1042 || training accuracy 93.69% || training f1_score 0.8717 || lr 0.00010000000000000038
#           training each f1 || mask f1 0.9952 || age f1 0.9731 || gender f1 0.9934
# Calculating validation results...
# [Val] acc : 88.64%, loss: 0.1701, f1: 0.8023 || best acc : 91.69%, best loss: 0.164, best f1: 0.8451
# [Val] each f1 || mask f1 0.9922 || age f1 0.8205 || gender f1 0.9856
#
# Epoch[37/70](50/242) || training loss 0.01995 || training accuracy 98.78% || training f1_score 0.9815 || lr 5.000000000000021e-05
#           training each f1 || mask f1 0.9968 || age f1 0.9936 || gender f1 0.9946
# Epoch[37/70](100/242) || training loss 0.006508 || training accuracy 99.47% || training f1_score 0.9884 || lr 5.000000000000021e-05
#           training each f1 || mask f1 0.9975 || age f1 0.9936 || gender f1 0.9965
# Epoch[37/70](150/242) || training loss 0.00895 || training accuracy 99.44% || training f1_score 0.9919 || lr 5.000000000000021e-05
#           training each f1 || mask f1 0.9976 || age f1 0.9945 || gender f1 0.9971
# Epoch[37/70](200/242) || training loss 0.0075 || training accuracy 99.50% || training f1_score 0.9875 || lr 5.000000000000021e-05
#           training each f1 || mask f1 0.9979 || age f1 0.995 || gender f1 0.9974
# Calculating validation results...
# [Val] acc : 90.98%, loss: 0.1815, f1: 0.8181 || best acc : 91.69%, best loss: 0.164, best f1: 0.8451
# [Val] each f1 || mask f1 0.996 || age f1 0.8294 || gender f1 0.9874
#
# Epoch[38/70](50/242) || training loss 0.003576 || training accuracy 99.84% || training f1_score 0.9973 || lr 0.0
#           training each f1 || mask f1 0.9996 || age f1 0.9987 || gender f1 0.9997
# Epoch[38/70](100/242) || training loss 0.002619 || training accuracy 99.84% || training f1_score 0.9989 || lr 0.0
#           training each f1 || mask f1 0.9998 || age f1 0.9991 || gender f1 0.9993
# Epoch[38/70](150/242) || training loss 0.002024 || training accuracy 99.97% || training f1_score 0.9994 || lr 0.0
#           training each f1 || mask f1 0.9999 || age f1 0.9994 || gender f1 0.9994
# Epoch[38/70](200/242) || training loss 0.002023 || training accuracy 99.88% || training f1_score 0.9987 || lr 0.0
#           training each f1 || mask f1 0.9999 || age f1 0.9995 || gender f1 0.9994
# Calculating validation results...
# [Val] acc : 91.07%, loss: 0.1791, f1: 0.8218 || best acc : 91.69%, best loss: 0.164, best f1: 0.8451
# [Val] each f1 || mask f1 0.996 || age f1 0.8335 || gender f1 0.9877
#
# Epoch[39/70](50/242) || training loss 0.001749 || training accuracy 99.91% || training f1_score 0.9992 || lr 4.9999999999999996e-05
#           training each f1 || mask f1  1.0 || age f1  1.0 || gender f1 0.999
# Epoch[39/70](100/242) || training loss 0.001905 || training accuracy 99.94% || training f1_score 0.9993 || lr 4.9999999999999996e-05
#           training each f1 || mask f1 0.9996 || age f1 0.9999 || gender f1 0.9995
# Epoch[39/70](150/242) || training loss 0.001732 || training accuracy 99.97% || training f1_score 0.9994 || lr 4.9999999999999996e-05
#           training each f1 || mask f1 0.9995 || age f1 0.9999 || gender f1 0.9997
# Epoch[39/70](200/242) || training loss 0.002852 || training accuracy 99.84% || training f1_score 0.997 || lr 4.9999999999999996e-05
#           training each f1 || mask f1 0.9995 || age f1 0.9992 || gender f1 0.9998
# Calculating validation results...
# [Val] acc : 91.25%, loss: 0.1716, f1: 0.8233 || best acc : 91.69%, best loss: 0.164, best f1: 0.8451
# [Val] each f1 || mask f1 0.996 || age f1 0.8309 || gender f1 0.9916
#
# Epoch[40/70](50/242) || training loss 0.001751 || training accuracy 99.94% || training f1_score 0.9989 || lr 0.00010000000000000041
#           training each f1 || mask f1 0.9993 || age f1 0.9998 || gender f1  1.0
# Epoch[40/70](100/242) || training loss 0.002014 || training accuracy 99.91% || training f1_score 0.9993 || lr 0.00010000000000000041
#           training each f1 || mask f1 0.9994 || age f1 0.9998 || gender f1 0.9998
# Epoch[40/70](150/242) || training loss 0.006244 || training accuracy 99.72% || training f1_score 0.9983 || lr 0.00010000000000000041
#           training each f1 || mask f1 0.9996 || age f1 0.9992 || gender f1 0.9999
# Epoch[40/70](200/242) || training loss 0.02478 || training accuracy 98.34% || training f1_score 0.9781 || lr 0.00010000000000000041
#           training each f1 || mask f1 0.9997 || age f1 0.9955 || gender f1 0.9983
# Calculating validation results...
# [Val] acc : 86.68%, loss: 0.1988, f1: 0.8033 || best acc : 91.69%, best loss: 0.164, best f1: 0.8451
# [Val] each f1 || mask f1 0.9931 || age f1 0.8193 || gender f1 0.9758
#
# Epoch[41/70](50/242) || training loss 0.02082 || training accuracy 98.47% || training f1_score 0.9733 || lr 5.000000000000059e-05
#           training each f1 || mask f1  1.0 || age f1 0.9806 || gender f1 0.9944
# Epoch[41/70](100/242) || training loss 0.01091 || training accuracy 99.22% || training f1_score 0.9828 || lr 5.000000000000059e-05
#           training each f1 || mask f1 0.9993 || age f1 0.9869 || gender f1 0.9952
# Epoch[41/70](150/242) || training loss 0.004875 || training accuracy 99.69% || training f1_score 0.9961 || lr 5.000000000000059e-05
#           training each f1 || mask f1 0.9995 || age f1 0.9907 || gender f1 0.9961
# Epoch[41/70](200/242) || training loss 0.001851 || training accuracy 99.91% || training f1_score 0.9963 || lr 5.000000000000059e-05
#           training each f1 || mask f1 0.9996 || age f1 0.9931 || gender f1 0.9969
# Calculating validation results...
# [Val] acc : 91.16%, loss: 0.1521, f1: 0.8411 || best acc : 91.69%, best loss: 0.164, best f1: 0.8451
# [Val] each f1 || mask f1 0.9964 || age f1 0.8445 || gender f1 0.9916
#
# Epoch[42/70](50/242) || training loss 0.002794 || training accuracy 99.91% || training f1_score 0.9941 || lr 0.0
#           training each f1 || mask f1  1.0 || age f1 0.9988 || gender f1 0.9997
# Epoch[42/70](100/242) || training loss 0.00382 || training accuracy 99.72% || training f1_score 0.991 || lr 0.0
#           training each f1 || mask f1  1.0 || age f1 0.9966 || gender f1 0.9997
# Epoch[42/70](150/242) || training loss 0.003663 || training accuracy 99.78% || training f1_score 0.9952 || lr 0.0
#           training each f1 || mask f1  1.0 || age f1 0.9965 || gender f1 0.9996
# Epoch[42/70](200/242) || training loss 0.001977 || training accuracy 99.97% || training f1_score 0.9995 || lr 0.0
#           training each f1 || mask f1  1.0 || age f1 0.9972 || gender f1 0.9997
# Calculating validation results...
# [Val] acc : 91.13%, loss: 0.1524, f1: 0.8381 || best acc : 91.69%, best loss: 0.164, best f1: 0.8451
# [Val] each f1 || mask f1 0.9964 || age f1 0.8413 || gender f1 0.9907
#
# Epoch[43/70](50/242) || training loss 0.001661 || training accuracy 99.94% || training f1_score 0.999 || lr 4.9999999999999996e-05
#           training each f1 || mask f1  1.0 || age f1 0.9992 || gender f1 0.9997
# Epoch[43/70](100/242) || training loss 0.001976 || training accuracy 99.91% || training f1_score 0.9996 || lr 4.9999999999999996e-05
#           training each f1 || mask f1  1.0 || age f1 0.9994 || gender f1 0.9997
# Epoch[43/70](150/242) || training loss 0.00169 || training accuracy 99.91% || training f1_score 0.9977 || lr 4.9999999999999996e-05
#           training each f1 || mask f1  1.0 || age f1 0.9989 || gender f1 0.9998
# Epoch[43/70](200/242) || training loss 0.002638 || training accuracy 99.75% || training f1_score 0.9976 || lr 4.9999999999999996e-05
#           training each f1 || mask f1 0.9996 || age f1 0.9992 || gender f1 0.9995
# Calculating validation results...
# [Val] acc : 91.39%, loss: 0.1663, f1: 0.8284 || best acc : 91.69%, best loss: 0.164, best f1: 0.8451
# [Val] each f1 || mask f1 0.9962 || age f1 0.8286 || gender f1 0.9925
#
# Epoch[44/70](50/242) || training loss 0.0008203 || training accuracy 99.97% || training f1_score 0.9965 || lr 0.00010000000000000044
#           training each f1 || mask f1  1.0 || age f1  1.0 || gender f1 0.9997
# Epoch[44/70](100/242) || training loss 0.007903 || training accuracy 99.44% || training f1_score 0.9881 || lr 0.00010000000000000044
#           training each f1 || mask f1 0.9966 || age f1  1.0 || gender f1 0.9993
# Epoch[44/70](150/242) || training loss 0.01511 || training accuracy 98.75% || training f1_score 0.9756 || lr 0.00010000000000000044
#           training each f1 || mask f1 0.9936 || age f1 0.9984 || gender f1 0.9989
# Epoch[44/70](200/242) || training loss 0.02553 || training accuracy 98.19% || training f1_score 0.9764 || lr 0.00010000000000000044
#           training each f1 || mask f1 0.9928 || age f1 0.9942 || gender f1 0.9978
# Calculating validation results...
# [Val] acc : 81.76%, loss: 0.2755, f1: 0.7453 || best acc : 91.69%, best loss: 0.164, best f1: 0.8451
# [Val] each f1 || mask f1 0.9897 || age f1 0.7554 || gender f1 0.9715
#
# Epoch[45/70](50/242) || training loss 0.0288 || training accuracy 97.94% || training f1_score 0.9619 || lr 5.000000000000027e-05
#           training each f1 || mask f1 0.9965 || age f1 0.9817 || gender f1 0.9925
# Epoch[45/70](100/242) || training loss 0.01469 || training accuracy 98.84% || training f1_score 0.9814 || lr 5.000000000000027e-05
#           training each f1 || mask f1 0.9959 || age f1 0.9848 || gender f1 0.9949
# Epoch[45/70](150/242) || training loss 0.007385 || training accuracy 99.59% || training f1_score 0.996 || lr 5.000000000000027e-05
#           training each f1 || mask f1 0.9971 || age f1 0.9882 || gender f1 0.9964
# Epoch[45/70](200/242) || training loss 0.005425 || training accuracy 99.75% || training f1_score 0.9975 || lr 5.000000000000027e-05
#           training each f1 || mask f1 0.9977 || age f1 0.9911 || gender f1 0.997
# Calculating validation results...
# [Val] acc : 92.04%, loss: 0.1427, f1: 0.8442 || best acc : 91.69%, best loss: 0.164, best f1: 0.8451
# [Val] each f1 || mask f1 0.9979 || age f1 0.8534 || gender f1 0.9925
#
# Epoch[46/70](50/242) || training loss 0.001503 || training accuracy 100.00% || training f1_score  1.0 || lr 0.0
# ...
# Epoch[54/70](200/242) || training loss 0.001306 || training accuracy 100.00% || training f1_score  1.0 || lr 0.0
#           training each f1 || mask f1 0.9991 || age f1 0.9998 || gender f1  1.0
# Calculating validation results...
# [Val] acc : 91.72%, loss: 0.1813, f1: 0.8186 || best acc : 92.10%, best loss: 0.1413, best f1: 0.8555
# [Val] each f1 || mask f1 0.9944 || age f1 0.833 || gender f1 0.9904
#
# Epoch[55/70](50/242) || training loss 0.001159 || training accuracy 99.97% || training f1_score 0.9998 || lr 4.9999999999999996e-05
#           training each f1 || mask f1 0.9996 || age f1  1.0 || gender f1  1.0
# Epoch[55/70](100/242) || training loss 0.001973 || training accuracy 99.94% || training f1_score 0.9967 || lr 4.9999999999999996e-05
#           training each f1 || mask f1 0.9994 || age f1 0.9996 || gender f1  1.0
# Epoch[55/70](150/242) || training loss 0.00198 || training accuracy 99.91% || training f1_score 0.9987 || lr 4.9999999999999996e-05
#           training each f1 || mask f1 0.9992 || age f1 0.9996 || gender f1  1.0
# Epoch[55/70](200/242) || training loss 0.004307 || training accuracy 99.72% || training f1_score 0.9976 || lr 4.9999999999999996e-05
#           training each f1 || mask f1 0.9992 || age f1 0.9996 || gender f1 0.9996
# Calculating validation results...
# [Val] acc : 91.92%, loss: 0.1724, f1: 0.8312 || best acc : 92.10%, best loss: 0.1413, best f1: 0.8555
# [Val] each f1 || mask f1 0.9971 || age f1 0.8485 || gender f1 0.9934
#
# Epoch[56/70](50/242) || training loss 0.001419 || training accuracy 99.97% || training f1_score 0.9999 || lr 9.999999999999979e-05
#           training each f1 || mask f1  1.0 || age f1 0.9998 || gender f1  1.0
# Epoch[56/70](100/242) || training loss 0.001666 || training accuracy 99.91% || training f1_score 0.999 || lr 9.999999999999979e-05
#           training each f1 || mask f1 0.9993 || age f1 0.9999 || gender f1 0.9998
# Epoch[56/70](150/242) || training loss 0.001285 || training accuracy 99.94% || training f1_score 0.9995 || lr 9.999999999999979e-05
#           training each f1 || mask f1 0.9993 || age f1 0.9999 || gender f1 0.9998
# Epoch[56/70](200/242) || training loss 0.003201 || training accuracy 99.72% || training f1_score 0.9976 || lr 9.999999999999979e-05
#           training each f1 || mask f1 0.9995 || age f1 0.9998 || gender f1 0.9993
# Calculating validation results...
# [Val] acc : 89.84%, loss: 0.1889, f1: 0.7958 || best acc : 92.10%, best loss: 0.1413, best f1: 0.8555
# [Val] each f1 || mask f1 0.9959 || age f1 0.8227 || gender f1 0.9846
#
# Epoch[57/70](50/242) || training loss 0.01068 || training accuracy 99.41% || training f1_score 0.9944 || lr 5.000000000000034e-05
#           training each f1 || mask f1 0.9993 || age f1 0.9971 || gender f1 0.9984
# Epoch[57/70](100/242) || training loss 0.009663 || training accuracy 99.28% || training f1_score 0.9909 || lr 5.000000000000034e-05
#           training each f1 || mask f1 0.9989 || age f1 0.9967 || gender f1 0.9975
# Epoch[57/70](150/242) || training loss 0.002788 || training accuracy 99.88% || training f1_score 0.9966 || lr 5.000000000000034e-05
#           training each f1 || mask f1 0.9993 || age f1 0.9975 || gender f1 0.998
# Epoch[57/70](200/242) || training loss 0.002608 || training accuracy 99.81% || training f1_score 0.9944 || lr 5.000000000000034e-05
#           training each f1 || mask f1 0.9995 || age f1 0.9974 || gender f1 0.9983
# Calculating validation results...
# [Val] acc : 92.07%, loss: 0.1809, f1: 0.8376 || best acc : 92.10%, best loss: 0.1413, best f1: 0.8555
# [Val] each f1 || mask f1 0.9949 || age f1 0.8484 || gender f1 0.9904
#
# Epoch[58/70](50/242) || training loss 0.001206 || training accuracy 100.00% || training f1_score  1.0 || lr 0.0
#           training each f1 || mask f1  1.0 || age f1  1.0 || gender f1  1.0
# Epoch[58/70](100/242) || training loss 0.001452 || training accuracy 99.94% || training f1_score 0.9977 || lr 0.0
#           training each f1 || mask f1  1.0 || age f1 0.9992 || gender f1  1.0
# Epoch[58/70](150/242) || training loss 0.001461 || training accuracy 99.97% || training f1_score 0.9995 || lr 0.0
#           training each f1 || mask f1  1.0 || age f1 0.9991 || gender f1  1.0
# Epoch[58/70](200/242) || training loss 0.001306 || training accuracy 99.97% || training f1_score 0.9999 || lr 0.0
#           training each f1 || mask f1  1.0 || age f1 0.9993 || gender f1  1.0
# Calculating validation results...
# [Val] acc : 92.13%, loss: 0.1879, f1: 0.8321 || best acc : 92.10%, best loss: 0.1413, best f1: 0.8555
# [Val] each f1 || mask f1 0.9949 || age f1 0.8406 || gender f1 0.9919
#
# Epoch[59/70](50/242) || training loss 0.001219 || training accuracy 100.00% || training f1_score  1.0 || lr 4.9999999999999996e-05
#           training each f1 || mask f1  1.0 || age f1  1.0 || gender f1  1.0
# Epoch[59/70](100/242) || training loss 0.0007953 || training accuracy 100.00% || training f1_score  1.0 || lr 4.9999999999999996e-05
#           training each f1 || mask f1  1.0 || age f1  1.0 || gender f1  1.0
# Epoch[59/70](150/242) || training loss 0.0008927 || training accuracy 100.00% || training f1_score  1.0 || lr 4.9999999999999996e-05
#           training each f1 || mask f1  1.0 || age f1  1.0 || gender f1  1.0
# Epoch[59/70](200/242) || training loss 0.0007711 || training accuracy 99.97% || training f1_score 0.9999 || lr 4.9999999999999996e-05
#           training each f1 || mask f1  1.0 || age f1 0.9999 || gender f1  1.0
# Calculating validation results...
# [Val] acc : 92.18%, loss: 0.1807, f1: 0.8385 || best acc : 92.10%, best loss: 0.1413, best f1: 0.8555
# [Val] each f1 || mask f1 0.9958 || age f1 0.8436 || gender f1 0.9907
#
# Epoch[60/70](50/242) || training loss 0.002136 || training accuracy 99.81% || training f1_score 0.9964 || lr 0.00010000000000000055
#           training each f1 || mask f1  1.0 || age f1 0.9991 || gender f1 0.9983
# Epoch[60/70](100/242) || training loss 0.01084 || training accuracy 99.31% || training f1_score 0.9812 || lr 0.00010000000000000055
#           training each f1 || mask f1  1.0 || age f1 0.9953 || gender f1 0.9975
# Epoch[60/70](150/242) || training loss 0.06743 || training accuracy 95.75% || training f1_score 0.9185 || lr 0.00010000000000000055
#           training each f1 || mask f1 0.9956 || age f1 0.9814 || gender f1 0.9947
# Epoch[60/70](200/242) || training loss 0.05074 || training accuracy 96.78% || training f1_score 0.9465 || lr 0.00010000000000000055
#           training each f1 || mask f1 0.995 || age f1 0.9779 || gender f1 0.994
# Calculating validation results...
# [Val] acc : 88.64%, loss: 0.2138, f1: 0.7687 || best acc : 92.10%, best loss: 0.1413, best f1: 0.8555
# [Val] each f1 || mask f1 0.9941 || age f1 0.7866 || gender f1 0.9771
#
# Epoch[61/70](50/242) || training loss 0.01607 || training accuracy 98.72% || training f1_score 0.9824 || lr 5.0000000000000375e-05
#           training each f1 || mask f1 0.9947 || age f1 0.9914 || gender f1 0.9953
# Epoch[61/70](100/242) || training loss 0.007623 || training accuracy 99.47% || training f1_score 0.9926 || lr 5.0000000000000375e-05
#           training each f1 || mask f1 0.9958 || age f1 0.9943 || gender f1 0.9965
# Epoch[61/70](150/242) || training loss 0.007524 || training accuracy 99.59% || training f1_score 0.9951 || lr 5.0000000000000375e-05
#           training each f1 || mask f1 0.9964 || age f1 0.9957 || gender f1 0.9969
# Epoch[61/70](200/242) || training loss 0.002653 || training accuracy 99.88% || training f1_score 0.9958 || lr 5.0000000000000375e-05
#           training each f1 || mask f1 0.9972 || age f1 0.9966 || gender f1 0.9975
# Calculating validation results...
# [Val] acc : 91.77%, loss: 0.1606, f1: 0.8237 || best acc : 92.10%, best loss: 0.1413, best f1: 0.8555
# [Val] each f1 || mask f1 0.9967 || age f1 0.8364 || gender f1 0.9907
#
# Epoch[62/70](50/242) || training loss 0.002357 || training accuracy 99.91% || training f1_score 0.9988 || lr 0.0
#           training each f1 || mask f1 0.9986 || age f1  1.0 || gender f1  1.0
# Epoch[62/70](100/242) || training loss 0.002286 || training accuracy 99.84% || training f1_score 0.999 || lr 0.0
#           training each f1 || mask f1 0.9991 || age f1 0.9999 || gender f1 0.9993
# Epoch[62/70](150/242) || training loss 0.001531 || training accuracy 100.00% || training f1_score  1.0 || lr 0.0
#           training each f1 || mask f1 0.9994 || age f1 0.9999 || gender f1 0.9996
# Epoch[62/70](200/242) || training loss 0.002806 || training accuracy 99.84% || training f1_score 0.9953 || lr 0.0
#           training each f1 || mask f1 0.9991 || age f1 0.9999 || gender f1 0.9996
# Calculating validation results...
# [Val] acc : 91.74%, loss: 0.1639, f1: 0.8209 || best acc : 92.10%, best loss: 0.1413, best f1: 0.8555
# [Val] each f1 || mask f1 0.9967 || age f1 0.8359 || gender f1 0.9904
#
# Epoch[63/70](50/242) || training loss 0.00319 || training accuracy 99.78% || training f1_score 0.9972 || lr 4.9999999999999996e-05
#           training each f1 || mask f1 0.9977 || age f1 0.9992 || gender f1 0.9997
# Epoch[63/70](100/242) || training loss 0.0017 || training accuracy 99.94% || training f1_score 0.9995 || lr 4.9999999999999996e-05
#           training each f1 || mask f1 0.9985 || age f1 0.9995 || gender f1 0.9998
# Epoch[63/70](150/242) || training loss 0.001129 || training accuracy 99.97% || training f1_score 0.9999 || lr 4.9999999999999996e-05
#           training each f1 || mask f1 0.999 || age f1 0.9996 || gender f1 0.9999
# Epoch[63/70](200/242) || training loss 0.0009148 || training accuracy 100.00% || training f1_score  1.0 || lr 4.9999999999999996e-05
#           training each f1 || mask f1 0.9993 || age f1 0.9997 || gender f1 0.9999
# Calculating validation results...
# [Val] acc : 91.92%, loss: 0.1618, f1: 0.8351 || best acc : 92.10%, best loss: 0.1413, best f1: 0.8555
# [Val] each f1 || mask f1 0.996 || age f1 0.8428 || gender f1 0.9928
#
# Epoch[64/70](50/242) || training loss 0.0007927 || training accuracy 100.00% || training f1_score  1.0 || lr 9.999999999999984e-05
#           training each f1 || mask f1  1.0 || age f1  1.0 || gender f1  1.0
# Epoch[64/70](100/242) || training loss 0.0006412 || training accuracy 100.00% || training f1_score  1.0 || lr 9.999999999999984e-05
#           training each f1 || mask f1  1.0 || age f1  1.0 || gender f1  1.0
# Epoch[64/70](150/242) || training loss 0.002633 || training accuracy 99.91% || training f1_score 0.9985 || lr 9.999999999999984e-05
#           training each f1 || mask f1  1.0 || age f1 0.9992 || gender f1  1.0
# Epoch[64/70](200/242) || training loss 0.01051 || training accuracy 99.25% || training f1_score 0.9864 || lr 9.999999999999984e-05
#           training each f1 || mask f1  1.0 || age f1 0.9969 || gender f1 0.9993
# Calculating validation results...
# [Val] acc : 88.91%, loss: 0.1932, f1: 0.7826 || best acc : 92.10%, best loss: 0.1413, best f1: 0.8555
# [Val] each f1 || mask f1 0.9963 || age f1 0.8071 || gender f1 0.9771
#
# Epoch[65/70](50/242) || training loss 0.0157 || training accuracy 99.09% || training f1_score 0.9835 || lr 5.000000000000039e-05
#           training each f1 || mask f1 0.9996 || age f1 0.9881 || gender f1 0.9986
# Epoch[65/70](100/242) || training loss 0.007054 || training accuracy 99.56% || training f1_score 0.9923 || lr 5.000000000000039e-05
#           training each f1 || mask f1 0.9998 || age f1 0.9911 || gender f1 0.9988
# Epoch[65/70](150/242) || training loss 0.005154 || training accuracy 99.78% || training f1_score 0.9976 || lr 5.000000000000039e-05
#           training each f1 || mask f1 0.9999 || age f1 0.9932 || gender f1 0.9989
# Epoch[65/70](200/242) || training loss 0.002116 || training accuracy 99.84% || training f1_score 0.9973 || lr 5.000000000000039e-05
#           training each f1 || mask f1 0.9999 || age f1 0.9943 || gender f1 0.999
# Calculating validation results...
# [Val] acc : 91.33%, loss: 0.1776, f1: 0.805 || best acc : 92.10%, best loss: 0.1413, best f1: 0.8555
# [Val] each f1 || mask f1 0.996 || age f1 0.8217 || gender f1 0.9913
#
# Epoch[66/70](50/242) || training loss 0.001239 || training accuracy 99.97% || training f1_score 0.9985 || lr 0.0
#           training each f1 || mask f1  1.0 || age f1 0.9991 || gender f1  1.0
# Epoch[66/70](100/242) || training loss 0.001041 || training accuracy 99.97% || training f1_score 0.9996 || lr 0.0
#           training each f1 || mask f1 0.9998 || age f1 0.9995 || gender f1  1.0
# Epoch[66/70](150/242) || training loss 0.0013 || training accuracy 99.97% || training f1_score 0.9995 || lr 0.0
#           training each f1 || mask f1 0.9999 || age f1 0.9994 || gender f1  1.0
# Epoch[66/70](200/242) || training loss 0.001065 || training accuracy 99.97% || training f1_score 0.9995 || lr 0.0
#           training each f1 || mask f1 0.9999 || age f1 0.9994 || gender f1  1.0
# Calculating validation results...
# [Val] acc : 91.39%, loss: 0.1757, f1: 0.8128 || best acc : 92.10%, best loss: 0.1413, best f1: 0.8555
# [Val] each f1 || mask f1 0.996 || age f1 0.8259 || gender f1 0.9913
#
# Epoch[67/70](50/242) || training loss 0.001365 || training accuracy 99.97% || training f1_score 0.9976 || lr 4.9999999999999996e-05
#           training each f1 || mask f1 0.9996 || age f1  1.0 || gender f1  1.0
# Epoch[67/70](100/242) || training loss 0.0008344 || training accuracy 100.00% || training f1_score  1.0 || lr 4.9999999999999996e-05
#           training each f1 || mask f1 0.9998 || age f1  1.0 || gender f1  1.0
# Epoch[67/70](150/242) || training loss 0.001032 || training accuracy 99.97% || training f1_score 0.9995 || lr 4.9999999999999996e-05
#           training each f1 || mask f1 0.9999 || age f1  1.0 || gender f1 0.9999
# Epoch[67/70](200/242) || training loss 0.0008194 || training accuracy 100.00% || training f1_score  1.0 || lr 4.9999999999999996e-05
#           training each f1 || mask f1 0.9999 || age f1  1.0 || gender f1 0.9999
# Calculating validation results...
# [Val] acc : 91.74%, loss: 0.1604, f1: 0.8199 || best acc : 92.10%, best loss: 0.1413, best f1: 0.8555
# [Val] each f1 || mask f1 0.9967 || age f1 0.8315 || gender f1 0.9922
#
# Epoch[68/70](50/242) || training loss 0.001239 || training accuracy 100.00% || training f1_score  1.0 || lr 0.00010000000000000059
#           training each f1 || mask f1  1.0 || age f1  1.0 || gender f1  1.0
# Epoch[68/70](100/242) || training loss 0.001084 || training accuracy 99.97% || training f1_score 0.9998 || lr 0.00010000000000000059
#           training each f1 || mask f1 0.9998 || age f1  1.0 || gender f1  1.0
# Epoch[68/70](150/242) || training loss 0.001045 || training accuracy 99.97% || training f1_score 0.9992 || lr 0.00010000000000000059
#           training each f1 || mask f1 0.9996 || age f1  1.0 || gender f1  1.0
# Epoch[68/70](200/242) || training loss 0.0008413 || training accuracy 100.00% || training f1_score  1.0 || lr 0.00010000000000000059
#           training each f1 || mask f1 0.9997 || age f1  1.0 || gender f1  1.0
# Calculating validation results...
# [Val] acc : 92.51%, loss: 0.1519, f1: 0.8362 || best acc : 92.10%, best loss: 0.1413, best f1: 0.8555
# [Val] each f1 || mask f1 0.9955 || age f1 0.8447 || gender f1 0.994
#
# Epoch[69/70](50/242) || training loss 0.0005696 || training accuracy 100.00% || training f1_score  1.0 || lr 5.0000000000000416e-05
#           training each f1 || mask f1  1.0 || age f1  1.0 || gender f1  1.0
# Epoch[69/70](100/242) || training loss 0.0008836 || training accuracy 100.00% || training f1_score  1.0 || lr 5.0000000000000416e-05
#           training each f1 || mask f1  1.0 || age f1  1.0 || gender f1  1.0
# Epoch[69/70](150/242) || training loss 0.0007351 || training accuracy 100.00% || training f1_score  1.0 || lr 5.0000000000000416e-05
#           training each f1 || mask f1  1.0 || age f1  1.0 || gender f1  1.0
# Epoch[69/70](200/242) || training loss 0.0006014 || training accuracy 100.00% || training f1_score  1.0 || lr 5.0000000000000416e-05
#           training each f1 || mask f1  1.0 || age f1  1.0 || gender f1  1.0
# Calculating validation results...
# [Val] acc : 92.36%, loss: 0.148, f1: 0.8381 || best acc : 92.10%, best loss: 0.1413, best f1: 0.8555
# [Val] each f1 || mask f1 0.9971 || age f1 0.8437 || gender f1 0.9922
