# %%
import argparse
import glob
import json
import multiprocessing
import os
import random
import re
from pathlib import Path
from enum import Enum
from typing import Tuple, List
from collections import defaultdict
from sklearn.metrics import f1_score

import cv2
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import torch
import torch.nn as nn
import torch.nn.functional as F
from PIL import Image
from torch.optim import SGD, Adam, RMSprop, AdamW
from adamp import AdamP
from torch.optim.lr_scheduler import StepLR, ReduceLROnPlateau, CosineAnnealingLR, ExponentialLR
from torch.utils.data import Dataset, Subset, random_split, DataLoader
from torch.utils.tensorboard import SummaryWriter
from torchvision import transforms, models
from albumentations import *
from albumentations.pytorch import ToTensorV2
from torchsampler import ImbalancedDatasetSampler

# %% [markdown]
# # config

# %%
# config
class Config():
    seed = 42
    
    # 데이터
#     data_dir = './face_input/train' #
    data_dir = './input/data/train'
#     resize = [256, 256]
    resize = [224, 224]
    val_ratio = 0.2
    
    # 학습 설정
    epochs = 50
    batch_size = 52
#     batch_size = 16
    valid_batch_size = 1000
    lr = 0.0001
    lr_decay_step = 10
    log_interval = 50
    
    # 세이브 경로
    save_dir = './newModel_exp'
    

config = Config()

# %%
# 시드 고정 함수
def seed_everything(seed):
    torch.manual_seed(seed)
    torch.cuda.manual_seed(seed)
    torch.cuda.manual_seed_all(seed)  # if use multi-GPU
    torch.backends.cudnn.deterministic = True
    torch.backends.cudnn.benchmark = False
    np.random.seed(seed)
    random.seed(seed)

# %%
# 시드 고정
seed_everything(config.seed)

# %%
 # -- settings
use_cuda = torch.cuda.is_available()
device = torch.device("cuda" if use_cuda else "cpu")

# %% [markdown]
# # Dataset

# %%
# base setting
IMG_EXTENSIONS = [
    ".jpg", ".JPG", ".jpeg", ".JPEG", ".png",
    ".PNG", ".ppm", ".PPM", ".bmp", ".BMP",
]


def is_image_file(filename):
    return any(filename.endswith(extension) for extension in IMG_EXTENSIONS)

class MaskLabels(int, Enum):
    MASK = 0
    INCORRECT = 1
    NORMAL = 2

class GenderLabels(int, Enum):
    MALE = 0
    FEMALE = 1

    @classmethod
    def from_str(cls, value: str) -> int:
        value = value.lower()
        if value == "male":
            return cls.MALE
        elif value == "female":
            return cls.FEMALE
        else:
            raise ValueError(f"Gender value should be either 'male' or 'female', {value}")

class AgeLabels(int, Enum):
    YOUNG = 0
    MIDDLE = 1
    OLD = 2
    
    @classmethod
    def class2number(cls, value: int) -> int:
        if value <= 2:
            return cls.YOUNG
        elif value <= 8:
            return cls.MIDDLE
        else:
            return cls.OLD
        
    @classmethod
    def from_cls(cls, value: str) -> int:
        try:
            value = int(value)
        except Exception:
            raise ValueError(f"Age value should be numeric, {value}")

        if value < 20:
            return 0
        elif value < 25:
            return 1
        elif value < 30:
            return 2
        elif value < 35:
            return 3
        elif value < 40:
            return 4
        elif value < 45:
            return 5
        elif value < 50:
            return 6
        elif value < 55:
            return 7
        elif value < 60:
            return 8
        else:
            return 9

# %% [markdown]
# ### define transform (Augmentation)

# %%
mean=(0.548, 0.504, 0.479)
std=(0.237, 0.247, 0.246)
train_transform = Compose([
    RandomCrop(height=460, width=320),
    HorizontalFlip(p=0.5),
#     ShiftScaleRotate(p=0.5),
    HueSaturationValue(hue_shift_limit=0.2, sat_shift_limit=0.2, val_shift_limit=0.2, p=0.5),
    RandomScale(scale_limit=0.1, interpolation=cv2.INTER_LINEAR, p=0.5),
    RandomBrightnessContrast(brightness_limit=(-0.2, 0.2), contrast_limit=(-0.2, 0.2), p=0.5),
    GaussNoise(p=0.5),
    Resize(config.resize[0], config.resize[1], p=1.0, interpolation=cv2.INTER_LINEAR),
    Normalize(mean=mean, std=std, max_pixel_value=255.0, p=1.0),
    ToTensorV2(p=1.0),
], p=1.0)
val_transform = Compose([
    CenterCrop(height=460, width=320),
    Resize(config.resize[0], config.resize[1], p=1.0),
    Normalize(mean=mean, std=std, max_pixel_value=255.0, p=1.0),
    ToTensorV2(p=1.0),
], p=1.0)

# %% [markdown]
# ### define datasets

# %%
class newBaseDataset(Dataset):

    def __init__(self, img_dir, indices, transform=None):
        """
        MaskBaseDataset을 initialize 합니다.

        Args:
            img_dir: 학습 이미지 폴더의 root directory 입니다.
            transform: Augmentation을 하는 함수입니다.
        """
        self.img_dir = img_dir
        self.transform = transform
        self.indices = indices
        self._file_names = {
            "mask1": MaskLabels.MASK,
            "mask2": MaskLabels.MASK,
            "mask3": MaskLabels.MASK,
            "mask4": MaskLabels.MASK,
            "mask5": MaskLabels.MASK,
            "incorrect_mask": MaskLabels.INCORRECT,
            "normal": MaskLabels.NORMAL
        }

        self.image_paths = []
        self.mask_labels = []
        self.gender_labels = []
        self.age_labels = []
        self.setup()

    def set_transform(self, transform):
        """
        transform 함수를 설정하는 함수입니다.
        """
        self.transform = transform

    def setup(self):
        """
        image의 경로와 각 이미지들의 label을 계산하여 저장해두는 함수입니다.
        """
        csv_path = os.path.join(self.img_dir, 'train.csv')
        csv_data = pd.read_csv(csv_path)
        
        csv_data = csv_data.loc[self.indices]
        csv_data_list = list(csv_data.values)
        cnt = 0
        for id, gender, _, age, path in csv_data_list:
            img_folder = os.path.join(self.img_dir, 'images', path)
            for file_name in os.listdir(img_folder):
                _file_name, ext = os.path.splitext(file_name)
                if _file_name not in self._file_names:  # "." 로 시작하는 파일 및 invalid 한 파일들은 무시합니다
                    continue
                    
                img_path = os.path.join(img_folder, file_name)  # (data_path, 000004_male_Asian_54, mask1.jpg)
                mask_label = self._file_names[_file_name]
                gender_label = GenderLabels.from_str(gender)
                age_label = AgeLabels.from_cls(age)
                self.image_paths.append(img_path)
                self.mask_labels.append(mask_label)
                self.gender_labels.append(gender_label)
                self.age_labels.append(age_label)
                
    def __getitem__(self, index):
        """
        데이터를 불러오는 함수입니다. 
        데이터셋 class에 데이터 정보가 저장되어 있고, index를 통해 해당 위치에 있는 데이터 정보를 불러옵니다.
        
        Args:
            index: 불러올 데이터의 인덱스값입니다.
        """
        # 이미지를 불러옵니다.
        image_path = self.image_paths[index]
        image = cv2.imread(image_path)
        image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
#         image = Image.open(image_path)
        
        # 레이블을 불러옵니다.
        mask_label = self.mask_labels[index]
        gender_label = self.gender_labels[index]
        age_label = self.age_labels[index]
        multi_class_label = mask_label * 6 + gender_label * 3 + AgeLabels.class2number(age_label)
        
        # 이미지를 Augmentation 시킵니다.
        image_transform = self.transform(image=np.array(image))['image']
        return image_transform, (mask_label, gender_label, age_label, multi_class_label) # multi_class_label

    def __len__(self):
        return len(self.image_paths)

# %%
# class Sampler(ImbalancedDatasetSampler):
#     def _get_labels(self, dataset):
#         return [dataset.dataset.class_list[i] for i in dataset.indices]

# class Sampler(ImbalancedDatasetSampler):
#     def _get_labels(self, dataset):
#         return dataset.age_labels

# %%
csv_path = os.path.join(config.data_dir,'train.csv')
data = pd.read_csv(csv_path)
age_0 = data['age'][lambda x : (x < 20)].count()
age_1 = data['age'][lambda x : (x >= 20) & (x<25)].count()
age_2 = data['age'][lambda x : (x >= 25) & (x<30)].count()
age_3 = data['age'][lambda x : (x >= 30) & (x<35)].count()
age_4 = data['age'][lambda x : (x >= 35) & (x<40)].count()
age_5 = data['age'][lambda x : (x >= 40) & (x<45)].count()
age_6 = data['age'][lambda x : (x >= 45) & (x<50)].count()
age_7 = data['age'][lambda x : (x >= 50) & (x<55)].count()
age_8 = data['age'][lambda x : (x >= 55) & (x<60)].count()
age_9 = data['age'][lambda x : x >= 60].count()
age_img_num_per_cls =  torch.Tensor([age_0, age_1, age_2, age_3, age_4, age_5, age_6, age_7, age_8, age_9])

length = len(data)
n_val = int(length * config.val_ratio)
val_indices = set(random.choices(range(length), k=n_val))
train_indices = set(range(length)) - val_indices

# %%
train_dataset = newBaseDataset(img_dir = config.data_dir, indices = train_indices)
val_dataset = newBaseDataset(img_dir = config.data_dir, indices = val_indices)
train_dataset.set_transform(train_transform)
val_dataset.set_transform(val_transform)
train_loader = DataLoader(
    train_dataset,
    batch_size=config.batch_size,
    num_workers=multiprocessing.cpu_count() // 2,
#     sampler=Sampler(train_dataset),
    shuffle=True,
    drop_last=True,
    pin_memory=use_cuda
    
)
val_loader = DataLoader(
    val_dataset,
    batch_size=config.valid_batch_size,
    num_workers=multiprocessing.cpu_count() // 2,
    shuffle=False,
    pin_memory=use_cuda
)

# %% [markdown]
# # define model

# %%
class Identity(nn.Module):
    def __init__(self):
        super(Identity, self).__init__()
        
    def forward(self, x):
        return x

# %%
# class SwinMultiheadModel(nn.Module):
#     def __init__(self):
#         super().__init__()
#         self.base_model = models.swin_b(weights='DEFAULT')
#         self.base_model.head = Identity()

#         self.fc_mask_head = nn.Sequential(
#             nn.Linear(in_features=1024, out_features=1000, bias=True),
#             nn.BatchNorm1d(1000),
#             nn.ELU(True),
#             nn.Dropout(0.5, inplace=True),
#             nn.Linear(in_features=1000, out_features=3, bias=True)
#         )
#         self.fc_gender_head = nn.Sequential(
#             nn.Linear(in_features=1024, out_features=1000, bias=True),
#             nn.BatchNorm1d(1000),
#             nn.ELU(True),
#             nn.Dropout(0.5, inplace=True),
#             nn.Linear(in_features=1000, out_features=2, bias=True)
#         )
#     def forward(self, x):
#         x = self.base_model(x)
#         mask = self.fc_mask_head(x)
#         gender = self.fc_gender_head(x)
#         return mask, gender

# %%
# class SwinAgeModel(nn.Module):
#     def __init__(self):
#         super().__init__()
#         self.base_model = models.swin_b(weights='DEFAULT')
#         self.base_model.head = nn.Sequential(
#             nn.Linear(in_features=1024, out_features=1000, bias=True),
#             nn.BatchNorm1d(1000),
#             nn.ELU(True),
#             nn.Dropout(0.5, inplace=True),
#             nn.Linear(in_features=1000, out_features=1000, bias=True),
#             nn.BatchNorm1d(1000),
#             nn.ELU(True),
#             nn.Dropout(0.5, inplace=True),
#             nn.Linear(in_features=1000, out_features=10, bias=True)
#         )
#     def forward(self, x):
#         x = self.base_model(x)
#         return x

# %%
class ResMultiheadModel(nn.Module):
    def __init__(self):
        super().__init__()
        self.base_model = models.resnext101_32x8d(weights=models.ResNeXt101_32X8D_Weights.DEFAULT)
        self.base_model.fc = Identity()

        self.fc_mask = nn.Sequential(
            nn.Linear(in_features=2048, out_features=1000, bias=True),
            nn.BatchNorm1d(1000),
            nn.ELU(True),
            nn.Dropout(0.5, inplace=True),
            nn.Linear(in_features=1000, out_features=3, bias=True)
        )
        self.fc_gender = nn.Sequential(
            nn.Linear(in_features=2048, out_features=1000, bias=True),
            nn.BatchNorm1d(1000),
            nn.ELU(True),
            nn.Dropout(0.5, inplace=True),
            nn.Linear(in_features=1000, out_features=2, bias=True)
        )
    def forward(self, x):
        x = self.base_model(x)
        mask = self.fc_mask(x)
        gender = self.fc_gender(x)
        return mask, gender

# %%
class ResAgeModel(nn.Module):
    def __init__(self):
        super().__init__()
        self.base_model = models.resnext101_32x8d(weights=models.ResNeXt101_32X8D_Weights.DEFAULT)
        self.base_model.fc = nn.Sequential(
            nn.Linear(in_features=2048, out_features=1000, bias=True),
            nn.BatchNorm1d(1000),
            nn.ELU(True),
            nn.Dropout(0.5, inplace=True),
            nn.Linear(in_features=1000, out_features=1000, bias=True),
            nn.BatchNorm1d(1000),
            nn.ELU(True),
            nn.Dropout(0.5, inplace=True),
            nn.Linear(in_features=1000, out_features=10, bias=True)
        )
    def forward(self, x):
        x = self.base_model(x)
        return x

# %%
model_multi = ResMultiheadModel()
model_age = ResAgeModel()
model_multi = model_multi.to(device)
model_age = model_age.to(device)

# %% [markdown]
# # train

# %%
# https://discuss.pytorch.org/t/is-this-a-correct-implementation-for-focal-loss-in-pytorch/43327/8
class FocalLoss(nn.Module):
    def __init__(self, weight=None,
                 gamma=2., reduction='mean'):
        nn.Module.__init__(self)
        self.weight = weight
        self.gamma = gamma
        self.reduction = reduction

    def forward(self, input_tensor, target_tensor):
        log_prob = F.log_softmax(input_tensor, dim=-1)
        prob = torch.exp(log_prob)
        return F.nll_loss(
            ((1 - prob) ** self.gamma) * log_prob,
            target_tensor,
            weight=self.weight,
            reduction=self.reduction
        )
class LADELoss(nn.Module):
    def __init__(self, num_classes=10, img_num_per_cls=None, remine_lambda=0.1):
        super().__init__()
        if img_num_per_cls is not None:
#             self.img_num_per_cls = calculate_prior(num_classes, img_max, prior, prior_txt, return_num=True).float().cuda()
            self.img_num_per_cls = img_num_per_cls
            self.prior = self.img_num_per_cls / self.img_num_per_cls.sum()
        else:
            self.prior = None
        self.prior = self.prior.to(device)
        self.balanced_prior = torch.tensor(1. / num_classes).float().cuda()
        self.remine_lambda = remine_lambda

        self.num_classes = num_classes
        self.cls_weight = (self.img_num_per_cls.float() / torch.sum(self.img_num_per_cls.float())).cuda()

    def mine_lower_bound(self, x_p, x_q, num_samples_per_cls):
        N = x_p.size(-1)
        first_term = torch.sum(x_p, -1) / (num_samples_per_cls + 1e-8)
        second_term = torch.logsumexp(x_q, -1) - np.log(N)

        return first_term - second_term, first_term, second_term

    def remine_lower_bound(self, x_p, x_q, num_samples_per_cls):
        loss, first_term, second_term = self.mine_lower_bound(x_p, x_q, num_samples_per_cls)
        reg = (second_term ** 2) * self.remine_lambda
        return loss - reg, first_term, second_term

    def forward(self, y_pred, target, q_pred=None):
        """
        y_pred: N x C
        target: N
        """
        per_cls_pred_spread = y_pred.T * (target == torch.arange(0, self.num_classes).view(-1, 1).type_as(target))  # C x N
        pred_spread = (y_pred - torch.log(self.prior + 1e-9) + torch.log(self.balanced_prior + 1e-9)).T  # C x N

        num_samples_per_cls = torch.sum(target == torch.arange(0, self.num_classes).view(-1, 1).type_as(target), -1).float()  # C
        estim_loss, first_term, second_term = self.remine_lower_bound(per_cls_pred_spread, pred_spread, num_samples_per_cls)

        loss = -torch.sum(estim_loss * self.cls_weight)
        return loss

# %% [markdown]
# ### loss , metric , optimizer , scheduler

# %%
# criterion = FocalLoss()

criterion_mask = FocalLoss() #F1Loss(classes=3)
criterion_age = LADELoss(num_classes=10, img_num_per_cls=age_img_num_per_cls) #F1Loss(classes=3)
criterion_gender = FocalLoss() #F1Loss(classes=2)
optimizer_multi = AdamP(
    filter(lambda p: p.requires_grad, model_multi.parameters()),
    lr=config.lr,
    weight_decay=5e-4
)
optimizer_age = AdamP(
    filter(lambda p: p.requires_grad, model_age.parameters()),
    lr=config.lr,
    weight_decay=5e-4
)
# scheduler = StepLR(optimizer, config.lr_decay_step, gamma=0.5)
scheduler_multi = CosineAnnealingLR(optimizer_multi, T_max=2, eta_min=0.)
scheduler_age = CosineAnnealingLR(optimizer_age, T_max=2, eta_min=0.)
# -- scheduler: ReduceLROnPlateau
# 성능이 향상되지 않을 때 learning rate를 줄입니다. patience=10은 10회 동안 성능 향상이 없을 경우입니다.
# scheduler = ReduceLROnPlateau(optimizer, factor=0.1, patience=10)
# -- scheduler: CosineAnnealingLR
# CosineAnnealing은 learning rate를 cosine 그래프처럼 변화시킵니다.
# scheduler = CosineAnnealingLR(optimizer, T_max=2, eta_min=0.)
def get_lr(optimizer):
    for param_group in optimizer.param_groups:
        return param_group['lr']

# %%
# 세이브 경로
path = Path(config.save_dir)
if (not path.exists()):
    save_dir = str(path)
else:
    dirs = glob.glob(f"{path}*")
    matches = [re.search(rf"%s(\d+)" % path.stem, d) for d in dirs]
    i = [int(m.groups()[0]) for m in matches if m]
    n = max(i) + 1 if i else 2
    save_dir = f"{path}{n}"

print("save path : " + save_dir)
# Out:
# save path : newModel_exp2

# %% [markdown]
# ### start training

# %%
logger = SummaryWriter(log_dir=save_dir)
with open(os.path.join(save_dir, 'config.json'), 'w', encoding='utf-8') as f:
    json.dump(vars(config), f, ensure_ascii=False, indent=4)

# %%
best_val_acc = 0
best_val_multi_loss = np.inf
best_val_multi_f1 = 0
best_val_age_loss = np.inf
best_val_age_f1 = 0
best_val_total_f1 = 0
for epoch in range(config.epochs):
    # train loop
    model_multi.train()
    model_age.train()
    multi_loss_value = 0
    age_loss_value = 0
    matches = 0
    label_list=[]
    pred_list=[]
    mask_label_list=[]
    mask_pred_list=[]
    age_label_list=[]
    age_pred_list=[]
    gender_label_list=[]
    gender_pred_list=[]
    for idx, train_batch in enumerate(train_loader):
        inputs, (mask_labels, gender_labels, age_labels, multi_class_labels) = train_batch
        inputs = inputs.to(device)
        
        mask_labels = mask_labels.to(device)
        gender_labels = gender_labels.to(device)
        age_labels = age_labels.to(device)
        multi_class_labels = multi_class_labels.to(device)

        optimizer_multi.zero_grad()
        optimizer_age.zero_grad()

        mask_outs, gender_outs = model_multi(inputs)
        mask_preds = torch.argmax(mask_outs, dim=-1)
        mask_preds = mask_preds.detach().cpu()
        gender_preds = torch.argmax(gender_outs, dim=-1)
        gender_preds = gender_preds.detach().cpu()
        
        age_outs = model_age(inputs)
        age_preds = torch.argmax(age_outs, dim=-1)
        age_pred = age_preds.detach().cpu()
        age_preds = age_preds.detach().cpu()
        age_pred_list+=age_pred
        age_preds = age_preds.apply_(AgeLabels.class2number)
        
        multi_preds = mask_preds * 6 + gender_preds * 3 + age_preds
        multi_preds = multi_preds.to(device)
        
        mask_loss = criterion_mask(mask_outs, mask_labels)
        gender_loss = criterion_gender(gender_outs, gender_labels)
        
        multi_loss = mask_loss + gender_loss 
        age_loss = criterion_age(age_outs, age_labels)
        
        multi_loss.backward()
        age_loss.backward()

        optimizer_multi.step()
        optimizer_age.step()
        
        label_list+=multi_class_labels.detach().cpu()
        pred_list+=multi_preds.detach().cpu()
        mask_label_list+=mask_labels.detach().cpu()
        mask_pred_list+=mask_preds
        age_label_list+=age_labels.detach().cpu()
        gender_label_list+=gender_labels.detach().cpu()
        gender_pred_list+=gender_preds

        multi_loss_value += multi_loss.item()
        age_loss_value += age_loss.item()
        matches += (multi_preds == multi_class_labels).sum().item()
        if (idx + 1) % config.log_interval == 0:
            multi_train_loss = multi_loss_value / config.log_interval
            age_train_loss = age_loss_value / config.log_interval
            
            total_train_acc = matches / config.batch_size / config.log_interval
            total_train_f1 = f1_score(label_list, pred_list, average='macro')
            
            mask_f1 = f1_score(mask_label_list, mask_pred_list, average='macro')
            age_f1 = f1_score(age_label_list, age_pred_list, average='macro')
            gender_f1 = f1_score(gender_label_list, gender_pred_list, average='macro')
            
            multi_current_lr = get_lr(optimizer_multi)
            age_current_lr = get_lr(optimizer_age)
            
            print(f"Epoch[{epoch}/{config.epochs}]({idx + 1}/{len(train_loader)})")
            print(f"     [Multi] training loss {multi_train_loss:4.4} || mask f1 {mask_f1:4.4} || gender f1 {gender_f1:4.4} || lr {multi_current_lr}")
            print(f"     [ Age ] training loss {age_train_loss:4.4} || age f1 {age_f1:4.4} || lr {age_current_lr}")
            print(f"     [Total] Acc {total_train_acc:4.2%} || f1-score {total_train_f1:4.4}")
            logger.add_scalar("Train/multi_loss", multi_train_loss, epoch * len(train_loader) + idx)
            logger.add_scalar("Train/age_loss", age_train_loss, epoch * len(train_loader) + idx)
            logger.add_scalar("Train/total_accuracy", total_train_acc, epoch * len(train_loader) + idx)
            logger.add_scalar("Train/total_f1_score", total_train_f1, epoch * len(train_loader) + idx)

            multi_loss_value = 0
            age_loss_value = 0
            matches = 0
            label_list=[]
            pred_list=[]
            mask_label_list=[]
            mask_pred_list=[]
            age_label_list=[]
            age_pred_list=[]
            gender_label_list=[]
            gender_pred_list=[]

    scheduler_multi.step()
    scheduler_age.step()

    # val loop
    with torch.no_grad():
        print("\nCalculating validation results...")
        model_multi.eval()
        model_age.eval()
        val_multi_loss_items = []
        val_age_loss_items = []
        val_acc_items = []
        label_list=[]
        pred_list=[]
        mask_label_list=[]
        mask_pred_list=[]
        age_label_list=[]
        age_pred_list=[]
        gender_label_list=[]
        gender_pred_list=[]
        for val_batch in val_loader:
            inputs, (mask_labels, gender_labels, age_labels, multi_class_labels) = val_batch
            inputs = inputs.to(device)
            mask_labels = mask_labels.to(device)
            gender_labels = gender_labels.to(device)
            age_labels = age_labels.to(device)
            multi_class_labels = multi_class_labels.to(device)

            mask_outs, gender_outs = model_multi(inputs)
            mask_preds = torch.argmax(mask_outs, dim=-1)
            mask_preds = mask_preds.detach().cpu()
            gender_preds = torch.argmax(gender_outs, dim=-1)
            gender_preds = gender_preds.detach().cpu()

            age_outs = model_age(inputs)
            age_preds = torch.argmax(age_outs, dim=-1)
            age_pred = age_preds.detach().cpu()
            age_preds = age_preds.detach().cpu()
            age_pred_list+=age_pred
            age_preds = age_preds.apply_(AgeLabels.class2number)

            multi_preds = mask_preds * 6 + gender_preds * 3 + age_preds
            multi_preds = multi_preds.to(device)

            mask_loss = criterion_mask(mask_outs, mask_labels)
            gender_loss = criterion_gender(gender_outs, gender_labels)

            multi_loss = mask_loss + gender_loss               
            age_loss = criterion_age(age_outs, age_labels)      
            
            label_list+=multi_class_labels.detach().cpu()
            pred_list+=multi_preds.detach().cpu()
            mask_label_list+=mask_labels.detach().cpu()
            mask_pred_list+=mask_preds
            age_label_list+=age_labels.detach().cpu()
            gender_label_list+=gender_labels.detach().cpu()
            gender_pred_list+=gender_preds
            
            acc_item = (multi_class_labels == multi_preds).sum().item()
            val_multi_loss_items.append(multi_loss.item())
            val_age_loss_items.append(age_loss.item())
            val_acc_items.append(acc_item)

        val_multi_loss = float(np.sum(val_multi_loss_items) / len(val_loader))
        val_age_loss = float(np.sum(val_age_loss_items) / len(val_loader))
        
        val_total_acc = float(np.sum(val_acc_items) / len(val_dataset))
        val_total_f1= float(f1_score(label_list,pred_list,average="macro"))
        
        val_mask_f1 = f1_score(mask_label_list, mask_pred_list, average='macro')
        val_age_f1 = f1_score(age_label_list, age_pred_list, average='macro')
        val_gender_f1 = f1_score(gender_label_list, gender_pred_list, average='macro')
        val_multi_f1 = (val_mask_f1 + val_gender_f1) / 2  # mask, gender mean

        if val_multi_f1 > best_val_multi_f1:
            print(f"New best model for Multi || f1 : {val_multi_f1:4.4}! saving the best multi model..")
            torch.save(model_multi.state_dict(), f"{save_dir}/best_multi.pth")
            best_val_multi_f1 = val_multi_f1
            best_val_multi_loss = val_multi_loss
        if val_age_f1 > best_val_age_f1:
            print(f"New best model for Age || f1 : {val_age_f1:4.4}! saving the best multi model..")
            torch.save(model_age.state_dict(), f"{save_dir}/best_age.pth")
            best_val_age_f1 = val_age_f1
            best_val_age_loss = val_age_loss
        if val_total_f1 > best_val_total_f1:
            print(f"New best model for Total || f1 : {val_total_f1:4.4}! saving the best multi model..")
            torch.save(model_multi.state_dict(), f"{save_dir}/best_total_multi.pth")
            torch.save(model_age.state_dict(), f"{save_dir}/best_total_age.pth")
            best_val_total_f1 = val_total_f1
        torch.save(model_multi.state_dict(), f"{save_dir}/last_multi.pth")
        torch.save(model_age.state_dict(), f"{save_dir}/last_age.pth")
        
        print(f"[Val_Multi] loss {val_multi_loss:4.4} || mask f1 {val_mask_f1:4.4} || gender f1 {val_gender_f1:4.4}")
        print(f"[ Val_Age ] loss {val_age_loss:4.4} || age f1 {val_age_f1:4.4}")
        print(f"[Val_Total] Acc {val_total_acc:4.2%} || f1-score {val_total_f1:4.4}")
        print(f"[  Best   ] age_f1 {best_val_age_f1:4.4} || multi_f1 {best_val_multi_f1:4.4} || total_f1 {best_val_total_f1:4.4}")
        logger.add_scalar("Val/multi_loss", val_multi_loss, epoch)
        logger.add_scalar("Val/age_loss", val_age_loss, epoch)
        logger.add_scalar("Val/total_accuracy", val_total_acc, epoch)
        logger.add_scalar("Val/total_f1_score", val_total_f1, epoch)
        print()
# Out:
# Epoch[0/50](50/297)
#      [Multi] training loss 0.2477 || mask f1 0.8086 || gender f1 0.8496 || lr 0.0001
#      [ Age ] training loss -0.5552 || age f1 0.2343 || lr 0.0001
#      [Total] Acc 55.65% || f1-score 0.4393
# Epoch[0/50](100/297)
#      [Multi] training loss 0.06205 || mask f1 0.9761 || gender f1 0.9469 || lr 0.0001
#      [ Age ] training loss -0.89 || age f1 0.3443 || lr 0.0001
#      [Total] Acc 78.69% || f1-score 0.6866
# Epoch[0/50](150/297)
#      [Multi] training loss 0.05206 || mask f1 0.9852 || gender f1 0.9635 || lr 0.0001
#      [ Age ] training loss -1.001 || age f1 0.4036 || lr 0.0001
#      [Total] Acc 84.00% || f1-score 0.7713
# Epoch[0/50](200/297)
#      [Multi] training loss 0.03941 || mask f1 0.9873 || gender f1 0.9675 || lr 0.0001
#      [ Age ] training loss -1.112 || age f1 0.4516 || lr 0.0001
#      [Total] Acc 86.77% || f1-score 0.7868
# Epoch[0/50](250/297)
#      [Multi] training loss 0.03669 || mask f1 0.9855 || gender f1 0.9808 || lr 0.0001
#      [ Age ] training loss -1.136 || age f1 0.4747 || lr 0.0001
#      [Total] Acc 88.38% || f1-score 0.8327
#
# Calculating validation results...
# New best model for Multi || f1 : 0.9874! saving the best multi model..
# New best model for Age || f1 : 0.3754! saving the best multi model..
# New best model for Total || f1 : 0.7566! saving the best multi model..
# [Val_Multi] loss 0.03262 || mask f1 0.996 || gender f1 0.9788
# [ Val_Age ] loss -1.119 || age f1 0.3754
# [Val_Total] Acc 87.30% || f1-score 0.7566
# [  Best   ] age_f1 0.3754 || multi_f1 0.9874 || total_f1 0.7566
#
# Epoch[1/50](50/297)
#      [Multi] training loss 0.01234 || mask f1 0.9945 || gender f1 0.9913 || lr 5e-05
#      [ Age ] training loss -1.386 || age f1 0.5948 || lr 5e-05
#      [Total] Acc 91.88% || f1-score 0.8618
# Epoch[1/50](100/297)
#      [Multi] training loss 0.01086 || mask f1 0.9974 || gender f1 0.991 || lr 5e-05
#      [ Age ] training loss -1.458 || age f1 0.6538 || lr 5e-05
#      [Total] Acc 94.00% || f1-score 0.9075
# Epoch[1/50](150/297)
#      [Multi] training loss 0.01398 || mask f1 0.9939 || gender f1 0.9918 || lr 5e-05
#      [ Age ] training loss -1.478 || age f1 0.664 || lr 5e-05
#      [Total] Acc 94.12% || f1-score 0.897
# Epoch[1/50](200/297)
#      [Multi] training loss 0.00862 || mask f1 0.9968 || gender f1 0.9939 || lr 5e-05
#      [ Age ] training loss -1.5 || age f1 0.6791 || lr 5e-05
#      [Total] Acc 95.00% || f1-score 0.9167
# Epoch[1/50](250/297)
#      [Multi] training loss 0.01078 || mask f1 0.9941 || gender f1 0.9939 || lr 5e-05
#      [ Age ] training loss -1.556 || age f1 0.7294 || lr 5e-05
#      [Total] Acc 95.12% || f1-score 0.9135
#
# Calculating validation results...
# New best model for Multi || f1 : 0.9891! saving the best multi model..
# New best model for Total || f1 : 0.7697! saving the best multi model..
# [Val_Multi] loss 0.03488 || mask f1 0.9952 || gender f1 0.9831
# [ Val_Age ] loss -1.089 || age f1 0.3698
# [Val_Total] Acc 87.44% || f1-score 0.7697
# [  Best   ] age_f1 0.3754 || multi_f1 0.9891 || total_f1 0.7697
#
# Epoch[2/50](50/297)
#      [Multi] training loss 0.004435 || mask f1 0.9976 || gender f1 0.9972 || lr 0.0
#      [ Age ] training loss -1.662 || age f1 0.8076 || lr 0.0
#      [Total] Acc 97.00% || f1-score 0.9493
# Epoch[2/50](100/297)
#      [Multi] training loss 0.007033 || mask f1 0.9976 || gender f1 0.9951 || lr 0.0
#      [ Age ] training loss -1.642 || age f1 0.7842 || lr 0.0
#      [Total] Acc 96.54% || f1-score 0.9502
# Epoch[2/50](150/297)
#      [Multi] training loss 0.00536 || mask f1 0.9968 || gender f1 0.9967 || lr 0.0
#      [ Age ] training loss -1.642 || age f1 0.7851 || lr 0.0
#      [Total] Acc 96.92% || f1-score 0.9536
# Epoch[2/50](200/297)
#      [Multi] training loss 0.004768 || mask f1 0.9956 || gender f1 0.9951 || lr 0.0
#      [ Age ] training loss -1.665 || age f1 0.7808 || lr 0.0
#      [Total] Acc 96.77% || f1-score 0.961
# Epoch[2/50](250/297)
#      [Multi] training loss 0.005073 || mask f1 0.997 || gender f1 0.9976 || lr 0.0
#      [ Age ] training loss -1.64 || age f1 0.7872 || lr 0.0
#      [Total] Acc 96.96% || f1-score 0.9567
#
# Calculating validation results...
# New best model for Total || f1 : 0.7703! saving the best multi model..
# [Val_Multi] loss 0.03478 || mask f1 0.9952 || gender f1 0.9819
# [ Val_Age ] loss -1.089 || age f1 0.3741
# [Val_Total] Acc 87.59% || f1-score 0.7703
# [  Best   ] age_f1 0.3754 || multi_f1 0.9891 || total_f1 0.7703
#
# Epoch[3/50](50/297)
#      [Multi] training loss 0.005508 || mask f1 0.9969 || gender f1 0.9955 || lr 4.9999999999999996e-05
#      [ Age ] training loss -1.663 || age f1 0.7649 || lr 4.9999999999999996e-05
#      [Total] Acc 97.27% || f1-score 0.9604
# Epoch[3/50](100/297)
#      [Multi] training loss 0.006168 || mask f1 0.9948 || gender f1 0.9967 || lr 4.9999999999999996e-05
#      [ Age ] training loss -1.682 || age f1 0.8149 || lr 4.9999999999999996e-05
#      [Total] Acc 97.08% || f1-score 0.9463
# Epoch[3/50](150/297)
#      [Multi] training loss 0.007317 || mask f1 0.9973 || gender f1 0.9922 || lr 4.9999999999999996e-05
#      [ Age ] training loss -1.701 || age f1 0.8306 || lr 4.9999999999999996e-05
#      [Total] Acc 96.46% || f1-score 0.9371
# Epoch[3/50](200/297)
#      [Multi] training loss 0.004247 || mask f1 0.9989 || gender f1 0.9967 || lr 4.9999999999999996e-05
#      [ Age ] training loss -1.711 || age f1 0.8431 || lr 4.9999999999999996e-05
#      [Total] Acc 97.73% || f1-score 0.9616
# Epoch[3/50](250/297)
#      [Multi] training loss 0.002902 || mask f1 0.9978 || gender f1 0.998 || lr 4.9999999999999996e-05
#      [ Age ] training loss -1.738 || age f1 0.8449 || lr 4.9999999999999996e-05
#      [Total] Acc 97.58% || f1-score 0.9647
#
# Calculating validation results...
# New best model for Age || f1 : 0.389! saving the best multi model..
# New best model for Total || f1 : 0.784! saving the best multi model..
# [Val_Multi] loss 0.03056 || mask f1 0.9956 || gender f1 0.9822
# [ Val_Age ] loss -1.052 || age f1 0.389
# [Val_Total] Acc 88.58% || f1-score 0.784
# [  Best   ] age_f1 0.389 || multi_f1 0.9891 || total_f1 0.784
#
# Epoch[4/50](50/297)
#      [Multi] training loss 0.007805 || mask f1 0.9959 || gender f1 0.9959 || lr 0.00010000000000000002
#      [ Age ] training loss -1.798 || age f1 0.8866 || lr 0.00010000000000000002
#      [Total] Acc 98.12% || f1-score 0.9743
# Epoch[4/50](100/297)
#      [Multi] training loss 0.008528 || mask f1 0.9949 || gender f1 0.9939 || lr 0.00010000000000000002
#      [ Age ] training loss -1.821 || age f1 0.9052 || lr 0.00010000000000000002
#      [Total] Acc 97.81% || f1-score 0.9684
# Epoch[4/50](150/297)
#      [Multi] training loss 0.00864 || mask f1 0.9944 || gender f1 0.9939 || lr 0.00010000000000000002
#      [ Age ] training loss -1.82 || age f1 0.8977 || lr 0.00010000000000000002
#      [Total] Acc 97.92% || f1-score 0.9664
# Epoch[4/50](200/297)
#      [Multi] training loss 0.01456 || mask f1 0.9978 || gender f1 0.9848 || lr 0.00010000000000000002
#      [ Age ] training loss -1.854 || age f1 0.9135 || lr 0.00010000000000000002
#      [Total] Acc 97.23% || f1-score 0.9633
# Epoch[4/50](250/297)
#      [Multi] training loss 0.01079 || mask f1 0.9951 || gender f1 0.9914 || lr 0.00010000000000000002
#      [ Age ] training loss -1.898 || age f1 0.9406 || lr 0.00010000000000000002
#      [Total] Acc 98.08% || f1-score 0.972
#
# Calculating validation results...
# [Val_Multi] loss 0.07271 || mask f1 0.9933 || gender f1 0.9701
# [ Val_Age ] loss -1.03 || age f1 0.3887
# [Val_Total] Acc 86.91% || f1-score 0.7572
# [  Best   ] age_f1 0.389 || multi_f1 0.9891 || total_f1 0.784
#
# Epoch[5/50](50/297)
#      [Multi] training loss 0.01763 || mask f1 0.9911 || gender f1 0.9911 || lr 5.000000000000002e-05
#      [ Age ] training loss -1.955 || age f1 0.9437 || lr 5.000000000000002e-05
#      [Total] Acc 97.96% || f1-score 0.9746
# Epoch[5/50](100/297)
#      [Multi] training loss 0.01109 || mask f1 0.9972 || gender f1 0.9943 || lr 5.000000000000002e-05
#      [ Age ] training loss -1.998 || age f1 0.9648 || lr 5.000000000000002e-05
#      [Total] Acc 98.73% || f1-score 0.9766
# Epoch[5/50](150/297)
#      [Multi] training loss 0.003991 || mask f1 0.9983 || gender f1 0.9963 || lr 5.000000000000002e-05
#      [ Age ] training loss -1.998 || age f1 0.9706 || lr 5.000000000000002e-05
#      [Total] Acc 99.04% || f1-score 0.99
# Epoch[5/50](200/297)
#      [Multi] training loss 0.007329 || mask f1 0.9979 || gender f1 0.9959 || lr 5.000000000000002e-05
#      [ Age ] training loss -2.009 || age f1 0.9768 || lr 5.000000000000002e-05
#      [Total] Acc 99.12% || f1-score 0.9823
# Epoch[5/50](250/297)
#      [Multi] training loss 0.003106 || mask f1 0.999 || gender f1 0.9963 || lr 5.000000000000002e-05
#      [ Age ] training loss -2.046 || age f1 0.9764 || lr 5.000000000000002e-05
#      [Total] Acc 99.23% || f1-score 0.9865
#
# Calculating validation results...
# New best model for Age || f1 : 0.4072! saving the best multi model..
# [Val_Multi] loss 0.04323 || mask f1 0.9935 || gender f1 0.981
# [ Val_Age ] loss -1.009 || age f1 0.4072
# [Val_Total] Acc 88.38% || f1-score 0.772
# [  Best   ] age_f1 0.4072 || multi_f1 0.9891 || total_f1 0.784
#
# Epoch[6/50](50/297)
#      [Multi] training loss 0.006136 || mask f1 0.9945 || gender f1 0.998 || lr 0.0
#      [ Age ] training loss -2.055 || age f1 0.9868 || lr 0.0
#      [Total] Acc 99.15% || f1-score 0.9825
# Epoch[6/50](100/297)
#      [Multi] training loss 0.007487 || mask f1 0.9948 || gender f1 0.9988 || lr 0.0
#      [ Age ] training loss -2.062 || age f1 0.9897 || lr 0.0
#      [Total] Acc 99.46% || f1-score 0.9949
# Epoch[6/50](150/297)
#      [Multi] training loss 0.004118 || mask f1 0.9946 || gender f1 0.9967 || lr 0.0
#      [ Age ] training loss -2.054 || age f1 0.9913 || lr 0.0
#      [Total] Acc 99.19% || f1-score 0.9835
# Epoch[6/50](200/297)
#      [Multi] training loss 0.01036 || mask f1 0.9955 || gender f1 0.9988 || lr 0.0
#      [ Age ] training loss -2.05 || age f1 0.9861 || lr 0.0
#      [Total] Acc 99.35% || f1-score 0.9898
# Epoch[6/50](250/297)
#      [Multi] training loss 0.007395 || mask f1 0.9973 || gender f1 0.9968 || lr 0.0
#      [ Age ] training loss -2.077 || age f1 0.9799 || lr 0.0
#      [Total] Acc 99.08% || f1-score 0.9872
#
# Calculating validation results...
# New best model for Age || f1 : 0.4123! saving the best multi model..
# [Val_Multi] loss 0.045 || mask f1 0.9923 || gender f1 0.9819
# [ Val_Age ] loss -1.018 || age f1 0.4123
# [Val_Total] Acc 88.52% || f1-score 0.7771
# [  Best   ] age_f1 0.4123 || multi_f1 0.9891 || total_f1 0.784
#
# Epoch[7/50](50/297)
#      [Multi] training loss 0.003313 || mask f1 0.9968 || gender f1 0.9984 || lr 4.9999999999999996e-05
#      [ Age ] training loss -2.069 || age f1 0.9892 || lr 4.9999999999999996e-05
#      [Total] Acc 99.42% || f1-score 0.9907
# Epoch[7/50](100/297)
#      [Multi] training loss 0.003235 || mask f1 0.9989 || gender f1 0.9988 || lr 4.9999999999999996e-05
#      [ Age ] training loss -2.075 || age f1 0.9874 || lr 4.9999999999999996e-05
#      [Total] Acc 99.54% || f1-score 0.9961
# Epoch[7/50](150/297)
#      [Multi] training loss 0.002145 || mask f1 0.9988 || gender f1 0.9975 || lr 4.9999999999999996e-05
#      [ Age ] training loss -2.079 || age f1 0.9851 || lr 4.9999999999999996e-05
#      [Total] Acc 99.50% || f1-score 0.9951
# Epoch[7/50](200/297)
#      [Multi] training loss 0.000728 || mask f1  1.0 || gender f1 0.9996 || lr 4.9999999999999996e-05
#      [ Age ] training loss -2.097 || age f1 0.9869 || lr 4.9999999999999996e-05
#      [Total] Acc 99.69% || f1-score 0.996
# Epoch[7/50](250/297)
#      [Multi] training loss 0.005019 || mask f1 0.9947 || gender f1 0.9975 || lr 4.9999999999999996e-05
#      [ Age ] training loss -2.098 || age f1 0.9776 || lr 4.9999999999999996e-05
#      [Total] Acc 99.04% || f1-score 0.9837
#
# Calculating validation results...
# New best model for Multi || f1 : 0.9909! saving the best multi model..
# [Val_Multi] loss 0.03602 || mask f1 0.9956 || gender f1 0.9861
# [ Val_Age ] loss -1.018 || age f1 0.3939
# [Val_Total] Acc 88.47% || f1-score 0.7777
# [  Best   ] age_f1 0.4123 || multi_f1 0.9909 || total_f1 0.784
#
# Epoch[8/50](50/297)
#      [Multi] training loss 0.005414 || mask f1 0.9995 || gender f1 0.9955 || lr 0.00010000000000000003
#      [ Age ] training loss -2.094 || age f1 0.9823 || lr 0.00010000000000000003
#      [Total] Acc 99.23% || f1-score 0.9891
# Epoch[8/50](100/297)
#      [Multi] training loss 0.00381 || mask f1 0.9979 || gender f1 0.9967 || lr 0.00010000000000000003
#      [ Age ] training loss -2.104 || age f1 0.9806 || lr 0.00010000000000000003
#      [Total] Acc 99.23% || f1-score 0.9872
# Epoch[8/50](150/297)
#      [Multi] training loss 0.01033 || mask f1 0.996 || gender f1 0.9943 || lr 0.00010000000000000003
#      [ Age ] training loss -2.108 || age f1 0.9756 || lr 0.00010000000000000003
#      [Total] Acc 98.50% || f1-score 0.9771
# Epoch[8/50](200/297)
#      [Multi] training loss 0.01021 || mask f1 0.9934 || gender f1 0.9947 || lr 0.00010000000000000003
#      [ Age ] training loss -2.112 || age f1 0.9735 || lr 0.00010000000000000003
#      [Total] Acc 98.58% || f1-score 0.9815
# Epoch[8/50](250/297)
#      [Multi] training loss 0.005441 || mask f1 0.9973 || gender f1 0.9959 || lr 0.00010000000000000003
#      [ Age ] training loss -2.12 || age f1 0.9676 || lr 0.00010000000000000003
#      [Total] Acc 99.00% || f1-score 0.9877
#
# Calculating validation results...
# [Val_Multi] loss 0.04917 || mask f1 0.9935 || gender f1 0.9861
# [ Val_Age ] loss -0.9238 || age f1 0.374
# [Val_Total] Acc 88.29% || f1-score 0.7719
# [  Best   ] age_f1 0.4123 || multi_f1 0.9909 || total_f1 0.784
#
# Epoch[9/50](50/297)
#      [Multi] training loss 0.003573 || mask f1 0.9972 || gender f1 0.9988 || lr 5.0000000000000036e-05
#      [ Age ] training loss -2.144 || age f1 0.989 || lr 5.0000000000000036e-05
#      [Total] Acc 99.50% || f1-score 0.9944
# Epoch[9/50](100/297)
#      [Multi] training loss 0.004155 || mask f1 0.997 || gender f1 0.9975 || lr 5.0000000000000036e-05
#      [ Age ] training loss -2.166 || age f1 0.9892 || lr 5.0000000000000036e-05
#      [Total] Acc 99.35% || f1-score 0.9932
# Epoch[9/50](150/297)
#      [Multi] training loss 0.00363 || mask f1 0.9994 || gender f1 0.9968 || lr 5.0000000000000036e-05
#      [ Age ] training loss -2.186 || age f1 0.9914 || lr 5.0000000000000036e-05
#      [Total] Acc 99.50% || f1-score 0.9954
# Epoch[9/50](200/297)
#      [Multi] training loss 0.002269 || mask f1 0.9989 || gender f1 0.9992 || lr 5.0000000000000036e-05
#      [ Age ] training loss -2.177 || age f1 0.991 || lr 5.0000000000000036e-05
#      [Total] Acc 99.69% || f1-score 0.9973
# Epoch[9/50](250/297)
#      [Multi] training loss 0.003362 || mask f1 0.9984 || gender f1 0.9984 || lr 5.0000000000000036e-05
#      [ Age ] training loss -2.181 || age f1 0.9914 || lr 5.0000000000000036e-05
#      [Total] Acc 99.65% || f1-score 0.9974
#
# Calculating validation results...
# New best model for Total || f1 : 0.7885! saving the best multi model..
# [Val_Multi] loss 0.04194 || mask f1 0.9952 || gender f1 0.9855
# [ Val_Age ] loss -0.9104 || age f1 0.3998
# [Val_Total] Acc 88.96% || f1-score 0.7885
# [  Best   ] age_f1 0.4123 || multi_f1 0.9909 || total_f1 0.7885
#
# Epoch[10/50](50/297)
#      [Multi] training loss 0.002081 || mask f1 0.9985 || gender f1 0.9996 || lr 0.0
#      [ Age ] training loss -2.18 || age f1 0.9943 || lr 0.0
#      [Total] Acc 99.88% || f1-score 0.9986
# Epoch[10/50](100/297)
#      [Multi] training loss 0.001076 || mask f1  1.0 || gender f1 0.9988 || lr 0.0
#      [ Age ] training loss -2.194 || age f1 0.9927 || lr 0.0
#      [Total] Acc 99.81% || f1-score 0.9984
# Epoch[10/50](150/297)
#      [Multi] training loss 0.003606 || mask f1 0.9989 || gender f1 0.9968 || lr 0.0
#      [ Age ] training loss -2.184 || age f1 0.9973 || lr 0.0
#      [Total] Acc 99.50% || f1-score 0.9869
# Epoch[10/50](200/297)
#      [Multi] training loss 0.001437 || mask f1 0.9995 || gender f1 0.9988 || lr 0.0
#      [ Age ] training loss -2.193 || age f1 0.9892 || lr 0.0
#      [Total] Acc 99.77% || f1-score 0.9938
# Epoch[10/50](250/297)
#      [Multi] training loss 0.001247 || mask f1 0.9995 || gender f1 0.9992 || lr 0.0
#      [ Age ] training loss -2.194 || age f1 0.9949 || lr 0.0
#      [Total] Acc 99.81% || f1-score 0.9983
#
# Calculating validation results...
# New best model for Multi || f1 : 0.9918! saving the best multi model..
# [Val_Multi] loss 0.04148 || mask f1 0.9956 || gender f1 0.9879
# [ Val_Age ] loss -0.9174 || age f1 0.3895
# [Val_Total] Acc 88.85% || f1-score 0.7877
# [  Best   ] age_f1 0.4123 || multi_f1 0.9918 || total_f1 0.7885
#
# Epoch[11/50](50/297)
#      [Multi] training loss 0.003042 || mask f1 0.9995 || gender f1 0.9984 || lr 4.9999999999999996e-05
#      [ Age ] training loss -2.197 || age f1 0.9933 || lr 4.9999999999999996e-05
#      [Total] Acc 99.69% || f1-score 0.9903
# Epoch[11/50](100/297)
#      [Multi] training loss 0.002241 || mask f1 0.9995 || gender f1 0.9984 || lr 4.9999999999999996e-05
#      [ Age ] training loss -2.196 || age f1 0.9962 || lr 4.9999999999999996e-05
#      [Total] Acc 99.69% || f1-score 0.9982
# Epoch[11/50](150/297)
#      [Multi] training loss 0.002429 || mask f1 0.9995 || gender f1 0.9959 || lr 4.9999999999999996e-05
#      [ Age ] training loss -2.205 || age f1 0.9932 || lr 4.9999999999999996e-05
#      [Total] Acc 99.46% || f1-score 0.993
# Epoch[11/50](200/297)
#      [Multi] training loss 0.001774 || mask f1 0.999 || gender f1 0.9984 || lr 4.9999999999999996e-05
#      [ Age ] training loss -2.206 || age f1 0.9957 || lr 4.9999999999999996e-05
#      [Total] Acc 99.73% || f1-score 0.9973
# Epoch[11/50](250/297)
#      [Multi] training loss 0.000684 || mask f1 0.9995 || gender f1  1.0 || lr 4.9999999999999996e-05
#      [ Age ] training loss -2.187 || age f1 0.9881 || lr 4.9999999999999996e-05
#      [Total] Acc 99.85% || f1-score 0.9993
#
# Calculating validation results...
# [Val_Multi] loss 0.04368 || mask f1 0.9956 || gender f1 0.9855
# [ Val_Age ] loss -0.8757 || age f1 0.3989
# [Val_Total] Acc 88.73% || f1-score 0.7804
# [  Best   ] age_f1 0.4123 || multi_f1 0.9918 || total_f1 0.7885
#
# Epoch[12/50](50/297)
#      [Multi] training loss 0.005233 || mask f1 0.9959 || gender f1 0.9996 || lr 0.00010000000000000024
#      [ Age ] training loss -2.213 || age f1 0.9934 || lr 0.00010000000000000024
#      [Total] Acc 99.62% || f1-score 0.9969
# Epoch[12/50](100/297)
#      [Multi] training loss 0.005744 || mask f1 0.9965 || gender f1 0.9971 || lr 0.00010000000000000024
#      [ Age ] training loss -2.198 || age f1 0.9883 || lr 0.00010000000000000024
#      [Total] Acc 99.46% || f1-score 0.9885
# Epoch[12/50](150/297)
#      [Multi] training loss 0.00955 || mask f1 0.9984 || gender f1 0.9919 || lr 0.00010000000000000024
#      [ Age ] training loss -2.193 || age f1 0.9881 || lr 0.00010000000000000024
#      [Total] Acc 98.96% || f1-score 0.989
# Epoch[12/50](200/297)
#      [Multi] training loss 0.02074 || mask f1 0.9862 || gender f1 0.993 || lr 0.00010000000000000024
#      [ Age ] training loss -2.184 || age f1 0.9782 || lr 0.00010000000000000024
#      [Total] Acc 98.04% || f1-score 0.9802
# Epoch[12/50](250/297)
#      [Multi] training loss 0.01093 || mask f1 0.9961 || gender f1 0.9923 || lr 0.00010000000000000024
#      [ Age ] training loss -2.179 || age f1 0.9832 || lr 0.00010000000000000024
#      [Total] Acc 98.69% || f1-score 0.987
#
# Calculating validation results...
# [Val_Multi] loss 0.04264 || mask f1 0.9956 || gender f1 0.9843
# [ Val_Age ] loss -0.7899 || age f1 0.3866
# [Val_Total] Acc 87.30% || f1-score 0.7631
# [  Best   ] age_f1 0.4123 || multi_f1 0.9918 || total_f1 0.7885
#
# Epoch[13/50](50/297)
#      [Multi] training loss 0.006556 || mask f1 0.9978 || gender f1 0.9959 || lr 5.000000000000007e-05
#      [ Age ] training loss -2.202 || age f1 0.9899 || lr 5.000000000000007e-05
#      [Total] Acc 99.38% || f1-score 0.9896
# Epoch[13/50](100/297)
#      [Multi] training loss 0.004231 || mask f1 0.9989 || gender f1 0.9947 || lr 5.000000000000007e-05
#      [ Age ] training loss -2.23 || age f1 0.9932 || lr 5.000000000000007e-05
#      [Total] Acc 99.23% || f1-score 0.9866
# Epoch[13/50](150/297)
#      [Multi] training loss 0.001431 || mask f1  1.0 || gender f1 0.9984 || lr 5.000000000000007e-05
#      [ Age ] training loss -2.234 || age f1 0.9954 || lr 5.000000000000007e-05
#      [Total] Acc 99.77% || f1-score 0.9975
# Epoch[13/50](200/297)
#      [Multi] training loss 0.003408 || mask f1 0.9975 || gender f1 0.9992 || lr 5.000000000000007e-05
#      [ Age ] training loss -2.228 || age f1 0.9944 || lr 5.000000000000007e-05
#      [Total] Acc 99.73% || f1-score 0.9974
# Epoch[13/50](250/297)
#      [Multi] training loss 0.003279 || mask f1 0.9991 || gender f1 0.998 || lr 5.000000000000007e-05
#      [ Age ] training loss -2.227 || age f1 0.9889 || lr 5.000000000000007e-05
#      [Total] Acc 99.58% || f1-score 0.992
#
# Calculating validation results...
# [Val_Multi] loss 0.03323 || mask f1 0.9952 || gender f1 0.9825
# [ Val_Age ] loss -0.8102 || age f1 0.4013
# [Val_Total] Acc 87.68% || f1-score 0.7689
# [  Best   ] age_f1 0.4123 || multi_f1 0.9918 || total_f1 0.7885
#
# Epoch[14/50](50/297)
#      [Multi] training loss 0.002659 || mask f1 0.9975 || gender f1 0.9988 || lr 0.0
#      [ Age ] training loss -2.238 || age f1 0.9982 || lr 0.0
#      [Total] Acc 99.73% || f1-score 0.9973
# Epoch[14/50](100/297)
#      [Multi] training loss 0.001595 || mask f1 0.9984 || gender f1  1.0 || lr 0.0
#      [ Age ] training loss -2.239 || age f1 0.9925 || lr 0.0
#      [Total] Acc 99.73% || f1-score 0.9986
# Epoch[14/50](150/297)
#      [Multi] training loss 0.001846 || mask f1 0.9994 || gender f1 0.9988 || lr 0.0
#      [ Age ] training loss -2.228 || age f1 0.9945 || lr 0.0
#      [Total] Acc 99.77% || f1-score 0.9972
# Epoch[14/50](200/297)
#      [Multi] training loss 0.003488 || mask f1 0.9984 || gender f1 0.9996 || lr 0.0
#      [ Age ] training loss -2.253 || age f1 0.9945 || lr 0.0
#      [Total] Acc 99.77% || f1-score 0.9976
# Epoch[14/50](250/297)
#      [Multi] training loss 0.001241 || mask f1 0.9984 || gender f1 0.9992 || lr 0.0
#      [ Age ] training loss -2.245 || age f1 0.9985 || lr 0.0
#      [Total] Acc 99.77% || f1-score 0.9982
#
# Calculating validation results...
# [Val_Multi] loss 0.02932 || mask f1 0.9952 || gender f1 0.9846
# [ Val_Age ] loss -0.8243 || age f1 0.4045
# [Val_Total] Acc 88.09% || f1-score 0.7746
# [  Best   ] age_f1 0.4123 || multi_f1 0.9918 || total_f1 0.7885
#
# Epoch[15/50](50/297)
#      [Multi] training loss 0.001057 || mask f1 0.9986 || gender f1 0.9992 || lr 4.9999999999999996e-05
#      [ Age ] training loss -2.244 || age f1 0.9974 || lr 4.9999999999999996e-05
#      [Total] Acc 99.85% || f1-score 0.996
# Epoch[15/50](100/297)
#      [Multi] training loss 0.0006966 || mask f1 0.9995 || gender f1 0.9992 || lr 4.9999999999999996e-05
#      [ Age ] training loss -2.249 || age f1 0.9944 || lr 4.9999999999999996e-05
#      [Total] Acc 99.81% || f1-score 0.9982
# Epoch[15/50](150/297)
#      [Multi] training loss 0.002164 || mask f1 0.9978 || gender f1 0.9996 || lr 4.9999999999999996e-05
#      [ Age ] training loss -2.246 || age f1 0.9983 || lr 4.9999999999999996e-05
#      [Total] Acc 99.73% || f1-score 0.9967
# Epoch[15/50](200/297)
#      [Multi] training loss 0.002804 || mask f1 0.9985 || gender f1 0.9988 || lr 4.9999999999999996e-05
#      [ Age ] training loss -2.243 || age f1 0.9965 || lr 4.9999999999999996e-05
#      [Total] Acc 99.77% || f1-score 0.9968
# Epoch[15/50](250/297)
#      [Multi] training loss 0.003269 || mask f1 0.9973 || gender f1  1.0 || lr 4.9999999999999996e-05
#      [ Age ] training loss -2.252 || age f1 0.9935 || lr 4.9999999999999996e-05
#      [Total] Acc 99.62% || f1-score 0.9888
#
# Calculating validation results...
# New best model for Multi || f1 : 0.9919! saving the best multi model..
# [Val_Multi] loss 0.03421 || mask f1 0.9956 || gender f1 0.9882
# [ Val_Age ] loss -0.7684 || age f1 0.3975
# [Val_Total] Acc 88.03% || f1-score 0.7801
# [  Best   ] age_f1 0.4123 || multi_f1 0.9919 || total_f1 0.7885
#
# Epoch[16/50](50/297)
#      [Multi] training loss 0.003521 || mask f1 0.998 || gender f1 0.9976 || lr 0.00010000000000000026
#      [ Age ] training loss -2.242 || age f1 0.9984 || lr 0.00010000000000000026
#      [Total] Acc 99.58% || f1-score 0.9939
# Epoch[16/50](100/297)
#      [Multi] training loss 0.003447 || mask f1 0.9991 || gender f1 0.9967 || lr 0.00010000000000000026
#      [ Age ] training loss -2.239 || age f1 0.9895 || lr 0.00010000000000000026
#      [Total] Acc 99.54% || f1-score 0.9964
# Epoch[16/50](150/297)
#      [Multi] training loss 0.006156 || mask f1 0.9994 || gender f1 0.9944 || lr 0.00010000000000000026
#      [ Age ] training loss -2.213 || age f1 0.9796 || lr 0.00010000000000000026
#      [Total] Acc 99.12% || f1-score 0.9881
# Epoch[16/50](200/297)
#      [Multi] training loss 0.009853 || mask f1 0.9994 || gender f1 0.9919 || lr 0.00010000000000000026
#      [ Age ] training loss -2.196 || age f1 0.9867 || lr 0.00010000000000000026
#      [Total] Acc 98.88% || f1-score 0.9839
# Epoch[16/50](250/297)
#      [Multi] training loss 0.009929 || mask f1 0.9973 || gender f1 0.9909 || lr 0.00010000000000000026
#      [ Age ] training loss -2.228 || age f1 0.9765 || lr 0.00010000000000000026
#      [Total] Acc 98.81% || f1-score 0.9857
#
# Calculating validation results...
# [Val_Multi] loss 0.05364 || mask f1 0.996 || gender f1 0.9789
# [ Val_Age ] loss -0.7977 || age f1 0.3921
# [Val_Total] Acc 88.23% || f1-score 0.78
# [  Best   ] age_f1 0.4123 || multi_f1 0.9919 || total_f1 0.7885
#
# Epoch[17/50](50/297)
#      [Multi] training loss 0.001554 || mask f1  1.0 || gender f1 0.9988 || lr 5.000000000000009e-05
#      [ Age ] training loss -2.236 || age f1 0.9908 || lr 5.000000000000009e-05
#      [Total] Acc 99.85% || f1-score 0.9954
# Epoch[17/50](100/297)
#      [Multi] training loss 0.003024 || mask f1 0.9995 || gender f1 0.9984 || lr 5.000000000000009e-05
#      [ Age ] training loss -2.241 || age f1 0.9893 || lr 5.000000000000009e-05
#      [Total] Acc 99.58% || f1-score 0.9957
# Epoch[17/50](150/297)
#      [Multi] training loss 0.002062 || mask f1  1.0 || gender f1 0.998 || lr 5.000000000000009e-05
#      [ Age ] training loss -2.241 || age f1 0.9918 || lr 5.000000000000009e-05
#      [Total] Acc 99.73% || f1-score 0.9975
# Epoch[17/50](200/297)
#      [Multi] training loss 0.001474 || mask f1  1.0 || gender f1 0.9984 || lr 5.000000000000009e-05
#      [ Age ] training loss -2.261 || age f1 0.9985 || lr 5.000000000000009e-05
#      [Total] Acc 99.85% || f1-score 0.9977
# Epoch[17/50](250/297)
#      [Multi] training loss 0.0009333 || mask f1  1.0 || gender f1 0.9988 || lr 5.000000000000009e-05
#      [ Age ] training loss -2.263 || age f1 0.9942 || lr 5.000000000000009e-05
#      [Total] Acc 99.77% || f1-score 0.9981
#
# Calculating validation results...
# [Val_Multi] loss 0.03597 || mask f1 0.9944 || gender f1 0.984
# [ Val_Age ] loss -0.6733 || age f1 0.3901
# [Val_Total] Acc 87.91% || f1-score 0.7745
# [  Best   ] age_f1 0.4123 || multi_f1 0.9919 || total_f1 0.7885
#
# Epoch[18/50](50/297)
#      [Multi] training loss 0.001181 || mask f1 0.9994 || gender f1 0.9988 || lr 0.0
#      [ Age ] training loss -2.266 || age f1 0.9966 || lr 0.0
#      [Total] Acc 99.77% || f1-score 0.9973
# Epoch[18/50](100/297)
#      [Multi] training loss 0.0003332 || mask f1  1.0 || gender f1  1.0 || lr 0.0
#      [ Age ] training loss -2.264 || age f1 0.9924 || lr 0.0
#      [Total] Acc 99.88% || f1-score 0.9992
# Epoch[18/50](150/297)
#      [Multi] training loss 0.0007332 || mask f1  1.0 || gender f1 0.9992 || lr 0.0
#      [ Age ] training loss -2.257 || age f1 0.9964 || lr 0.0
#      [Total] Acc 99.88% || f1-score 0.9989
# Epoch[18/50](200/297)
#      [Multi] training loss 0.000871 || mask f1 0.9978 || gender f1 0.9996 || lr 0.0
#      [ Age ] training loss -2.261 || age f1 0.9975 || lr 0.0
#      [Total] Acc 99.77% || f1-score 0.9976
# Epoch[18/50](250/297)
#      [Multi] training loss 0.002593 || mask f1 0.9985 || gender f1 0.9984 || lr 0.0
#      [ Age ] training loss -2.263 || age f1  1.0 || lr 0.0
#      [Total] Acc 99.77% || f1-score 0.9964
#
# Calculating validation results...
# [Val_Multi] loss 0.03674 || mask f1 0.9944 || gender f1 0.9837
# [ Val_Age ] loss -0.684 || age f1 0.392
# [Val_Total] Acc 88.44% || f1-score 0.777
# [  Best   ] age_f1 0.4123 || multi_f1 0.9919 || total_f1 0.7885
#
# Epoch[19/50](50/297)
#      [Multi] training loss 0.001517 || mask f1 0.9995 || gender f1 0.9983 || lr 4.9999999999999996e-05
#      [ Age ] training loss -2.254 || age f1 0.9968 || lr 4.9999999999999996e-05
#      [Total] Acc 99.77% || f1-score 0.9985
# Epoch[19/50](100/297)
#      [Multi] training loss 0.002006 || mask f1 0.9969 || gender f1 0.9996 || lr 4.9999999999999996e-05
#      [ Age ] training loss -2.261 || age f1 0.9976 || lr 4.9999999999999996e-05
#      [Total] Acc 99.77% || f1-score 0.9969
# Epoch[19/50](150/297)
#      [Multi] training loss 0.0006246 || mask f1 0.9991 || gender f1 0.9996 || lr 4.9999999999999996e-05
#      [ Age ] training loss -2.267 || age f1 0.999 || lr 4.9999999999999996e-05
#      [Total] Acc 99.88% || f1-score 0.9991
# Epoch[19/50](200/297)
#      [Multi] training loss 0.001386 || mask f1 0.9985 || gender f1 0.9992 || lr 4.9999999999999996e-05
#      [ Age ] training loss -2.266 || age f1 0.9951 || lr 4.9999999999999996e-05
#      [Total] Acc 99.81% || f1-score 0.9979
# Epoch[19/50](250/297)
#      [Multi] training loss 0.0003883 || mask f1  1.0 || gender f1 0.9996 || lr 4.9999999999999996e-05
#      [ Age ] training loss -2.264 || age f1 0.9991 || lr 4.9999999999999996e-05
#      [Total] Acc 99.96% || f1-score 0.9992
#
# Calculating validation results...
# [Val_Multi] loss 0.03084 || mask f1 0.9952 || gender f1 0.9867
# [ Val_Age ] loss -0.7067 || age f1 0.3868
# [Val_Total] Acc 88.09% || f1-score 0.777
# [  Best   ] age_f1 0.4123 || multi_f1 0.9919 || total_f1 0.7885
#
# Epoch[20/50](50/297)
#      [Multi] training loss 0.00209 || mask f1 0.9969 || gender f1 0.9996 || lr 0.00010000000000000028
#      [ Age ] training loss -2.266 || age f1 0.9947 || lr 0.00010000000000000028
#      [Total] Acc 99.65% || f1-score 0.9897
# Epoch[20/50](100/297)
#      [Multi] training loss 0.001262 || mask f1 0.9984 || gender f1  1.0 || lr 0.00010000000000000028
#      [ Age ] training loss -2.255 || age f1 0.9862 || lr 0.00010000000000000028
#      [Total] Acc 99.73% || f1-score 0.9975
# Epoch[20/50](150/297)
#      [Multi] training loss 0.001028 || mask f1 0.9995 || gender f1 0.9992 || lr 0.00010000000000000028
#      [ Age ] training loss -2.248 || age f1 0.9952 || lr 0.00010000000000000028
#      [Total] Acc 99.73% || f1-score 0.9965
# Epoch[20/50](200/297)
#      [Multi] training loss 0.005249 || mask f1 0.9972 || gender f1 0.9988 || lr 0.00010000000000000028
#      [ Age ] training loss -2.225 || age f1 0.9831 || lr 0.00010000000000000028
#      [Total] Acc 99.38% || f1-score 0.985
# Epoch[20/50](250/297)
#      [Multi] training loss 0.005023 || mask f1 0.995 || gender f1 0.9992 || lr 0.00010000000000000028
#      [ Age ] training loss -2.228 || age f1 0.98 || lr 0.00010000000000000028
#      [Total] Acc 99.23% || f1-score 0.9896
#
# Calculating validation results...
# [Val_Multi] loss 0.04096 || mask f1 0.9948 || gender f1 0.9867
# [ Val_Age ] loss -0.7064 || age f1 0.3792
# [Val_Total] Acc 87.91% || f1-score 0.7802
# [  Best   ] age_f1 0.4123 || multi_f1 0.9919 || total_f1 0.7885
#
# Epoch[21/50](50/297)
#      [Multi] training loss 0.003804 || mask f1 0.998 || gender f1 0.9964 || lr 5.000000000000012e-05
#      [ Age ] training loss -2.244 || age f1 0.9867 || lr 5.000000000000012e-05
#      [Total] Acc 99.27% || f1-score 0.994
# Epoch[21/50](100/297)
#      [Multi] training loss 0.00181 || mask f1 0.9981 || gender f1 0.9996 || lr 5.000000000000012e-05
#      [ Age ] training loss -2.253 || age f1 0.992 || lr 5.000000000000012e-05
#      [Total] Acc 99.65% || f1-score 0.9936
# Epoch[21/50](150/297)
#      [Multi] training loss 0.0008786 || mask f1  1.0 || gender f1 0.9992 || lr 5.000000000000012e-05
#      [ Age ] training loss -2.269 || age f1 0.9919 || lr 5.000000000000012e-05
#      [Total] Acc 99.77% || f1-score 0.9983
# Epoch[21/50](200/297)
#      [Multi] training loss 0.001363 || mask f1  1.0 || gender f1 0.998 || lr 5.000000000000012e-05
#      [ Age ] training loss -2.255 || age f1 0.9971 || lr 5.000000000000012e-05
#      [Total] Acc 99.81% || f1-score 0.9973
# Epoch[21/50](250/297)
#      [Multi] training loss 0.0007161 || mask f1 0.9986 || gender f1  1.0 || lr 5.000000000000012e-05
#      [ Age ] training loss -2.269 || age f1 0.9968 || lr 5.000000000000012e-05
#      [Total] Acc 99.88% || f1-score 0.9971
#
# Calculating validation results...
# [Val_Multi] loss 0.03292 || mask f1 0.9952 || gender f1 0.9879
# [ Val_Age ] loss -0.62 || age f1 0.3794
# [Val_Total] Acc 87.47% || f1-score 0.7766
# [  Best   ] age_f1 0.4123 || multi_f1 0.9919 || total_f1 0.7885
#
# Epoch[22/50](50/297)
#      [Multi] training loss 0.0005404 || mask f1  1.0 || gender f1 0.9996 || lr 0.0
#      [ Age ] training loss -2.263 || age f1 0.9966 || lr 0.0
#      [Total] Acc 99.88% || f1-score 0.9985
# Epoch[22/50](100/297)
#      [Multi] training loss 0.0009758 || mask f1 0.9991 || gender f1 0.9992 || lr 0.0
#      [ Age ] training loss -2.272 || age f1 0.9972 || lr 0.0
#      [Total] Acc 99.81% || f1-score 0.9956
# Epoch[22/50](150/297)
#      [Multi] training loss 0.0009391 || mask f1 0.9989 || gender f1 0.9984 || lr 0.0
#      [ Age ] training loss -2.273 || age f1 0.9988 || lr 0.0
#      [Total] Acc 99.73% || f1-score 0.9946
# Epoch[22/50](200/297)
#      [Multi] training loss 0.0009385 || mask f1 0.9989 || gender f1 0.9992 || lr 0.0
#      [ Age ] training loss -2.276 || age f1 0.9981 || lr 0.0
#      [Total] Acc 99.81% || f1-score 0.9936
# Epoch[22/50](250/297)
#      [Multi] training loss 0.0003679 || mask f1  1.0 || gender f1 0.9996 || lr 0.0
#      [ Age ] training loss -2.276 || age f1 0.9988 || lr 0.0
#      [Total] Acc 99.96% || f1-score 0.9993
#
# Calculating validation results...
# [Val_Multi] loss 0.03337 || mask f1 0.9948 || gender f1 0.9882
# [ Val_Age ] loss -0.6434 || age f1 0.3788
# [Val_Total] Acc 87.65% || f1-score 0.7735
# [  Best   ] age_f1 0.4123 || multi_f1 0.9919 || total_f1 0.7885
#
# Epoch[23/50](50/297)
#      [Multi] training loss 0.000739 || mask f1 0.9986 || gender f1  1.0 || lr 4.9999999999999996e-05
#      [ Age ] training loss -2.278 || age f1 0.997 || lr 4.9999999999999996e-05
#      [Total] Acc 99.88% || f1-score 0.9984
# Epoch[23/50](100/297)
#      [Multi] training loss 0.001578 || mask f1 0.9994 || gender f1 0.9992 || lr 4.9999999999999996e-05
#      [ Age ] training loss -2.271 || age f1 0.9966 || lr 4.9999999999999996e-05
#      [Total] Acc 99.88% || f1-score 0.9989
# Epoch[23/50](150/297)
#      [Multi] training loss 0.00195 || mask f1 0.998 || gender f1  1.0 || lr 4.9999999999999996e-05
#      [ Age ] training loss -2.274 || age f1 0.996 || lr 4.9999999999999996e-05
#      [Total] Acc 99.81% || f1-score 0.9986
# Epoch[23/50](200/297)
#      [Multi] training loss 0.002668 || mask f1 0.9973 || gender f1 0.9996 || lr 4.9999999999999996e-05
#      [ Age ] training loss -2.271 || age f1 0.9976 || lr 4.9999999999999996e-05
#      [Total] Acc 99.81% || f1-score 0.9977
# Epoch[23/50](250/297)
#      [Multi] training loss 0.0002732 || mask f1  1.0 || gender f1  1.0 || lr 4.9999999999999996e-05
#      [ Age ] training loss -2.278 || age f1 0.9986 || lr 4.9999999999999996e-05
#      [Total] Acc 99.96% || f1-score 0.9978
#
# Calculating validation results...
# [Val_Multi] loss 0.04044 || mask f1 0.9952 || gender f1 0.9861
# [ Val_Age ] loss -0.5513 || age f1 0.3839
# [Val_Total] Acc 88.32% || f1-score 0.7841
# [  Best   ] age_f1 0.4123 || multi_f1 0.9919 || total_f1 0.7885
#
# Epoch[24/50](50/297)
#      [Multi] training loss 0.003322 || mask f1 0.9978 || gender f1 0.9996 || lr 0.00010000000000000033
#      [ Age ] training loss -2.268 || age f1 0.9972 || lr 0.00010000000000000033
#      [Total] Acc 99.77% || f1-score 0.997
# Epoch[24/50](100/297)
#      [Multi] training loss 0.004738 || mask f1 0.9979 || gender f1 0.9992 || lr 0.00010000000000000033
#      [ Age ] training loss -2.264 || age f1 0.9966 || lr 0.00010000000000000033
#      [Total] Acc 99.73% || f1-score 0.9962
# Epoch[24/50](150/297)
#      [Multi] training loss 0.008616 || mask f1 0.999 || gender f1 0.9955 || lr 0.00010000000000000033
#      [ Age ] training loss -2.229 || age f1 0.9833 || lr 0.00010000000000000033
#      [Total] Acc 99.38% || f1-score 0.9936
# Epoch[24/50](200/297)
#      [Multi] training loss 0.009107 || mask f1 0.9989 || gender f1 0.9932 || lr 0.00010000000000000033
#      [ Age ] training loss -2.245 || age f1 0.982 || lr 0.00010000000000000033
#      [Total] Acc 99.04% || f1-score 0.9926
# Epoch[24/50](250/297)
#      [Multi] training loss 0.003973 || mask f1 0.9984 || gender f1 0.9959 || lr 0.00010000000000000033
#      [ Age ] training loss -2.26 || age f1 0.992 || lr 0.00010000000000000033
#      [Total] Acc 99.38% || f1-score 0.9906
#
# Calculating validation results...
# [Val_Multi] loss 0.03275 || mask f1 0.9932 || gender f1 0.984
# [ Val_Age ] loss -0.5602 || age f1 0.3888
# [Val_Total] Acc 87.53% || f1-score 0.7728
# [  Best   ] age_f1 0.4123 || multi_f1 0.9919 || total_f1 0.7885
#
# Epoch[25/50](50/297)
#      [Multi] training loss 0.002503 || mask f1 0.9971 || gender f1  1.0 || lr 5.000000000000015e-05
#      [ Age ] training loss -2.251 || age f1 0.9898 || lr 5.000000000000015e-05
#      [Total] Acc 99.65% || f1-score 0.9951
# Epoch[25/50](100/297)
#      [Multi] training loss 0.0009826 || mask f1  1.0 || gender f1 0.9996 || lr 5.000000000000015e-05
#      [ Age ] training loss -2.261 || age f1 0.9938 || lr 5.000000000000015e-05
#      [Total] Acc 99.85% || f1-score 0.9969
# Epoch[25/50](150/297)
#      [Multi] training loss 0.001952 || mask f1 0.9984 || gender f1 0.9992 || lr 5.000000000000015e-05
#      [ Age ] training loss -2.278 || age f1 0.9977 || lr 5.000000000000015e-05
#      [Total] Acc 99.81% || f1-score 0.9965
# Epoch[25/50](200/297)
#      [Multi] training loss 0.0009364 || mask f1  1.0 || gender f1 0.9996 || lr 5.000000000000015e-05
#      [ Age ] training loss -2.268 || age f1 0.9959 || lr 5.000000000000015e-05
#      [Total] Acc 99.92% || f1-score 0.9997
# Epoch[25/50](250/297)
#      [Multi] training loss 0.0007789 || mask f1  1.0 || gender f1 0.9992 || lr 5.000000000000015e-05
#      [ Age ] training loss -2.282 || age f1 0.9987 || lr 5.000000000000015e-05
#      [Total] Acc 99.92% || f1-score 0.9986
#
# Calculating validation results...
# [Val_Multi] loss 0.03632 || mask f1 0.996 || gender f1 0.9852
# [ Val_Age ] loss -0.6604 || age f1 0.3808
# [Val_Total] Acc 88.35% || f1-score 0.7804
# [  Best   ] age_f1 0.4123 || multi_f1 0.9919 || total_f1 0.7885
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-22-b865289c219d> in <module>
#      30
#      31         optimizer_multi.zero_grad()
# ---> 32         optimizer_age.zero_grad()
#      33
#      34         mask_outs, gender_outs = model_multi(inputs)
#
# /opt/conda/lib/python3.8/site-packages/torch/optim/optimizer.py in zero_grad(self, set_to_none)
#     245                                 p.grad.detach_()
#     246                             else:
# --> 247                                 p.grad.requires_grad_(False)
#     248                             if (not foreach or p.grad.is_sparse):
#     249                                 p.grad.zero_()
#
# /opt/conda/lib/python3.8/site-packages/torch/_tensor.py in grad(self)
#    1081             return handle_torch_function(Tensor.grad.__get__, (self,), self)  # type: ignore[attr-defined]
#    1082
# -> 1083         return self._grad
#    1084
#    1085     @grad.setter
#
# KeyboardInterrupt:
